# %%
# Importing YouTube API, MongoDB, MySQL, and Streamlit 

from googleapiclient.discovery import build
import pymongo
import pandas as pd
import streamlit as st
import mysql.connector

# %%
# Establishing Connection With API Key

def api_connect():
    api_id = 'AIzaSyAqxT8f-HYwqKxuOZBrTyAo46JBf1kaKoY'
    api_service_name = 'youtube'
    api_version = 'v3'

    youtube = build(api_service_name, api_version, developerKey = api_id)

    return youtube

youtube = api_connect()

# %%
# Fetching Channel Information From YouTube API

request = youtube.channels().list(
        part = "snippet,contentDetails,statistics",
        id = "UCT8FGLq9AU1H6U3ePhegxJA"
)

response = request.execute()

# %%
# Function To Fetch Youtube Channel Information

def get_channel_info(channel_id):
    request = youtube.channels().list(
        part = "snippet,contentDetails,statistics",
        id = channel_id
    )
    response = request.execute()  

    for item in response['items']:
        channel_data = dict(channel_name = item['snippet']['title'],
                            channel_id = item['id'],
                            channel_description = item['snippet']['description'],
                            channel_playlist = item['contentDetails']['relatedPlaylists']['uploads'],
                            channel_viewcount = item['statistics']['viewCount'],
                            channel_subcribers = item['statistics']['subscriberCount'],
                            channel_videocount = item['statistics']['videoCount']
        )
    return channel_data

# %%
channel_details = get_channel_info("UCT8FGLq9AU1H6U3ePhegxJA")

# %%
channel_details
# Out:
# {'channel_name': 'Mad Stuff With Rob',
#  'channel_id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#  'channel_description': "hey Guys! You might remember me from M.A.D. on POGO but I have now started my own YouTube journey. So for all those who want to catch up on the new stuff that I've been doing then I suggest you subscribe! I upload a new DIY video every week. So stay tuned!\n\nHappy DIY-ing!\n\nYouTube - http://www.youtube.com/user/madstuffwithrob\nFacebook - https://www.facebook.com/artguyrob\nInstagram - http://instagram.com/artguyrob\n\n\n",
#  'channel_playlist': 'UUT8FGLq9AU1H6U3ePhegxJA',
#  'channel_viewcount': '164594974',
#  'channel_subcribers': '2460000',
#  'channel_videocount': '473'}

# %%
# Function To Fetch All Video IDs Of The Channel

def get_videos_ids(channel_id):
    video_ids = []

    response = youtube.channels().list(part='contentDetails', id=channel_id).execute()

    # Retrieving YouTube Channel's Uploads Playlist

    playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token = None

    while True:
        # Fetching All Videos From Uploads Playlist

        playlist_items = youtube.playlistItems().list(
            part="snippet",
            playlistId=playlist_id,
            maxResults=50,  
            pageToken=next_page_token
        ).execute()

        # Append video IDs To The List
        
        for item in playlist_items['items']:
            video_ids.append(item['snippet']['resourceId']['videoId'])

        next_page_token = playlist_items.get('nextPageToken')

        if next_page_token is None:
            break

    return video_ids

Video_Ids = get_videos_ids('UCT8FGLq9AU1H6U3ePhegxJA')

# %%
Video_Ids
# Out:
# ['ieX38it7gFo',
#  'WDJrRiI4kJ4',
#  'uMeAQ4pO_dI',
#  'df3regswjQI',
#  'WzjdkcFjEaY',
#  'tV-yBLmJgw0',
#  'AfXZxknpp70',
#  'WEgYQZizohY',
#  'duFBMPfk_Ng',
#  'KQyAPIGLmU0',
#  'VLiYnallEh0',
#  'wjJxGiknA_I',
#  '0efzC1BVim4',
#  'tzy2UYOP4Z0',
#  'UpGv1i4mKWs',
#  'Zg31pJpNsWA',
#  '8t6KDsX2Sa8',
#  'lYSsaGDSg2o',
#  'Zb21vAf5GfA',
#  'lM_Sk8biVco',
#  'i6b1zU0Gcio',
#  'yIBx3HFweyc',
#  '5XP1ivrFit4',
#  'l3CsgsmCdzY',
#  'VCrjf_di-50',
#  'gr1Lb_VK5oQ',
#  'CJ7LQXgp81w',
#  'ex_mbgZiifU',
#  'W5Qp7XNdu5E',
#  '9CFmhbSOuv8',
#  'i3_qqZzfXsQ',
#  'ncZgvHIL0G8',
#  'MkMgg36urz8',
#  'gD0gtXNob14',
#  'xDNfXTHYkts',
#  'oVcW1cIvf3I',
#  'wbUhcqQH-Ww',
#  'xTKl3Cx5QNs',
#  'O8BgKkJezNk',
#  'fMAQSi_xh7k',
#  'dZMTI-D3UHA',
#  'GTExAaWJm7w',
#  'CjxP6BBgFnQ',
#  '8iXbXT4Wm3U',
#  'ZX5O3JN9S_g',
#  'MKM2lwShDJE',
#  'qA22VJo3BDc',
#  '0KVk2yAdjSE',
#  '1OAN8540F8M',
#  '4orjieN6Efg',
#  'zUGPmT1wP0I',
#  'Nriha6gNyys',
#  'dR-ipRb1MzY',
#  'ciocc_qFTDU',
#  'HnV7MaYawQc',
#  'G5DyAYm_im8',
#  'hkpVgYjZa7w',
#  '55am_FqkUJk',
#  'O2jeulWy5JQ',
#  'IIbYWZpQz1E',
#  'oqK0O7O3ezI',
#  'RxE4AkI1TBI',
#  'vMHS0xZWe68',
#  '7RbdAKo13Q8',
#  'CsX3StndYA4',
#  'jSGL3uuJ0PQ',
#  'AJl9sbm42Tk',
#  'DvZGdrH_fpQ',
#  'KbLVaK_VFGI',
#  'NlAj1GrtRr8',
#  '08cz7gG3aNU',
#  'qbWQifJDJ6Y',
#  'JAh0M5laIyg',
#  'DapKunmAXTs',
#  'uphEZ_n8cXw',
#  'IhrJnJX0SEs',
#  'dQwy2xUBB-Y',
#  'w3CQYn6E7Ao',
#  'jOBZ1_zwj5o',
#  'YZyIqlaFghM',
#  '34da-mMDDx8',
#  'uDGIkh8kb6U',
#  'Pl1rkHvvBXY',
#  'feVgzlylMx4',
#  'gMqPtWCNr_E',
#  'jIH8jLOxDBQ',
#  'lbkrE23WN_4',
#  'bRLHovfoRh0',
#  'nOY-HUPRJYE',
#  'UV5w3NA91j4',
#  'MR3ZByO9iwM',
#  'kskIkK0wRO4',
#  'ipRp-wOxOU4',
#  'G3_yFtpgwG4',
#  'eszJTVKMwt8',
#  'JPbdgjQ-1N8',
#  'gwtS3ZYDrD0',
#  'XQPsKHAltY8',
#  'S8GIZ3xvASs',
#  'EEiUqqCIys4',
#  'rnG27HAM1Eg',
#  'C3Gt1jm2iTY',
#  'Y4KL7zMMkFY',
#  'X9mxmfmPJ1s',
#  '5x0GTPpJSQ4',
#  '7PfpqOSa-nw',
#  'a2KiEiS1FUo',
#  'zmS7xrf2DCk',
#  'NdWNlsMrB7Q',
#  '3JF1D_Qo6cI',
#  'oFBFNGowK1E',
#  'XmofCZ6Pabk',
#  'B67NVBkvCyk',
#  'Zy-PDebbYyE',
#  'MtwuubKbAfE',
#  '23K8dDAP1Vs',
#  'GCfG9QAPrWY',
#  'Un4v1T1ad98',
#  'MZMA91mFhmI',
#  'i0evLRCA0rw',
#  'q-EOtqwt7Xk',
#  '9MudKrwJW6s',
#  '1n8NZbS7U10',
#  '4YF2W0-bEgU',
#  'MrS6eVpdP3c',
#  '7B5AwELCTmo',
#  'hKr9OE4-7zo',
#  'Al1G7npR13Q',
#  'DIcfOVxxdDw',
#  'IzkcrgeIHf8',
#  'hukOMv4sBHw',
#  'xzSP82PVIDU',
#  'J6dcpjbVfIY',
#  'vg5z8J--PGY',
#  'uudZozN4oUU',
#  'TURBJuFkRYE',
#  'fDcxBfKJKtQ',
#  'k7xAf0rBI9I',
#  'E17gw766DDw',
#  '5joOQqS0xi0',
#  '5UyFqvGSfik',
#  '_wRYX21jEyo',
#  'kutWS_xo2rc',
#  '9yfBKIAOVbU',
#  'o-HjZHmAS3Q',
#  'rRlIab63sHg',
#  'n_Ewm286nZQ',
#  'CpCTQ0wlZ0I',
#  'uZz1RVRItWY',
#  'R2VX2fnWSNY',
#  'Y-_s4lrUWNQ',
#  'wO0THrkHjdQ',
#  'or_Pgm-LZPQ',
#  '2BiIveaeWPs',
#  'iJN3HlERBT0',
#  'cIVTJgKmO9U',
#  'sQyBCVbyDxY',
#  'GwzlKVfsO8U',
#  'WNfIzxyob2k',
#  'uSnXEqaLrAA',
#  'R8bebeVQx74',
#  'TMsYhDcwp1E',
#  'mxd5TNjfTp4',
#  'zipFwZXBFUY',
#  'qYDTy-AVQK8',
#  '0IJAT9ddNbg',
#  'Qgm4XpOkc3U',
#  'woEwISxiwi0',
#  'sim6vQ4v1kg',
#  'EIrmOyDwQDQ',
#  'VhWF-IZGDFI',
#  'fLuGhY8SO-U',
#  '-pkqcymGaAU',
#  'CYUukvltMC8',
#  'eUAahLymOyk',
#  'nchvOumXDyM',
#  'SEh-cf2z0fk',
#  'pkjBldQ39ok',
#  'DVHcU_f2Glg',
#  'EhloVIqbKgk',
#  'p6blgUxTxgg',
#  'H-2jvaHjRRc',
#  'u5cRkZ38i3w',
#  'e84EPgK2BPQ',
#  'WqFTmKCbKdE',
#  'aUoF69nxOKU',
#  '9PGYEZLyY0Q',
#  'yXvgX8yRB4w',
#  'uVs5Npz-FWk',
#  'TszbU2TeQMM',
#  'hb_BM_MVkxg',
#  'nVmJBh3-DLQ',
#  '6wsmENQG6r8',
#  '-16e2BT9uig',
#  '-roKpCyi4-U',
#  'IBVE06AW9Vs',
#  '_mOIQMMdyjM',
#  'SY7k1mDwpeg',
#  'AsqXZ8ZQTd8',
#  'kmXWSoXDY9s',
#  'Lf0sA0Ar55k',
#  'PLYnUPsLPOc',
#  'xzz7zSBJSDk',
#  'prWVzf9WmNs',
#  'Ar2HrCl6c2w',
#  'I9MGgBsSWwk',
#  'pDC-0bihW2E',
#  'WMjfCD7ua1w',
#  'Cgx5Ue_Y6_4',
#  'mRKpumg1q5A',
#  'n-hOexiKUds',
#  '1wo_8vQ96XQ',
#  'ZhBMwf1mcMw',
#  '0NEIl-XhIpY',
#  'oGXV3x7tPb0',
#  'DkuYJ26Cr8E',
#  '3xq-xoRlu74',
#  'qA97ae8sXMY',
#  'uCN388MabTk',
#  '8y-3Qt3z_2Q',
#  'HkGo5eNeO8U',
#  'qJv26WW3CvQ',
#  'Omy-BQe_-iM',
#  '0SEh98ysmkc',
#  'Pizxi6x70VM',
#  '2lW8hGbX1M8',
#  'cQ_UrUtUKrM',
#  '52Ij4lPyjF4',
#  'O8fdY6GYZaU',
#  'tlQlAmqJdm4',
#  'ntoqcc1IPw0',
#  'mbEHsVSs_-o',
#  'XycTYZK-DR4',
#  'I0wEpoOMxYQ',
#  'LAGsiojVw5k',
#  'IzS9ZKsLJ64',
#  '2qGqgJtsxjk',
#  'H16O7kJhjVU',
#  '8yyqKptIhtE',
#  'sRiCktusG4U',
#  '-8dgjGUBJYw',
#  '3wV-0ztkG30',
#  'CiqWnqyYfaM',
#  'nsmWjs3kE-o',
#  'v2Ze2Wtpeuk',
#  'A39viqE6GFE',
#  '9eR8UPMGtWs',
#  'C79hO52CKDY',
#  'ML0ATGnNuCs',
#  'BJzjCll8ei8',
#  'fgxYhzJS6yg',
#  'yeGMzz2aDCc',
#  '3F65JFyeu3g',
#  '_iH0S_f4vBI',
#  'qm8hj4EVNjw',
#  'vfMhLdbph_U',
#  'X98GMDkf7Q8',
#  'cCxmP12M5gA',
#  'uqgab8lmgow',
#  'hUuS0ucce50',
#  'RtARtt4rVbA',
#  'l3zvV5ZX1yY',
#  'FeZCLbMSK5c',
#  'FbdDn5rBbGs',
#  '8BnKcjSCGI4',
#  'ONiQ-yoGui8',
#  '5P92_SBXCac',
#  'mK_pLfWudR8',
#  'qLcsD6fWrxE',
#  'HvQu3xfZuA8',
#  'ZoxgFOB_pOM',
#  'k2aP5gpovh0',
#  'j3MDQIEnS4Y',
#  'pd0zQKEXU5Q',
#  'ARQ1N9EI7eA',
#  'Uri4lw549aU',
#  'ES9cWAX6a-g',
#  'QHWQmNWGlDM',
#  'D-jihgef1uM',
#  'tFVIkcMGEe0',
#  '5BAav9_qiIE',
#  'XYtGnGt1D4Q',
#  'cCCGVe4apkk',
#  'tfvPypljzWA',
#  'oeIYbRxa810',
#  'VdnCUvCENRQ',
#  'rdG4t4ZT8ZI',
#  'y24j5V50ADE',
#  'xU7sihPTiMk',
#  'xlV2dtpfE5c',
#  'joybBI1XhdY',
#  'aAIHg6A9cEo',
#  'D0kW6cyYZis',
#  'jgjKTCXasCA',
#  'cn0y6NTKXX4',
#  'ICHqJOFPxpc',
#  'BJ0YAOx-kYY',
#  'WltRT38uyRM',
#  'bx-bjnxSjFU',
#  '-emvUS7i3Us',
#  'Dz_gote8VXg',
#  '3_3uipNZzjw',
#  'PXQDLiiXEBU',
#  'YJy8uRxWo8g',
#  '9xQtEgTVUz8',
#  'uVOX2oDkJ9k',
#  'ypn807dfCj0',
#  'TPzsOkDJU5c',
#  'i5JPd9M_hUQ',
#  'T9EOzcySGaU',
#  'y6bgLJaAtbA',
#  'Fu7viVGu9KI',
#  'ElQOiTJM-0k',
#  'GgCqH5wn6NU',
#  '0GqFmqsdEBo',
#  'nU5NcvZYxgk',
#  '3oyO9ffIVjw',
#  '0rf9fVRvWPU',
#  'O6TeLbkZCF8',
#  'mIZtigsoqeI',
#  'ablmm_JpVXs',
#  '7EvZ9OtNpJA',
#  'VmuITZZPgsE',
#  'm3aWLpOiEk8',
#  'dWcxRmPGhJQ',
#  'L5pbHs2PXvc',
#  'FjPImi7LYZc',
#  'rHruDYBxXQc',
#  'c1bgqpeQ_2g',
#  'grTjeO8c6Kw',
#  'xH5gAH2ZNkY',
#  'qXSXkjcRp8E',
#  'joGsF4OLFKU',
#  'icOCgML_be0',
#  'G3zmh4it0Ok',
#  'GVyzrcMqZRg',
#  'P_i0HICXYMg',
#  'p76KcWRHrGY',
#  'X5OGYZHEDe4',
#  'tt-Yr-JHpLs',
#  '5VpZLTMqUk0',
#  'NSapKgDKnU8',
#  'cop92Dc1R6s',
#  'zK4UcmN_iw0',
#  'sESsuA8k2C4',
#  'ghtgDHjzquc',
#  'yUzy0GGRN9g',
#  'a8yxZOWUlpw',
#  '08VTidiK5h8',
#  'pLRfXQoEa4g',
#  'MTzDjH3ybUQ',
#  'n1Ej6qLz_bc',
#  'WFTzBqNF37g',
#  'mopyNwcPt38',
#  'cbGz9XR10PI',
#  'N7TReqdgw0Q',
#  'ZtdCQnUCFvs',
#  'VdZX7OAzgSc',
#  'OWJwlrj2CzA',
#  'Mw6-3MH7Nv8',
#  '4uTwgsNi-TQ',
#  'kf8xVTfuSTc',
#  'ENUitandaaY',
#  'q5H5sJ_kfWo',
#  'IS_xoFMJxFI',
#  'ug4Au8K_3pA',
#  'eGX62Qwz5zA',
#  'hyLglAZSAR8',
#  'CKKM89PhrnU',
#  'y0IhSIYNZTA',
#  '3tUcyy883T0',
#  '0OtAVY7PuDc',
#  'CzW8bpsozfA',
#  'RKRZ2HiGuPc',
#  'nrsGcwuBDdU',
#  'brGqB2b-J90',
#  'R8pIWvYZj48',
#  'VOJ9e57_FlM',
#  'Hcbeg5dQ_xM',
#  'JRQiX0MvzJc',
#  'tdEid6IC94c',
#  'yi759FlETkk',
#  'l98xf8ThTas',
#  'ShX5Dk2uTvE',
#  'bh1cnA_VPW8',
#  'gyUxxtksOfM',
#  'Mrg13JGEWnw',
#  '3NArOSiy7Qg',
#  'YgjXXmNwWuY',
#  'h6A_jmI8kNU',
#  'Z1zHFPUpCAg',
#  'MSltsGzuP1I',
#  'ZtoIC1fXjWc',
#  'P5fQAbxNYSM',
#  'APMvN34QJ-c',
#  'oW768Fj-YxA',
#  'dhx9B4QMF8Q',
#  'Z4Z0QJWlWrQ',
#  'fPuTxncilq0',
#  'oWLOBKa5gAI',
#  '-jHYI1udHw0',
#  'xC1AEhPHH2E',
#  'HpyoLx3ocQw',
#  'jL41j9-TkY8',
#  '_302ij48cKg',
#  'K3wI6IB-6Fo',
#  '2_nCbQcZ5K8',
#  'gKgbcOP2jzE',
#  'zaCfPEk1UrM',
#  'mPBk8Xc4Je8',
#  'e_EnTDeoQsg',
#  'Fj6zL1O7ByU',
#  '9L5beqqGr2g',
#  'ooJBupXD-yE',
#  '6_8omObsfgM',
#  '5BydbBQeKXM',
#  'yq0pSurCwzM',
#  'DjlpaTirZL0',
#  'SzqgagqCyC4',
#  'e8_KR72d1KI',
#  'Z5Li83iuQ1s',
#  '1oYaatlD6fg',
#  'qa0TxyNUgE4',
#  'lKKuFviw8kw',
#  'HfMsWu-Fvd8',
#  '7lh0xEFquPk',
#  'SQg2dUxL76s',
#  'FmO5Amh8xB4',
#  'qW0llmsmHQ0',
#  '8ogWAz25XMg',
#  'UA1VWyfJkto',
#  '5_wi2XAQVVc',
#  'MWHF75FEERU',
#  'Je2Nf2G84GA',
#  '54X2YKJ4lms',
#  'UuAK_jJ7tE0',
#  'xI_cH2C08GA',
#  'yr4QcQ5aaYY',
#  'M_XsR9KF3Dk',
#  '8svtVsuigqg',
#  'N0Ntx3Z7vYU',
#  'Yl5q2Ss69Ck',
#  'o3mNxJ9odwc',
#  '6Ag_5GQ4JIs',
#  'NJJS9E7t6gA',
#  'MegWaMWBpL4',
#  'oo8TEDTKqm4',
#  'HBFckT1ntKM',
#  'wDWo4-V31XY',
#  'RotiRfHhDJw',
#  'lhsfvTSX3-g',
#  'e2iH1ychfTc',
#  'YALF_Scl4g0',
#  'HFfBGJiPMvQ',
#  'Pxx-tO601ns',
#  'WlhXnBH1Aqs',
#  'SOlaZjpPpTk',
#  'OLal9NpHwqA',
#  'ioqeerpPQuk',
#  'ogOs8cTN3bU',
#  '379UAqa4SD4',
#  'mESFDYLUDEs',
#  'r0JxpUQqs2E',
#  '5uu3YNwAfb4',
#  'KYV5eoZ3KIA',
#  '69dJR7-dbMQ',
#  '2eEwfuoJdTU',
#  'AAio26t6Tfc',
#  'DRGNXy9R5Qc',
#  'M_uG9lC4OcI',
#  'VaUzJJ-mpn8',
#  'Zh-FK3TJruo',
#  'vldWS5-4gwQ',
#  'CRm6BHeKQ2Y',
#  'ioNYc9y7uqY',
#  'tE3MHgXCoEM']

# %%
# To Collect All Video Details

for video_id in Video_Ids:
    request = youtube.videos().list(
        part = "snippet,contentDetails,statistics",
        id = video_id
    )
    response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'iwUvqb6PjfR9ZEkwNPSZpXU2Vos',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'zKWODrGtOyosvDUUuh2QaR2cf0I',
#    'id': 'tE3MHgXCoEM',
#    'snippet': {'publishedAt': '2014-11-11T09:03:28Z',
#     'channelId': 'UCT8FGLq9AU1H6U3ePhegxJA',
#     'title': 'Mad Stuff with Rob – How to draw an owl | DIY Drawing for children',
#     'description': 'Wanna capture some nocturnal wildlife on paper? Simply use Rob’s Drawsome Awesome steps and learn how drawing an owl can be a hoot. It’s DIY art that may even impress your parents into letting you stay up past your bedtime. \n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tE3MHgXCoEM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tE3MHgXCoEM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tE3MHgXCoEM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/tE3MHgXCoEM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/tE3MHgXCoEM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Mad Stuff With Rob',
#     'tags': ['Mad Rob Pogo',
#      'Creative Create',
#      'How to',
#      'Pogo',
#      'The Best place for kids',
#      'Art Attack',
#      'Step by step',
#      'DIY',
#      'DIY Science',
#      'DIY Art',
#      'DIY Craft',
#      'DIY Projects',
#      'Colors',
#      'Paint',
#      'Brush',
#      'paper',
#      'School',
#      'Teacher',
#      'Homework',
#      'Play',
#      'Fun',
#      'Learning',
#      'Drawing (Interest)',
#      'Do It Yourself (Hobby)',
#      'Painting',
#      'Lesson',
#      'Cartoon Network',
#      'Disney',
#      'Rob’s new channel',
#      'Rob’s youtube channel',
#      'Rob Pogo',
#      'rob new channel',
#      'pogo rob new channel',
#      'mad rob new channel',
#      'mad pogo rob new channel',
#      'Kids art project',
#      'Fun kids activity'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Mad Stuff with Rob – How to draw an owl | DIY Drawing for children',
#      'description': 'Wanna capture some nocturnal wildlife on paper? Simply use Rob’s Drawsome Awesome steps and learn how drawing an owl can be a hoot. It’s DIY art that may even impress your parents into letting you stay up past your bedtime. \n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.'},
#     'defaultAudioLanguage': 'zxx'},
#    'contentDetails': {'duration': 'PT3M16S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '26246',
#     'likeCount': '753',
#     'favoriteCount': '0',
#     'commentCount': '0'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
# Function To Fetch All Video Information Of The Channel

def get_video_info(Video_Ids):
    v_data = []
    for video_id in Video_Ids:
        request = youtube.videos().list(
            part = "snippet,contentDetails,statistics",
            id = video_id
        )
        response = request.execute()

        ## all info

        for item in response["items"]:
            video_data = dict(Channel_Name = item['snippet']['channelTitle'],
                            Channel_ID = item['snippet']['channelId'],
                            Video_Title = item['snippet']['title'],
                            Video_ID = item['id'],
                            Thumbnail = item['snippet']['thumbnails']['default']['url'],
                            Description = item['snippet'].get('description'),
                            Published_Date = item['snippet']['publishedAt'],
                            Tags = item['snippet'].get('tags'),
                            Duration = item['contentDetails']['duration'],
                            Defnination = item['contentDetails']['definition'],
                            Views = item['statistics'].get('viewCount'),
                            Likes = item['statistics'].get('likeCount'),
                            Comment_count = item['statistics'].get('commentCount'),
                            Favourite_count = item['statistics']['favoriteCount'],
                            Like_count = item['statistics'].get('likeCount'),
                            )
            v_data.append(video_data)
    return v_data

# %%
video_details = get_video_info(Video_Ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Superhero Doodles with Uni Pin Fineliners',
#   'Video_ID': 'ieX38it7gFo',
#   'Thumbnail': 'https://i.ytimg.com/vi/ieX38it7gFo/default.jpg',
#   'Description': "Uniball sent me these Uni Pin Fineliners and I decided to test them out. I landed up drawing these comic book characters. Well if you didn't know already comic books have always been my main source of inspiration growing up. Felt great doing it again.  \n.\nIf you would like to get some for yourself then they're giving  a flat 10% discount on Amazon.in at the moment. 👍",
#   'Published_Date': '2023-05-08T06:27:48Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'uniball',
#    'uniballindia',
#    'uniballmitshubishi',
#    'unipinfineliners',
#    'artguyrob',
#    'superheroes'],
#   'Duration': 'PT53S',
#   'Defnination': 'hd',
#   'Views': '247758',
#   'Likes': '18969',
#   'Comment_count': '131',
#   'Favourite_count': '0',
#   'Like_count': '18969'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Tried the new WINDOWS 11 | Cool Features!',
#   'Video_ID': 'WDJrRiI4kJ4',
#   'Thumbnail': 'https://i.ytimg.com/vi/WDJrRiI4kJ4/default.jpg',
#   'Description': "Guys as you can see I got my hands on this super stylish NEW Windows 11 laptop and you can get it too. \n.\nTrust me it's been nothing short of amazing. It looks stylish, it’s fun to draw on, sleek and easy to carry around and the best part is the battery life ✨ I didn't have to carry a charger with me while shooting and creating art on this.\n.\nIt’s also packed with some other great features but don’t take my word for it go check it out yourself. Upgrade to Windows 11 on https://www.amazon.in/stores/page/B30B0A92-0173-40CA-84CE-D3273F6B15AF\n\n*Some features are hardware dependent \n\n#artguyrob #Windows11 #WindowsForCreators #CreateWithoutLimits #CreateWithWindows #Collab #MicrosoftSponsored\n\nDisclaimer: The video is sponsored by Microsoft India",
#   'Published_Date': '2023-02-24T07:59:13Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'windows11',
#    'microsoftwindows 11',
#    'windowsforcreators',
#    'createwithoutlimits',
#    'coolfeatures',
#    'coll features windows11',
#    'cool features',
#    'new features windows 11',
#    'artist',
#    'graphic designer',
#    'windows 11review',
#    'windows 11 review',
#    'artist review'],
#   'Duration': 'PT3M8S',
#   'Defnination': 'hd',
#   'Views': '66270',
#   'Likes': '2642',
#   'Comment_count': '264',
#   'Favourite_count': '0',
#   'Like_count': '2642'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'I did the #ManikeMove with @NoraFatehi, sort of 😎 #Shorts @YouTubeIndia',
#   'Video_ID': 'uMeAQ4pO_dI',
#   'Thumbnail': 'https://i.ytimg.com/vi/uMeAQ4pO_dI/default.jpg',
#   'Description': 'Even my illustrations can’t resist doing the #ManikeMove  challenge. \n\nAap bhi karo, only on #Shorts ! #Ad',
#   'Published_Date': '2022-10-07T06:39:56Z',
#   'Tags': None,
#   'Duration': 'PT21S',
#   'Defnination': 'hd',
#   'Views': '193861',
#   'Likes': '13632',
#   'Comment_count': '145',
#   'Favourite_count': '0',
#   'Like_count': '13632'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Comment 😎 if you got it before reveal, 😳 if you didn’t!   #ad',
#   'Video_ID': 'df3regswjQI',
#   'Thumbnail': 'https://i.ytimg.com/vi/df3regswjQI/default.jpg',
#   'Description': '',
#   'Published_Date': '2022-08-30T06:04:43Z',
#   'Tags': None,
#   'Duration': 'PT22S',
#   'Defnination': 'hd',
#   'Views': '158626',
#   'Likes': '5865',
#   'Comment_count': '113',
#   'Favourite_count': '0',
#   'Like_count': '5865'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'MAGIC LOOP TUTORIAL | How To Make A Infinite Loop Video | In Hindi',
#   'Video_ID': 'WzjdkcFjEaY',
#   'Thumbnail': 'https://i.ytimg.com/vi/WzjdkcFjEaY/default.jpg',
#   'Description': "First 1000 people to click on this link will get 30% off on the Skillshare Annual Membership. Here's the link: https://skl.sh/madstuffwithrob05221\nI'm so thrilled to share my Skillshare Original class with you guys. In this class I teach you how to make Incredible videos and make money from your own content. Whether you just started making videos or you want to increase your reach, this class is for DIGITAL CONTENT CREATORS of all kinds. Join Now and do let me know if it was helpful or not.\n.\nAlso this  video is the EASIEST and BEST Tutorial to make a PERFECT LOOP. As most of you know that majority of my REELS on Instagram are an infinite loop and you often ask me how I do it. So here you go!!! Honestly its super simple to do and if you watch the video even you'll know the TRICK to make a perfect one.\nAnd your videos and Reels will definitely become more interesting with this simple hack, so do try it. \n.\nAnd if you like the video and found the tutorial helpful then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment.\nIt makes me happy ☺\n\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/artguyrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified! \n\n#PerfectLoop #Tutorial #madstuffwithrob",
#   'Published_Date': '2022-05-16T10:33:32Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'perfect loop',
#    'infinte loop',
#    'tutorial',
#    'infinte loop tutorial',
#    'perfect loop tutorial',
#    'seamless loop',
#    'seamless loop tutorial',
#    'looping video',
#    'looping video tutorial',
#    'artguy rob',
#    'art guy rob',
#    'Art Guy Rob',
#    'Art Rob',
#    'Artist Rob',
#    'Pogo Artist',
#    'POGO ARTIST Rob',
#    'POGO artist Rob',
#    'POGO Rob',
#    'Art Guy',
#    'Perfect loop DIY',
#    'How to make loop video',
#    'How to make a looping video',
#    'How to make perfect loop video',
#    'how to make infinite loop video'],
#   'Duration': 'PT10M12S',
#   'Defnination': 'hd',
#   'Views': '150738',
#   'Likes': '7692',
#   'Comment_count': '405',
#   'Favourite_count': '0',
#   'Like_count': '7692'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Can this Cardboard Bird fly? | HOW TO MAKE | In Hindi',
#   'Video_ID': 'tV-yBLmJgw0',
#   'Thumbnail': 'https://i.ytimg.com/vi/tV-yBLmJgw0/default.jpg',
#   'Description': "Guys here's how you can make a Cardboard Bird at HOME that can fly. Well, almost!  So a while back I had posted a REEL on Instagram with this bird automata toy and all of you asked me to teach you guys how to make it.\nSo here's a SIMPLE METHOD to make this at home with just some cardboard and a few basic tools. How amazing is that!! \n.\nYou can also use the technique to make other flying creatures like bats and dragons. Honestly! It looks amazing and doesn't take too long to make it. \n.\nMake one for yourself or surprise a friend with it :) Do try it!! \n.\nAnd if you like the video and found the tutorial helpful then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment.\nIt makes me happy ☺\n\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/artguyrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified! \n\n#madstuffwithrob #flyingbirdtoy #diy",
#   'Published_Date': '2022-04-28T05:22:16Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'bird toy',
#    'automata',
#    'bird automata',
#    'cardboard bird toy',
#    'toy',
#    'easy hack',
#    'best out of waste',
#    'cardboard diy',
#    'carboard toy',
#    'carboard hacks',
#    'simple hacks',
#    'cardboard project'],
#   'Duration': 'PT11M21S',
#   'Defnination': 'hd',
#   'Views': '457346',
#   'Likes': '22616',
#   'Comment_count': '677',
#   'Favourite_count': '0',
#   'Like_count': '22616'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Happy Republic Day 🇮🇳   | YT SHORTS',
#   'Video_ID': 'AfXZxknpp70',
#   'Thumbnail': 'https://i.ytimg.com/vi/AfXZxknpp70/default.jpg',
#   'Description': 'UNITED WE STAND and TOGETHER WE CAN WIN ✨\nThat’s all we need to realize, understand and believe in. We are all equal no matter what caste, religion or creed. So we need to respect each other and support one another only then we can move forward and grow.\n.\nAs the Youth, you are the country’s future so let’s pledge to love each other and work towards building our nation without differences, negativity and hate.\nComment JAI HIND if you agree with me 👇  Also share the positive message with everyone you know. \n\n#MadStuffWithRob #RepublicDay #YouTubeShorts',
#   'Published_Date': '2022-01-26T06:03:53Z',
#   'Tags': ['Mad Stuff With Rob',
#    'Art Guy Rob',
#    'Rob pogo',
#    'Art guy Rob',
#    'Rob Pogo MAD',
#    'Rob MAD',
#    'Art Rob MAD',
#    'Artist Rob MAD',
#    'Artist Rob POGO',
#    'Republic day',
#    'Happy Republic Day',
#    'Republic Day India',
#    'Simple Art',
#    'DIY',
#    'DIY ideas',
#    'Cool hacks',
#    'Cool ideas',
#    'Fun diy ideas',
#    'republic day project',
#    'Republic day DIY',
#    'Simple DIY',
#    'Colouring ideas',
#    'ideas to paint'],
#   'Duration': 'PT19S',
#   'Defnination': 'hd',
#   'Views': '3788096',
#   'Likes': '116137',
#   'Comment_count': '1220',
#   'Favourite_count': '0',
#   'Like_count': '116137'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': "DREAMS DON'T WORK UNLESS YOU DO | SHORTS",
#   'Video_ID': 'WEgYQZizohY',
#   'Thumbnail': 'https://i.ytimg.com/vi/WEgYQZizohY/default.jpg',
#   'Description': 'Dream big but don’t sleep on them because the only way to achieve them is to put them in action. \nIf you have big dreams then you need to work hard and smart. \nTrust me when you see your dreams becoming a reality, it’s the best feeling ever. ✨\n.\nWhat are your BIG DREAMS?  Let me know in the comments⚡️\n.\n#madstuffwithrob #robkagyan #Shorts',
#   'Published_Date': '2022-01-25T14:40:14Z',
#   'Tags': ['mad stuff with rob',
#    'Rob pogo',
#    'rob artist mad',
#    'rob mad',
#    'motivation',
#    'art guy rob',
#    'artist rob',
#    'rob ka gyan'],
#   'Duration': 'PT19S',
#   'Defnination': 'hd',
#   'Views': '213932',
#   'Likes': '11889',
#   'Comment_count': '99',
#   'Favourite_count': '0',
#   'Like_count': '11889'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'YASHRAJ MUKHATE challenged me! | I made a MEME SONG',
#   'Video_ID': 'duFBMPfk_Ng',
#   'Thumbnail': 'https://i.ytimg.com/vi/duFBMPfk_Ng/default.jpg',
#   'Description': "Yashraj Mukhate challeneged me to make a MEME song so i put the NEW ASUS PRO ART STUDIOBOOK to the test and created one.\nDo hear it and RANK ME from 1-10 in the comments below.\nI really hope you guy like it.\n\nCreativity can’t wait! Hence don't miss your next source of inspiration and #CreateTheUncreated with a brand new ASUS creators’ series lineup of #ProArt #StudioBook & #VivoBookPro OLED laptops.\n\nKnow more at https://asus.in/createtheuncreated/ \n\n\n#ASUSIndia #CreateTheUncreated #OLED #ASUSOLED #CreatorSeries #ProCreators #ASUSOLED",
#   'Published_Date': '2021-12-14T12:47:12Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'ASUS',
#    'ASUS India',
#    'ASUS laptop',
#    'ASUS laptops',
#    'proart studiobook',
#    'ASUS studiobook',
#    'art guy rob',
#    'yashraj mukhate',
#    'meme song',
#    'meme songs',
#    'Asus Pro Art'],
#   'Duration': 'PT13M9S',
#   'Defnination': 'hd',
#   'Views': '139767',
#   'Likes': '10267',
#   'Comment_count': '630',
#   'Favourite_count': '0',
#   'Like_count': '10267'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'WHAT IS THE SECRET?',
#   'Video_ID': 'KQyAPIGLmU0',
#   'Thumbnail': 'https://i.ytimg.com/vi/KQyAPIGLmU0/default.jpg',
#   'Description': "Haven't done a live in so long and thought today is the perfect day to do it!",
#   'Published_Date': '2021-11-19T13:17:07Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT27M47S',
#   'Defnination': 'hd',
#   'Views': '51275',
#   'Likes': '3172',
#   'Comment_count': '188',
#   'Favourite_count': '0',
#   'Like_count': '3172'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'LAST MIN. DIWALI DECOR IDEA | DIY Paper Lamp | In Hindi',
#   'Video_ID': 'VLiYnallEh0',
#   'Thumbnail': 'https://i.ytimg.com/vi/VLiYnallEh0/default.jpg',
#   'Description': "Here’s a LAST MINUTE DIY DIWALI DÉCOR idea. An origami lamp made out of paper. This is inspired by guoguo6611. Thanks to some of my followers who shared that video with me. I'm glad I tried it and love how it turned out. Super happy with it! Hope you like it too.\n\n\r\rIt’s a VERY EASY TECHNIQUE and just with few folds and scoring you can turn a piece of paper into an awesome looking lamp. How amazing is that!! The great thing is that the design is versatile; you can place it on the table or hang it with ferry lights. It’ll looks great either way. So do try it! \r\r\n\nMake it for your home or surprise a friend with it :) They will love it!! And if you like the video and found the tutorial helpful then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment. It makes me happy ☺ \n\n\r\rDon't forget to tag me on my social media when you upload pictures of your art: Instagram – \nhttps://www.instagram.com/artguyrob/ https://www.instagram.com/robinthehoodofficial/ \nFacebook - @artguyrob \n\nDo hit the bell icon to stay notified!\n\n #madstuffwithrob #diwalidecor #diypaperlamp",
#   'Published_Date': '2021-11-03T11:24:05Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'diwali decor',
#    'diwali lamp',
#    'diwali lamp ideas',
#    'diy diwali lamp',
#    'diy paper lamp',
#    'diy',
#    'paper lamp',
#    'origami lamp',
#    'easy paper lamp',
#    'easy diy',
#    'quick hack',
#    'easy hack',
#    'easy lamp idea',
#    'diwali decoration',
#    'diwali decoration idea',
#    'diwali kandeel',
#    'art guy rob',
#    'rob pogo',
#    'rob artist',
#    'super easy lamp',
#    'diy lamp',
#    'lamp diy',
#    'last minute decor ideas',
#    'home decor',
#    'home decor ideas',
#    'home decor lmap',
#    'last minute diwali decor',
#    'papercraft'],
#   'Duration': 'PT9M14S',
#   'Defnination': 'hd',
#   'Views': '131217',
#   'Likes': '9275',
#   'Comment_count': '888',
#   'Favourite_count': '0',
#   'Like_count': '9275'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'How to make SQUID GAME MASK with PAPER | DIY |  In Hindi | Easy Tutorial',
#   'Video_ID': 'wjJxGiknA_I',
#   'Thumbnail': 'https://i.ytimg.com/vi/wjJxGiknA_I/default.jpg',
#   'Description': "Guys here's how you can make the SQUID GAME MASK at HOME with paper. Ever since I saw the show I wanted to create something related to the it. And when I posted a REEL on Instagram dressed up like one of the soldiers from SQUID GAME all of you asked me to teach you guys how to make that MASK.\nSo here's a VERY EASY METHOD to make this at home with just paper and few basic tools. How amazing is that!! \n.\nYou can also use the technique to make masks of other halloween characters or your favorite superheroes. Honestly! It looks amazing and doesn't take too long to make it. \n.\nMake one for yourself or surprise a friend with it :) Do try it!! \n.\nAnd if you like the video and found the tutorial helpful then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment.\nIt makes me happy ☺\n\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/artguyrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified! \n\n#madstuffwithrob #squidgame #diymask",
#   'Published_Date': '2021-10-29T18:51:20Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'artguyrob',
#    'squidgame',
#    'how to make squid game mask',
#    'diy squid game mask',
#    'squid game mask diy',
#    'make squid game mask at home',
#    'squid game mask tutorial',
#    'squid game mask with paper',
#    'easy to do squid game mask',
#    'easy squid game mask',
#    'squid game mask netflix',
#    'easy diy mask',
#    'paper mask',
#    'paper mask diy',
#    'squid game paper mask diy',
#    'squid game mask hack',
#    'easy hack',
#    'mask tutorial',
#    'diy'],
#   'Duration': 'PT8M28S',
#   'Defnination': 'hd',
#   'Views': '757155',
#   'Likes': '12716',
#   'Comment_count': '1254',
#   'Favourite_count': '0',
#   'Like_count': '12716'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'AM I QUITTING YOUTUBE?',
#   'Video_ID': '0efzC1BVim4',
#   'Thumbnail': 'https://i.ytimg.com/vi/0efzC1BVim4/default.jpg',
#   'Description': 'Join me to as I update you guys about the future of this channel.',
#   'Published_Date': '2021-06-23T12:54:01Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT19M36S',
#   'Defnination': 'hd',
#   'Views': '234976',
#   'Likes': '11806',
#   'Comment_count': '1684',
#   'Favourite_count': '0',
#   'Like_count': '11806'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'How to make a NEON SIGN at home | NEON LIGHTS | in Hindi | DIY',
#   'Video_ID': 'tzy2UYOP4Z0',
#   'Thumbnail': 'https://i.ytimg.com/vi/tzy2UYOP4Z0/default.jpg',
#   'Description': "Guys here's a simple HACK to make a NEON SIGN at HOME with very basic materials. Everyone loves NEON LIGHTS because they can add a lot of character and vibe to your space. Since I know most of you are home bound, here's a cool technique to make this with materials lying at home. How amazing is that!! \n.\nYou can use the technique to make a NEON SIGN of you favorite Game, Car, Bike or Superhero LOGO. Or simply make one of your favorite quote or word like i did. It looks amazing and doesn't take too long to make it. \n.\nMake one for your self, a friend or your family :) Do try it!! \n.\nAnd if you like the video and found the tutorial helpful then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment.\nIt makes me happy ☺\n\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/madstuffwithrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified!\n\n#madstuffwithrob #neonsign #neonlights",
#   'Published_Date': '2021-04-23T12:05:37Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'neon lights',
#    'how to make a neon sign',
#    'make a neon sign',
#    'simple hack',
#    'easy neon sign',
#    'how to draw a neon sign',
#    'how to make neon signs at home',
#    'how to make a neon sign board',
#    'draw neon lights',
#    'draw neon sign',
#    'rob pogo',
#    'rob mad pogo',
#    'pogo guy',
#    'how to draw a glow',
#    'how to darw a glow sign',
#    'drawing neon lights',
#    'drawing neon sign',
#    'neon sign hacks',
#    'easy diy',
#    'cheap neon sign',
#    'neon sign',
#    'neon glow',
#    'glow sign',
#    'easy glow sign',
#    'glow'],
#   'Duration': 'PT7M22S',
#   'Defnination': 'hd',
#   'Views': '1576969',
#   'Likes': '96223',
#   'Comment_count': '3657',
#   'Favourite_count': '0',
#   'Like_count': '96223'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'The Hitman Rohit Sharma | Mumbai Indians | Tape Art | Cricket',
#   'Video_ID': 'UpGv1i4mKWs',
#   'Thumbnail': 'https://i.ytimg.com/vi/UpGv1i4mKWs/default.jpg',
#   'Description': "Guys here's a crazy Tape Art I tried of Rohit Sharma, the HIT MAN of our Indian Cricket team. Its a really cool technique and the magic happens when I put a light source behind the artwork. It just comes alive!! \n.\nDo give it a watch if you are a Fan of Cricket and of Rohit Sharma. I will really appreciate if you guys leave a nice comment if you appreciate what i did here and also HIT that LIKE button if you enjoyed watching this. Also do let me know who should i make next. Or if you want me to make a tutorial of this.\nlooking forward to read all your comments. \n.\nAnd if you like the video and found it entertaining then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment.\nIt makes me happy ☺\n\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/madstuffwithrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified!\n\n#madstuffwithrob #rohitsharma #cricket",
#   'Published_Date': '2021-04-18T04:00:06Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'tape art',
#    'tape art ideas',
#    'tape artwork',
#    'tape art paintings',
#    'tape art and craft',
#    'the hitman',
#    'hitman Rohit Sharma',
#    'Rohit Sharma',
#    'Cricketer',
#    'cricket',
#    'mumbai',
#    'mumbai indians',
#    'ipl',
#    'cricket match',
#    'IPL match',
#    'IPL matches',
#    'IPL Rohit',
#    'IPL Rohit Sharma',
#    'Mumbai Indians Rohit Sharma',
#    'Mumbai Indians Captian',
#    'IPL',
#    'Best Cricketer',
#    'Mad Rob',
#    'Pogo Rob',
#    'Tape Hacks',
#    'Hacks',
#    'Tape art portrait',
#    'portrait',
#    'Rohit Sharma Portrait',
#    'Art',
#    'Rohit Sharma Fanart'],
#   'Duration': 'PT1M23S',
#   'Defnination': 'hd',
#   'Views': '116605',
#   'Likes': '8128',
#   'Comment_count': '596',
#   'Favourite_count': '0',
#   'Like_count': '8128'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Among Us #Shorts #BackToBasics',
#   'Video_ID': 'Zg31pJpNsWA',
#   'Thumbnail': 'https://i.ytimg.com/vi/Zg31pJpNsWA/default.jpg',
#   'Description': 'You can now make a super cool Among Us Lamp in a very inexpensive way. Have you checked the DIY yet?  \n\n#MadStuffWithRob',
#   'Published_Date': '2021-03-26T10:45:30Z',
#   'Tags': None,
#   'Duration': 'PT30S',
#   'Defnination': 'hd',
#   'Views': '244428',
#   'Likes': '10910',
#   'Comment_count': '471',
#   'Favourite_count': '0',
#   'Like_count': '10910'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': "Don't Stop Until You Are Proud! #Shorts #BackToBasic",
#   'Video_ID': '8t6KDsX2Sa8',
#   'Thumbnail': 'https://i.ytimg.com/vi/8t6KDsX2Sa8/default.jpg',
#   'Description': "If you enjoyed watching this then please like, share and comment. Also, if you are new don't forget to subscribe.",
#   'Published_Date': '2021-03-26T09:52:25Z',
#   'Tags': None,
#   'Duration': 'PT30S',
#   'Defnination': 'hd',
#   'Views': '295807',
#   'Likes': '13585',
#   'Comment_count': '351',
#   'Favourite_count': '0',
#   'Like_count': '13585'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'PRINT with COKE | Printing hacks | DIY | In Hindi',
#   'Video_ID': 'lYSsaGDSg2o',
#   'Thumbnail': 'https://i.ytimg.com/vi/lYSsaGDSg2o/default.jpg',
#   'Description': "Guys here's a simple HACK to PRINT your ART with COKE (and some other basic materials lying at HOME). Also i need to mention that we are using FLAT COKE, that has no fizz. So many times after parties you have Coke lying at home that has gone flat that you don't want to drink. Well, now you can print with it. How amazing is that!! \n.\nNow you can print your drawings, doodles or even your favorite pictures on paper or even a T-shirt or bag by just using some Coke and regular aluminium foil. Sounds crazy but it works as you can see in this video. \nI was super happy with the results and amazed to see how simple it is. \n.\nThe best thing is that it’s inexpensive and you can take multiple prints using this technique :) Do try it!! \n.\nAnd if you like the video and found the tutorial helpful then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment.\nIt makes me happy ☺\n\n\r\rHere’s the MATERIAL LIST of todays DIY PROJECT\r\n\n•Coke\n•Glass marker pencil or wax crayons\n\r•Aluminium Foil\n•Acrylic sheet/plexiglass/glass - any smooth surface\n\r•Water\n•Sponge and old rags\n\r•Roller and printing Ink\r\n\n\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/madstuffwithrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified!\n\n#madstuffwithrob #printwithcoke #Printathome",
#   'Published_Date': '2021-03-24T12:44:56Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'coke',
#    'how to print',
#    'how to print on paper',
#    'printinghacks',
#    'printing hacks',
#    'howtoprint',
#    'printing technique',
#    'lithography',
#    'kitchen lithography',
#    'kitchen litho',
#    'how to do kitchen lithography',
#    'how to print at home',
#    'diy printing',
#    'how to print on a tshirt',
#    'how to print on a bag',
#    'simple printing technique',
#    'simple printing hack',
#    'Rob',
#    'Rob pogo',
#    'Rob Mad',
#    'Rob mad pogo',
#    'printing with coke',
#    'print with coke',
#    'cool hack',
#    'cool hacks',
#    'simple hacks'],
#   'Duration': 'PT10M48S',
#   'Defnination': 'hd',
#   'Views': '323624',
#   'Likes': '18554',
#   'Comment_count': '1099',
#   'Favourite_count': '0',
#   'Like_count': '18554'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Trills of Speed #Shorts #BackToBasics',
#   'Video_ID': 'Zb21vAf5GfA',
#   'Thumbnail': 'https://i.ytimg.com/vi/Zb21vAf5GfA/default.jpg',
#   'Description': '',
#   'Published_Date': '2021-03-19T10:27:43Z',
#   'Tags': None,
#   'Duration': 'PT30S',
#   'Defnination': 'hd',
#   'Views': '155794',
#   'Likes': '8676',
#   'Comment_count': '233',
#   'Favourite_count': '0',
#   'Like_count': '8676'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Be Water, My Friend #Shorts #BackToBasics',
#   'Video_ID': 'lM_Sk8biVco',
#   'Thumbnail': 'https://i.ytimg.com/vi/lM_Sk8biVco/default.jpg',
#   'Description': 'Be fluid, flexible, and spontaneous. Be ready to adapt to certain situations, change and grow.\n.\nThis philosophy of BRUCE LEE is so simple yet so powerful. It basically encourages you to be more adjusting, be ever ready and be fearless. Imagine if we all could be like water.\n.\nIf you enjoyed watching this then pls LIKE and SHARE. Also check out other fun REELS on my page.\n.\n#madstuffwithrob\n#easydiy #brucelee #paints #belikewater #painting #art #artist #artistoninstagram #canvasart #robkagyan',
#   'Published_Date': '2021-03-19T08:36:41Z',
#   'Tags': None,
#   'Duration': 'PT30S',
#   'Defnination': 'hd',
#   'Views': '225801',
#   'Likes': '14975',
#   'Comment_count': '346',
#   'Favourite_count': '0',
#   'Like_count': '14975'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': "Here's one for VIRAT KOHLI Fans. Yenjoy! #Shorts #BackToBasics",
#   'Video_ID': 'i6b1zU0Gcio',
#   'Thumbnail': 'https://i.ytimg.com/vi/i6b1zU0Gcio/default.jpg',
#   'Description': 'Congratulations @virat.kohli for setting yet another record of becoming the first cricketer to cross a 100M followers on Instagram. Thanks for inspiring a whole generation.⚡️\n.\nCongratulate him in the comments below 👇 for recording yet another century and do TAG HIM and share this with other Virat or Cricket fans 👏',
#   'Published_Date': '2021-03-18T09:43:30Z',
#   'Tags': None,
#   'Duration': 'PT29S',
#   'Defnination': 'hd',
#   'Views': '16356526',
#   'Likes': '614338',
#   'Comment_count': '2500',
#   'Favourite_count': '0',
#   'Like_count': '614338'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Are you suffering from an IMPOSTER syndrome? #Shorts #BackToBasics',
#   'Video_ID': 'yIBx3HFweyc',
#   'Thumbnail': 'https://i.ytimg.com/vi/yIBx3HFweyc/default.jpg',
#   'Description': "Don't know what it is?\nTo put it simply, Impostor syndrome refers to an internal experience of believing that you are not as competent as others perceive you to be and that you succeeded due to luck and not due to your talent or qualifications.\n.\nEveryone is trying to be that somebody in life and for that at times you’ll need to act brave, be strong or intelligent and work hard, very hard. And if you succeed then always remember that your success is not always luck! It can never be. Luck can you to a point but hard work will keep you there.\n.\nIt's ok to experience moments of doubts at times but don't let that over come you. So next time, take that compliment, chin up and know that you deserve it cause your worked hard for it.\n.\nIf you enjoyed watching this then pls LIKE and SHARE. Also check out other fun REELS on my page.\n.\n#madstuffwithrob #happynewyear\n#reelkarofeelkaro #reelsinstagram #reelsoninstagram #stopmotion #stopmotionanimation #stopmotionvideo #stopmotionvideos #animation #animationvideo #animationvideos #animate #animated #animator #animator #robkagyan #amongus #amongusart #amongusdiy #amongusimpostor #amongusanimation #amongusdeadbody #amongusdead #amonguscrew",
#   'Published_Date': '2021-03-18T08:36:12Z',
#   'Tags': None,
#   'Duration': 'PT31S',
#   'Defnination': 'hd',
#   'Views': '186850',
#   'Likes': '9663',
#   'Comment_count': '346',
#   'Favourite_count': '0',
#   'Like_count': '9663'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Building a NEW HOUSE and STUDIO in GOA',
#   'Video_ID': '5XP1ivrFit4',
#   'Thumbnail': 'https://i.ytimg.com/vi/5XP1ivrFit4/default.jpg',
#   'Description': 'It was my dream to build a house in Goa and finally its happening. Constructing a brand new studio space as well. Was planning this for very long and now this dream on mine is becoming a reality.\nJust wanted share this good news with you guys and UPDATE you guys on what happening.\n\nSo lets chat!!!\n\n#dreamhouse #newstudio #Goa',
#   'Published_Date': '2021-02-26T12:04:05Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT46M40S',
#   'Defnination': 'hd',
#   'Views': '87788',
#   'Likes': '4482',
#   'Comment_count': '352',
#   'Favourite_count': '0',
#   'Like_count': '4482'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'COOL HACK using BUTTONS and RUBBER BANDS  | In HINDI',
#   'Video_ID': 'l3CsgsmCdzY',
#   'Thumbnail': 'https://i.ytimg.com/vi/l3CsgsmCdzY/default.jpg',
#   'Description': "CLICK TO WATCH FULL VIDEO :  https://youtu.be/fbXUSXMP8d8\nLEARN this COOL HACK to make Amazing things using BUTTONS & RUBBER BANDS.\nAlso, if you want to know more about NID or how to become a better Artist/Designer or if you want to build a successful Brand ? Then please watch this video.\n.\nSince you keep asking me to tell you more about NID, i decided to interview a friend of mine who is a NID designer and has a successful brand  called BUTTON MASALA and he shared all his tips and tricks on how you can be successful too.\n.\nDo give it a watch and let me know who you would like to see next.\n.\nPlease SUBSCRIBE to the channel, LIKE the video and do leave a nice comment and spread Love.\n.\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://instagram.com/madstuffwithrob?igshid=w6jjgbiivq6m\nhttps://instagram.com/robinthehoodofficial?igshid=10w8h41liiuht\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified!\n\n#Buttonmasala #NID #Designer",
#   'Published_Date': '2021-02-17T09:27:30Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT2M3S',
#   'Defnination': 'hd',
#   'Views': '107494',
#   'Likes': '6261',
#   'Comment_count': '573',
#   'Favourite_count': '0',
#   'Like_count': '6261'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'How to make STOP MOTION Videos with CLAY using your Phone | In Hindi',
#   'Video_ID': 'VCrjf_di-50',
#   'Thumbnail': 'https://i.ytimg.com/vi/VCrjf_di-50/default.jpg',
#   'Description': "In this video I'll show you how to make STOP MOTION Videos with CLAY using your PHONE. Stop motion animation is a lot of fun and anyone can do it. All you need is a camera/phone, some objects or props to animate and a little time at hand. Thats it!  \n.\nIn this video we will ANIMATE CLAY and for that I've shared the basic technique and a list of things you need to do stop motion animation at home. Do watch the video and give it a try. Even if you are not great at art or want to become an animator you should still try it. To watch inanimate objects come to life is a different vibe all together.\nDo it and you can thank me later.\n. \nIf you enjoy watching the video then make sure you LIKE, SHARE and do SUBSCRIBE. It’ll mean a lot. \n. \nDon't forget to tag me on my social media when you upload pictures of your art: Instagram – \nhttps://www.instagram.com/madstuffwithrob/ \nhttps://www.instagram.com/robinthehoodofficial/ \nFacebook - @madstuffwithrob \n\nDo hit the bell icon to stay notified! \n\n#claymation #stopmotion #stopmotionanimation",
#   'Published_Date': '2021-02-11T13:29:46Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'animation',
#    'stop motion',
#    'stop motion animation',
#    'how to make stop motion videos',
#    'how to make stop motion animation',
#    'how to make stop motion',
#    'how to do stop motion animation',
#    'how to animate',
#    'how to do animation',
#    'how to make stop motion videos on android',
#    'how to make stop motion videos on iphone',
#    'how to animate using your phone',
#    'how to do animation on your phone',
#    'how to animate on phone'],
#   'Duration': 'PT12M58S',
#   'Defnination': 'hd',
#   'Views': '559754',
#   'Likes': '14766',
#   'Comment_count': '1188',
#   'Favourite_count': '0',
#   'Like_count': '14766'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'SOME MORE STOP MOTION ANIMATION',
#   'Video_ID': 'gr1Lb_VK5oQ',
#   'Thumbnail': 'https://i.ytimg.com/vi/gr1Lb_VK5oQ/default.jpg',
#   'Description': "Here's some more STOP MOTION ANIMATION for you guys.I really hope you enjoy it. Also I'm super glad that you guys loved the STOP MOTION Tutorial I posted 2 days back. If you haven't seen it yet then do watch it. I have explained the basics of Stop Motion in the most simplest possible way.\n\r.\n\rIf you are making Stop Morion videos after watching my tutorial the don't forget to tag me so i can watch your films too.\n.\nAlso Don't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/madstuffwithrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified!\n\n#stopmotionanimation #madstuffwithrob #Stopmotion",
#   'Published_Date': '2021-02-03T08:51:16Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT3M13S',
#   'Defnination': 'hd',
#   'Views': '125098',
#   'Likes': '8367',
#   'Comment_count': '964',
#   'Favourite_count': '0',
#   'Like_count': '8367'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'How to make STOP MOTION Videos using your PHONE | In Hindi',
#   'Video_ID': 'CJ7LQXgp81w',
#   'Thumbnail': 'https://i.ytimg.com/vi/CJ7LQXgp81w/default.jpg',
#   'Description': "In this video I'll show you how to make STOP MOTION videos using your PHONE. Stop motion animation is a lot of fun and anyone can do it. All you need is a camera/phone, some objects or props to animate and a little time at hand. Thats it! \nAlso you need an app on your phone. I used one but you can use one of your choice.\nhttps://play.google.com/store/apps/details?id=com.cateater.stopmotionstudio&hl=en_IN&gl=US\n.\nI've shared the basic technique and a list of things you need to do stop motion animation at home. Do watch the video and give it a try. Even if you are not great at art or want to become an animator you should still try it. To watch inanimate objects come to life is a different vibe all together.\nDo it and you can thank me later.\n. \nIf you enjoy watching the video then make sure you LIKE, SHARE and do SUBSCRIBE. It’ll mean a lot. \n. \nDon't forget to tag me on my social media when you upload pictures of your art: Instagram – \nhttps://www.instagram.com/madstuffwithrob/ \nhttps://www.instagram.com/robinthehoodofficial/ \nFacebook - @madstuffwithrob \n\nDo hit the bell icon to stay notified! \n\n#animation #stopmotion #stopmotionanimation",
#   'Published_Date': '2021-02-01T10:30:01Z',
#   'Tags': ['mad stuff with rob',
#    'mad stuff',
#    'pogo',
#    'rob',
#    'DIY',
#    'Craft',
#    'animation',
#    'stop motion',
#    'how to make stop motion videos',
#    'how to make stop motion',
#    'how to make stop motion video',
#    'how to animate',
#    'how to make stop motion videos on android',
#    'how to make stop motion videos on iphone',
#    'how to make stop motion animation',
#    'how to do animation',
#    'how to',
#    'how to animate on phone',
#    'how to animte using your phone',
#    'how to do animation on your phone'],
#   'Duration': 'PT13M54S',
#   'Defnination': 'hd',
#   'Views': '881549',
#   'Likes': '50693',
#   'Comment_count': '2245',
#   'Favourite_count': '0',
#   'Like_count': '50693'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': "YOU WON'T BELIEVE WHAT I SAW...",
#   'Video_ID': 'ex_mbgZiifU',
#   'Thumbnail': 'https://i.ytimg.com/vi/ex_mbgZiifU/default.jpg',
#   'Description': "You can watch the full VLOG here : https://youtu.be/XJWIpNe5sW8\nYou wont believe what I saw guys. This is why i love shooting outdoors because you get to see and explore so much. Watch this VLOG to catch all the action.\n.\nSuper happy with how it turned out. If you enjoy watching the video then make sure you LIKE, SHARE and do SUBSCRIBE. It’ll mean a lot. \n. \nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – \nhttps://www.instagram.com/madstuffwithrob/ https://www.instagram.com/robinthehoodofficial/ \nFacebook - @madstuffwithrob \n\nDo hit the bell icon to stay notified! \n\n#VLOG #Jungleadventure #belikewater",
#   'Published_Date': '2021-01-23T07:52:04Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT3M47S',
#   'Defnination': 'hd',
#   'Views': '109446',
#   'Likes': '7118',
#   'Comment_count': '993',
#   'Favourite_count': '0',
#   'Like_count': '7118'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'PAINTING in a JUNGLE | BRUCE LEE | Be like Water, my friend.',
#   'Video_ID': 'W5Qp7XNdu5E',
#   'Thumbnail': 'https://i.ytimg.com/vi/W5Qp7XNdu5E/default.jpg',
#   'Description': "Painting in a Jungle!!! You heard me right. Decided to spend some time in nature but not without my paints and brushes ☺ I want this NEW YEAR to be full of NEW ADVENTURES and this honestly was a great start. I always wanted to do something like this and can't begin to tell you how much fun I had doing this.\n.\nThough there are a lot of challenges when you are shooting outdoors. You don’t have control over the light (If you want to work in natural light then you get from sunrise to sunset) or sound (there were lots of chirping birds) in addition to that it was super hot and there were lots of mosquitoes. But the idea is to face to challenges and overcome them. \nAnd that’s exactly the message of this video too. Bruce Lee’s philosophy to “BE LIKE WATER”. Be fluid, flexible, and spontaneous. Be ready to adapt to certain situations, change and grow. \n. \nSuper happy with how it turned out. If you enjoy watching the video then make sure you LIKE, SHARE and do SUBSCRIBE. It’ll mean a lot. \n. \nDon't forget to tag me on my social media when you upload pictures of your art: Instagram – \nhttps://www.instagram.com/madstuffwithrob/ https://www.instagram.com/robinthehoodofficial/ \nFacebook - @madstuffwithrob \n\nDo hit the bell icon to stay notified! \n\n#Painting #brucelee #belikewater",
#   'Published_Date': '2021-01-20T13:11:56Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT3M16S',
#   'Defnination': 'hd',
#   'Views': '147066',
#   'Likes': '13478',
#   'Comment_count': '1314',
#   'Favourite_count': '0',
#   'Like_count': '13478'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Tried STOP MOTION ANIMATION | AMONG US | Happy New Year',
#   'Video_ID': '9CFmhbSOuv8',
#   'Thumbnail': 'https://i.ytimg.com/vi/9CFmhbSOuv8/default.jpg',
#   'Description': "Did some STOP MOTION ANIMATION after a long time and was pretty happy with the results hence decide to share it with you guys. The AMONG US animation was super fun to make and the COUCH POTATO one was the trickiest. I honestly feel that the animation is pretty rusty since I did it after many years but still I’m super happy cos they turned out so much fun.\n\r.\n\rAlso wanted to wish everyone a very Happy New Year through this video.\rI know its slightly late for New Year wishes but better late than never. And its never late to make changes in our lifestyle or habits and push ourselves to become a better version of ourselves. \r\n2020 was a bit challenging but make sure that you start 2021 on a positive note and make it your year. \r\nHave a SUPER 2021\n.\r\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/madstuffwithrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified!\n\n#stopmotionanimation #madstuffwithrob #Amongus",
#   'Published_Date': '2021-01-15T13:06:22Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT1M46S',
#   'Defnination': 'hd',
#   'Views': '176845',
#   'Likes': '10563',
#   'Comment_count': '775',
#   'Favourite_count': '0',
#   'Like_count': '10563'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'NEW YEAR NEW PLANS',
#   'Video_ID': 'i3_qqZzfXsQ',
#   'Thumbnail': 'https://i.ytimg.com/vi/i3_qqZzfXsQ/default.jpg',
#   'Description': '',
#   'Published_Date': '2021-01-13T12:15:19Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT30M16S',
#   'Defnination': 'hd',
#   'Views': '50755',
#   'Likes': '3863',
#   'Comment_count': '434',
#   'Favourite_count': '0',
#   'Like_count': '3863'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Simple PAPER CUTOUT | Shadow Box | DIY in Hindi',
#   'Video_ID': 'ncZgvHIL0G8',
#   'Thumbnail': 'https://i.ytimg.com/vi/ncZgvHIL0G8/default.jpg',
#   'Description': "Wanna try some Simple PAPER CUTOUT Shadow Box ? Then here’s something special for you guys. A DIY Christmas Crib Shadow box made with just PAPER and CARDBOARD. \rI set up a crib at home every year but this year because of the current situation and frequent lockdowns I knew it’ll be difficult for everyone to step outside to buy materials for the crib including me. So I decided to make one with materials lying at home. \n\n\r\rI always say, “Why BUY when you can DIY!” because making stuff yourself brings a lot of joy. And this time I’m super happy cos this turned out better than I had expected. Do watch and do give it a try.\r\r\n\nI would love it if you guys make a paper crib at home this time for Christmas.\r If you make it then pls click pics and share them with me. And if you enjoyed watching this video and found the tutorial helpful then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment. It makes me happy ☺\r\r\r\n\n\r\rDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/madstuffwithrob/ https://www.instagram.com/robinthehoodofficial/ \nFacebook - @madstuffwithrob \n\nDo hit the bell icon to stay notified! \n\n#Christmascrib #Shadowbox #DIY\n#madstuffwithrob",
#   'Published_Date': '2020-12-25T04:26:17Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT13M53S',
#   'Defnination': 'hd',
#   'Views': '196193',
#   'Likes': '14204',
#   'Comment_count': '1437',
#   'Favourite_count': '0',
#   'Like_count': '14204'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Painting with TOOTHPASTE and a TOOTHBRUSH on an iPad | Virat Kohli',
#   'Video_ID': 'MkMgg36urz8',
#   'Thumbnail': 'https://i.ytimg.com/vi/MkMgg36urz8/default.jpg',
#   'Description': "Tried something NEW!! Painted VIRAT KOHLI using TOOTHPASTE and a TOOTHBRUSH on an IPad. Whaaaatttt? \r\rYou heard me right. \n\nIn fact I made this a while back and shared it on my REELS on Instagram. It did really well and I realised that my audience on both the platforms is very different so I decided to share it here too. Hope you guys like it as much. If you do, then please give the video a big LIKE, Share it and do leave a nice comment for encouragement. It makes me happy ☺\r\r\n\nAlso if you are a VIRAT KOHLI fan then do tag him or share it with your friends who love him or love cricket in general. Thanks!\r\r\n\nFYI : No IPAD was harmed in the making of this video ☺ \r\r\n\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/madstuffwithrob/ https://www.instagram.com/robinthehoodofficial/ \r\nFacebook - @madstuffwithrob \r\r\n\nDo hit the bell icon to stay notified! \r\r\n\n#viratkohli #runmachine #cricket",
#   'Published_Date': '2020-12-21T11:03:38Z',
#   'Tags': ['mad stuff with rob', 'mad stuff', 'pogo', 'rob', 'DIY', 'Craft'],
#   'Duration': 'PT1M46S',
#   'Defnination': 'hd',
#   'Views': '219436',
#   'Likes': '15161',
#   'Comment_count': '1556',
#   'Favourite_count': '0',
#   'Like_count': '15161'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Make an AMONG US LAMP at home | DIY | In Hindi',
#   'Video_ID': 'gD0gtXNob14',
#   'Thumbnail': 'https://i.ytimg.com/vi/gD0gtXNob14/default.jpg',
#   'Description': "All you AMONG US fans, now you can make a COOL LAMP at HOME. \nHow amazing is that!! \nAll you need is some basic materials and tools and you can turn a Plastic Bottle into a Dead body Lamp. Sounds crazy but it works as you can see in this video. I was super happy with the results. \n\nThe best thing is that it’s inexpensive and you can do it materials lying at home. Well almost minus a few things that you'll need to buy :) But trust me they are super cheap so Do try it!! \nAnd if you like the video and found the tutorial helpful then please SUBSCRIBE to the channel, LIKE the video and do leave a nice comment.\nIt makes me happy ☺\n\n\r\rHere’s the MATERIAL LIST of todays DIY PROJECT\r\n\n• Plastic Bottle - 2 ltrs\n• Cardboard \n\r• T T Balls\n\r• Empty Tube of White Glue\n• Piece of Foam sheet or mount board \n\r• Sticky Tape\r\n• Glue Gun\n• Scissors\n• Cutter\n• Acrylic paints or Spray paints\n\nDon't forget to tag me on my social media when you upload pictures of your art: \nInstagram – https://www.instagram.com/madstuffwithrob/\nhttps://www.instagram.com/robinthehoodofficial/\nFacebook - @madstuffwithrob \n\n\r\rDo hit the bell icon to stay notified!\n\n#Amongus #Amonguslamp #DIY",
#   'Published_Date': '2020-12-16T09:00:32Z',
# ...
#   'Published_Date': '2014-11-11T09:03:29Z',
#   'Tags': ['Do It Yourself (Hobby)',
#    'Step by step',
#    'Mad Rob Pogo',
#    'Creative Create',
#    'How to',
#    'Pogo',
#    'The Best place for kids',
#    'DIY',
#    'DIY Art',
#    'DIY Craft',
#    'DIY Projects',
#    'Craft work with waste material',
#    'Craft ideas for decoration',
#    'Craft making',
#    'Craft work for children',
#    'Craft ideas for teenagers',
#    'Art and craft',
#    'Art with waste material',
#    'Colors',
#    'Paint',
#    'Craft (TV Subject)',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'fun learning',
#    'Kids craft videos',
#    'Pogo channel'],
#   'Duration': 'PT3M14S',
#   'Defnination': 'hd',
#   'Views': '19717',
#   'Likes': '281',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '281'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Mad Stuff with Rob – These little hands | Children’s Day Special | Art from the Heart',
#   'Video_ID': 'DRGNXy9R5Qc',
#   'Thumbnail': 'https://i.ytimg.com/vi/DRGNXy9R5Qc/default.jpg',
#   'Description': 'Would you like to be a part of my mad world? Subscribe to MadStuffWithRob and join me in the Robosphere. My YouTube channel is a safe space for little hands with BIG imaginations. Find simple, step-by-step, artistic ways to create mad art, craft, magic and fun DIY stuff that will teleport out of the screen into your real world!\n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.',
#   'Published_Date': '2014-11-11T09:03:29Z',
#   'Tags': ["Children's Day (Holiday)",
#    'Rob',
#    'Hands',
#    'Keep',
#    'Mad Rob Pogo',
#    'Creative Create',
#    'Step by step',
#    'DIY',
#    'DIY Science',
#    'DIY Art',
#    'DIY Craft',
#    'Craft ideas for teenagers',
#    'Craft work for children',
#    'Art with waste material',
#    'Pranks for children',
#    'Fun',
#    'Jungle Book',
#    'Shaktimaan',
#    'Shinchan',
#    'Do It Yourself (Hobby)',
#    'Hobby (Interest)',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'pogo rob new channel',
#    'mad rob new channel',
#    'mad pogo rob new channel',
#    'Craft making',
#    'Kids videos',
#    'Paper games & crafts'],
#   'Duration': 'PT1M44S',
#   'Defnination': 'hd',
#   'Views': '51814',
#   'Likes': '127',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '127'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Mad Stuff with Rob – Funny Coffee Glue Stain Prank | DIY for Children',
#   'Video_ID': 'M_uG9lC4OcI',
#   'Thumbnail': 'https://i.ytimg.com/vi/M_uG9lC4OcI/default.jpg',
#   'Description': 'Scare the patatas out of your parents, your friends or even your teacher with this cool trick from the PrankTank! Rob shows you how to create a realistic coffee or juice stain that’s so Prankstah, it looks like a real disaster on someone’s precious laptop, clothes or books!\n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.',
#   'Published_Date': '2014-11-11T09:03:29Z',
#   'Tags': ['Pranks for children',
#    'Pranks in India',
#    'Prank',
#    'Craft work with paper',
#    'Craft making',
#    'Craft work for children',
#    'Glue',
#    'Colors',
#    'Paint',
#    'Brush',
#    'School',
#    'Teacher',
#    'Play',
#    'Fun',
#    'Learning',
#    'Mad Rob Pogo',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'rob new channel',
#    'pogo rob new channel',
#    'mad rob new channel',
#    'mad pogo rob new channel',
#    'Stain',
#    'Do It Yourself (Hobby)',
#    'DIY Network (TV Network)',
#    'Paint (Software)',
#    'Funny',
#    'Cool',
#    'Fun kids activity',
#    'Kids art classes',
#    'Art and craft',
#    'fun learning'],
#   'Duration': 'PT3M2S',
#   'Defnination': 'hd',
#   'Views': '133245',
#   'Likes': '2755',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '2755'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Mad Stuff with Rob – How to draw a fish | DIY Drawing for children',
#   'Video_ID': 'VaUzJJ-mpn8',
#   'Thumbnail': 'https://i.ytimg.com/vi/VaUzJJ-mpn8/default.jpg',
#   'Description': 'Take a big breath and plunge into the Robosphere where you can have an underwater encounter with a cool sea creature. You don’t need to know how to swim to learn how to Drawsome Awesome a swimming fish in just a Single Stroke. Splash! \n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com',
#   'Published_Date': '2014-11-11T09:03:29Z',
#   'Tags': ['Drawing (Interest)',
#    'Do It Yourself (Hobby)',
#    'How-to (Website Category)',
#    'Fish',
#    'Painting',
#    'Hobby (Interest)',
#    'DIY',
#    'Mad Rob Pogo',
#    'Creative Create',
#    'Pogo',
#    'The Best place for kids',
#    'Art Attack',
#    'Craft work with paper',
#    'Colors',
#    'Paint',
#    'paper',
#    'Fun',
#    'DIY Craft',
#    'Art and craft',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'rob new channel',
#    'pogo rob new channel',
#    'mad rob new channel',
#    'mad pogo rob new channel',
#    'Kids fish craft',
#    'Kids learning',
#    'Kids art project',
#    'Pogo channel',
#    'How to draw cartoon'],
#   'Duration': 'PT3M34S',
#   'Defnination': 'hd',
#   'Views': '15579',
#   'Likes': '220',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '220'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Mad Stuff with Rob – Funny Flower Prank | DIY for Children',
#   'Video_ID': 'Zh-FK3TJruo',
#   'Thumbnail': 'https://i.ytimg.com/vi/Zh-FK3TJruo/default.jpg',
#   'Description': 'Trick your friends with this classic, hilarious, super simple, funny prank! With Rob’s CraftPunk skills, learn how to make a ‘Squirting Flower’. All you need is an ink dropper, paint, an artificial flower and a trusting pal.\n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.',
#   'Published_Date': '2014-11-11T09:03:29Z',
#   'Tags': ['Mad Rob Pogo',
#    'How to',
#    'Pogo',
#    'The Best place for kids',
#    'Prank',
#    'Pranks in India',
#    'Pranks for children',
#    'Play',
#    'Laugh Gags',
#    'Do It Yourself (Hobby)',
#    'Funny',
#    'Flower Prank',
#    'Squirting Flower',
#    'Prankster',
#    'Prankster (Comic Book Character)',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'rob new channel',
#    'pogo rob new channel',
#    'mad rob new channel',
#    'mad pogo rob new channel',
#    'fun learning',
#    'Pogo channel',
#    'Fun kids activity',
#    'Paper games & crafts',
#    'Art and craft',
#    'Kids craft work',
#    'Kids art project'],
#   'Duration': 'PT2M48S',
#   'Defnination': 'hd',
#   'Views': '45178',
#   'Likes': '660',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '660'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Mad Stuff with Rob – How to print your own T-Shirt | DIY Craft for Children',
#   'Video_ID': 'vldWS5-4gwQ',
#   'Thumbnail': 'https://i.ytimg.com/vi/vldWS5-4gwQ/default.jpg',
#   'Description': 'Why wear what everyone else is wearing? Be creative and learn how to make your own unique t-shirt! You won’t believe how simple it is. Do one or a whole bunch as a project with the members of your own secret CraftPunk club. \n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.',
#   'Published_Date': '2014-11-11T09:03:29Z',
#   'Tags': ['Do It Yourself (Hobby)',
#    'Mad Rob Pogo',
#    'Creative Create',
#    'How to',
#    'Pogo',
#    'The Best place for kids',
#    'Step by step',
#    'DIY',
#    'DIY Art',
#    'DIY Craft',
#    'DIY Projects',
#    'Craft work with waste material',
#    'Craft ideas for decoration',
#    'Craft work with paper',
#    'Craft making',
#    'Art and craft',
#    'Colors',
#    'Paint',
#    'Brush',
#    'School',
#    'Homework',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'mad pogo rob new channel',
#    'Kids craft',
#    'DIY Kids craft',
#    'How to draw cartoon',
#    'Paper games & crafts',
#    'DIY awesome crafts',
#    'Learning',
#    'Fun'],
#   'Duration': 'PT4M26S',
#   'Defnination': 'hd',
#   'Views': '396011',
#   'Likes': '8293',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '8293'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Mad Stuff with Rob – How to make fish swim | DIY Craft for children',
#   'Video_ID': 'CRm6BHeKQ2Y',
#   'Thumbnail': 'https://i.ytimg.com/vi/CRm6BHeKQ2Y/default.jpg',
#   'Description': 'Not allowed to have fish as a pet? That’s no problem in the Robosphere. Learn how to use drawing, craft and some slick CraftPunk tricks to create fish that actually SWIM in water. A really cool project for your school!\n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.',
#   'Published_Date': '2014-11-11T09:03:28Z',
#   'Tags': ['Do It Yourself (Hobby)',
#    'Craft (TV Subject)',
#    'Fish',
#    'Swimming',
#    'Water',
#    'Rob',
#    'DIY',
#    'DIY Science',
#    'DIY Art',
#    'DIY Craft',
#    'DIY Projects',
#    'Craft work with waste material',
#    'Craft ideas for decoration',
#    'Craft work with paper',
#    'Craft work for children',
#    'Craft ideas for teenagers',
#    'Art and craft',
#    'Art with waste material',
#    'Learning',
#    'Making',
#    'Mad Rob Pogo',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'rob new channel',
#    'pogo rob new channel',
#    'mad rob new channel',
#    'mad pogo rob new channel',
#    'Kids fish craft'],
#   'Duration': 'PT3M8S',
#   'Defnination': 'hd',
#   'Views': '128132',
#   'Likes': '3179',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '3179'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Mad Stuff with Rob – feat. Neil Bhoopalam | How to make Maracas | DIY Craft for Children',
#   'Video_ID': 'ioNYc9y7uqY',
#   'Thumbnail': 'https://i.ytimg.com/vi/ioNYc9y7uqY/default.jpg',
#   'Description': 'Have you met my buddy Neil Bhoopalam? He’s really fun and here is a mad video of his visit to the Robosphere. I taught him to make cool Maracas and we learned how to use them on this song.\n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.',
#   'Published_Date': '2014-11-11T09:03:28Z',
#   'Tags': ['Do It Yourself (Hobby)',
#    'Paper',
#    'Stuff',
#    'Making',
#    'Rob',
#    'Mad Rob Pogo',
#    'Pogo',
#    'The Best place for kids',
#    'Art Attack',
#    'DIY',
#    'DIY Science',
#    'DIY Art',
#    'DIY Craft',
#    'Craft work with waste material',
#    'Craft work with paper',
#    'Craft making',
#    'Craft work for children',
#    'Art and craft',
#    'Colors',
#    'Paint',
#    'Brush',
#    'Neil Bhoopalam',
#    'Ungli',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'mad pogo rob new channel',
#    'rob new channel',
#    'pogo rob new channel',
#    'mad rob new channel',
#    'How-to (Website Category)',
#    'Kids art project'],
#   'Duration': 'PT6M18S',
#   'Defnination': 'hd',
#   'Views': '42163',
#   'Likes': '581',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '581'},
#  {'Channel_Name': 'Mad Stuff With Rob',
#   'Channel_ID': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Video_Title': 'Mad Stuff with Rob – How to draw an owl | DIY Drawing for children',
#   'Video_ID': 'tE3MHgXCoEM',
#   'Thumbnail': 'https://i.ytimg.com/vi/tE3MHgXCoEM/default.jpg',
#   'Description': 'Wanna capture some nocturnal wildlife on paper? Simply use Rob’s Drawsome Awesome steps and learn how drawing an owl can be a hoot. It’s DIY art that may even impress your parents into letting you stay up past your bedtime. \n\nFor more Artrageous stuff Subscribe to \n\nYouTube - http://www.youtube.com/user/madstuffwithrob?sub_confirmation=1  \n\nLike on Facebook\nhttps://www.facebook.com/madstuffwithrob \n\nG+ \nhttps://plus.google.com/u/0/116004689690990036095/\n\nFollow on Twitter \nhttps://twitter.com/madmadrob\n\ninstagram\nhttp://instagram.com/madstuffwithrob\n\n\nFor Bookings contact:\nNihaal Poonja | +91-9920585595\nnihaal.poonja@sonymusic.com\n\nSony Music  Kids Initiative. C & P 2014 Sony Music Entertainment India Pvt.Ltd.',
#   'Published_Date': '2014-11-11T09:03:28Z',
#   'Tags': ['Mad Rob Pogo',
#    'Creative Create',
#    'How to',
#    'Pogo',
#    'The Best place for kids',
#    'Art Attack',
#    'Step by step',
#    'DIY',
#    'DIY Science',
#    'DIY Art',
#    'DIY Craft',
#    'DIY Projects',
#    'Colors',
#    'Paint',
#    'Brush',
#    'paper',
#    'School',
#    'Teacher',
#    'Homework',
#    'Play',
#    'Fun',
#    'Learning',
#    'Drawing (Interest)',
#    'Do It Yourself (Hobby)',
#    'Painting',
#    'Lesson',
#    'Cartoon Network',
#    'Disney',
#    'Rob’s new channel',
#    'Rob’s youtube channel',
#    'Rob Pogo',
#    'rob new channel',
#    'pogo rob new channel',
#    'mad rob new channel',
#    'mad pogo rob new channel',
#    'Kids art project',
#    'Fun kids activity'],
#   'Duration': 'PT3M16S',
#   'Defnination': 'hd',
#   'Views': '26246',
#   'Likes': '753',
#   'Comment_count': '0',
#   'Favourite_count': '0',
#   'Like_count': '753'}]

# %%
# Function To Fetch All Comments Information Of The Channel


def get_comment_info(Video_Ids):
    c_data = []
    try:
        for video_id in Video_Ids:
            request = youtube.commentThreads().list(
                part = "snippet",
                videoId = video_id,
                maxResults = 50
            )
            response = request.execute()
            for item in response["items"]:
                comment_data = dict(comment_Id = item["snippet"]["topLevelComment"]["id"],
                        Video_Id = item["snippet"]["topLevelComment"]["snippet"]["videoId"],
                        Comment_Text = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                        Commet_Author = item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                        Comment_publication = item["snippet"]["topLevelComment"]["snippet"]["publishedAt"])
                
                c_data.append(comment_data)
    except:
        pass 
        return c_data

# %%
comment_details = get_comment_info(Video_Ids)

# %%
comment_details
# Out:
# [{'comment_Id': 'Ugy2xigIkFfL74f7eiF4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': '❤❤❤❤❤',
#   'Commet_Author': '@devanshn.contractor5259',
#   'Comment_publication': '2024-01-08T18:03:17Z'},
#  {'comment_Id': 'Ugym2pauU9r051QCWx94AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'joh joh free fire lover hai woh like karo ❤',
#   'Commet_Author': '@gwneha3093',
#   'Comment_publication': '2023-12-31T17:14:28Z'},
#  {'comment_Id': 'UgyEOe10vndzKN8jOY54AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Sir aap ko tv mai nahi aate par kyo',
#   'Commet_Author': '@aactorboy9588',
#   'Comment_publication': '2023-12-31T11:02:32Z'},
#  {'comment_Id': 'UgyTitNRlm_NOa1xPjB4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Happy belated birthday rob sir 🎉🎉',
#   'Commet_Author': '@dimplesharma1454',
#   'Comment_publication': '2023-12-29T15:02:15Z'},
#  {'comment_Id': 'UgwtedMtej7HIBs6Nwp4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': '🙏🙏🙏',
#   'Commet_Author': '@Debjittandar',
#   'Comment_publication': '2023-12-27T13:36:50Z'},
#  {'comment_Id': 'Ugw0Chz7tutMfwnn9Sx4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Why you are inactive bro, please upload long videos ❤❤',
#   'Commet_Author': '@YtGamingWorld69',
#   'Comment_publication': '2023-12-23T05:47:57Z'},
#  {'comment_Id': 'UgxboWKi62iFmORpMAh4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'My childhood drawing teacher❤❤',
#   'Commet_Author': '@MrRebel0098',
#   'Comment_publication': '2023-12-21T05:49:50Z'},
#  {'comment_Id': 'UgwI4JcyRS1B74IvTUB4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Lekin koi support nahin karta sare hit comment',
#   'Commet_Author': '@Skartcraft1',
#   'Comment_publication': '2023-12-21T05:43:22Z'},
#  {'comment_Id': 'UgyaqrQLCVgDuK20A2N4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Main hero is on middle 😎😎😎🔥😈',
#   'Commet_Author': '@zesspod',
#   'Comment_publication': '2023-12-14T16:50:56Z'},
#  {'comment_Id': 'UgxFVyZthsg3C0t-J0F4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Uncle aap YouTube mein old videos <a href="http://dijiye.na/">dijiye.na</a> jaise aap TV mein dete the',
#   'Commet_Author': '@purnimasaha4261',
#   'Comment_publication': '2023-12-13T17:16:44Z'},
#  {'comment_Id': 'UgyeawvLc5auBpo_jZ54AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Which song sir and what drawing sir',
#   'Commet_Author': '@londhekishor4718',
#   'Comment_publication': '2023-12-10T09:55:38Z'},
#  {'comment_Id': 'UgzKbwXLCgTKSbkOwul4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'I need  this pen 🖊  I  love  drawing  and doodling  and other things 😍',
#   'Commet_Author': '@user-br8ex4pw8p',
#   'Comment_publication': '2023-12-07T17:08:31Z'},
#  {'comment_Id': 'UgxqSjc9XasdtRFkoep4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'You are my childhood hero ❤❤',
#   'Commet_Author': '@satishjadav782',
#   'Comment_publication': '2023-12-07T08:48:06Z'},
#  {'comment_Id': 'UgzyMc_EARCq1i_tDHt4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Mad and art attack ❤❤',
#   'Commet_Author': '@lakshmiyelchuri2367',
#   'Comment_publication': '2023-12-05T08:48:09Z'},
#  {'comment_Id': 'UgzmWaoLcSLCtqoi9h54AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'That doodle turned out superb ❤',
#   'Commet_Author': '@09.dixitarnavshriram40',
#   'Comment_publication': '2023-11-30T07:27:30Z'},
#  {'comment_Id': 'Ugxb6LgKHg4Wvf6vvCx4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': '😢MAD RoB',
#   'Commet_Author': '@farafathi9962',
#   'Comment_publication': '2023-11-29T14:25:08Z'},
#  {'comment_Id': 'UgyJeOpDRAXmXcfGaX94AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Your my childhood hero and is show is amazing and wonderful and so beautiful and my hero sir mad show',
#   'Commet_Author': '@sunitaratre8730',
#   'Comment_publication': '2023-11-29T11:25:43Z'},
#  {'comment_Id': 'UgzEg98j-uhzUuHYF5R4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Mad ❤❤',
#   'Commet_Author': '@lil_rogue.2',
#   'Comment_publication': '2023-11-28T19:28:04Z'},
#  {'comment_Id': 'Ugy8nuvMDxK8YN6UozJ4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'I still miss MAD..  Those days of my childhood watching him making exciting stuff &amp; trying to do them on my own ❤',
#   'Commet_Author': '@Aurelia03118',
#   'Comment_publication': '2023-11-26T14:40:44Z'},
#  {'comment_Id': 'Ugzr53QPwJz3h-dYVbB4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Gokus emotion are perfect😂😂',
#   'Commet_Author': '@mixmasala9018',
#   'Comment_publication': '2023-11-21T05:48:13Z'},
#  {'comment_Id': 'Ugx9QPNmopha5p6GN1t4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Haye bachpan yaad agaya..🥺🥺🥺',
#   'Commet_Author': '@tamkeenhasan2558',
#   'Comment_publication': '2023-11-19T21:13:51Z'},
#  {'comment_Id': 'Ugzm5hWAowUFMZ4wqxd4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Childhood 🥺❤  🇱🇰 🇱🇰 🇱🇰',
#   'Commet_Author': '@chamathrasanga7081',
#   'Comment_publication': '2023-11-13T18:58:22Z'},
#  {'comment_Id': 'UgzNmT3SGvT-V6UZmgp4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Goku is super drawing',
#   'Commet_Author': '@sengamalamm2976',
#   'Comment_publication': '2023-11-13T00:51:14Z'},
#  {'comment_Id': 'Ugwpwnz7PSj_FbuB8I54AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': '😢😢😢 bachpan yaad a gaya',
#   'Commet_Author': '@pindiboy3386',
#   'Comment_publication': '2023-11-12T22:45:13Z'},
#  {'comment_Id': 'UgyFkWYJn549nOYOWBR4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Love to see him back bachpan vapis aa gaya',
#   'Commet_Author': '@gagandeepsinghkainth3211',
#   'Comment_publication': '2023-11-12T05:14:40Z'},
#  {'comment_Id': 'Ugx4PvOhEkdX0C4iJQR4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Our hero',
#   'Commet_Author': '@DeepakKumar-bt7mv',
#   'Comment_publication': '2023-11-11T07:58:56Z'},
#  {'comment_Id': 'UgzXy7ciDkcVVHhqrCl4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Thanks for making my childhood cool with art ❤ now I am a married man with my own child.. time flies😢',
#   'Commet_Author': '@zimykuki9552',
#   'Comment_publication': '2023-11-10T12:29:19Z'},
#  {'comment_Id': 'UgxQBpgGT9tXN_2pq3l4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Hey, Rob I just I just wanna say you....  <b>Thanks</b> for making my and our childhood memorable I used to watch your show everyday I never missed any episode but now I miss that show very much 😢',
#   'Commet_Author': '@ITZMECOSMO',
#   'Comment_publication': '2023-11-09T11:15:56Z'},
#  {'comment_Id': 'UgwWE7mB5f43DPDYs9R4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'You still young♥️',
#   'Commet_Author': '@hollow_0763',
#   'Comment_publication': '2023-11-07T10:59:16Z'},
#  {'comment_Id': 'UgwFV7s3KF4GcUhZrA54AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Sir please make a comeback😢 we remember you love you 3000❤',
#   'Commet_Author': '@chandrasarmah8255',
#   'Comment_publication': '2023-11-02T01:27:53Z'},
#  {'comment_Id': 'UgzdZT0sBB6qmlVtUc14AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'My childhood  hero I was missing you ❤<br>Love you sir ❤',
#   'Commet_Author': '@mryashgaming961',
#   'Comment_publication': '2023-11-01T15:28:24Z'},
#  {'comment_Id': 'Ugxa5hX7NMCAD-AIjb94AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'One day I&#39;ll meet you sir ❤️',
#   'Commet_Author': '@prathambhardwaj7038',
#   'Comment_publication': '2023-10-30T08:16:28Z'},
#  {'comment_Id': 'UgyPkEaWa2XNQ9GHmQ94AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Aapko dekhkar mujhe apne bachpan ka M.A.D. show yaad aa gaya😊',
#   'Commet_Author': '@Netflix.webseries-hindi',
#   'Comment_publication': '2023-10-29T05:26:55Z'},
#  {'comment_Id': 'UgwGr-u7tKks6Csxl1Z4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Childhood memories mai ho yar aap ❤️🙂',
#   'Commet_Author': '@Mughalempire999',
#   'Comment_publication': '2023-10-28T04:45:10Z'},
#  {'comment_Id': 'Ugzoxtb5ZPFbkmcnAeJ4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Inver  forget you my 90s hero im missing that days when I see you in black white tv',
#   'Commet_Author': '@MadihaFatima111',
#   'Comment_publication': '2023-10-27T13:05:33Z'},
#  {'comment_Id': 'UgxSs8OIzXKz6SSY9ZN4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'The g.o.a.t (greatest of all the time) in my child hood🎉',
#   'Commet_Author': '@santanuadhikari1253',
#   'Comment_publication': '2023-10-27T08:53:07Z'},
#  {'comment_Id': 'Ugy2Pk95mYcmhICQ5tV4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'You made my childhood awesome ♥️<br>Big fan from Sri Lanka 🇱🇰',
#   'Commet_Author': '@eshansahan5213',
#   'Comment_publication': '2023-10-16T03:11:16Z'},
#  {'comment_Id': 'UgwqrzXA3Rbc3vAdFhR4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Use posca markers',
#   'Commet_Author': '@amrapalisen8444',
#   'Comment_publication': '2023-10-15T17:50:31Z'},
#  {'comment_Id': 'Ugw6TyONqkWfyZFWWAR4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Bro please mere sath art craft karo ma apke Ghar a jaouga',
#   'Commet_Author': '@antitegaming5555',
#   'Comment_publication': '2023-10-13T11:03:02Z'},
#  {'comment_Id': 'Ugyfj5ijk4St-Q9WMzt4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'He made goku',
#   'Commet_Author': '@manoramapareek8079',
#   'Comment_publication': '2023-10-08T09:31:06Z'},
#  {'comment_Id': 'Ugx4tgGuoLyzGCgHYHV4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Hello....... Rob<br>😊 artist Anil Dingankar here',
#   'Commet_Author': '@anildingankar8586',
#   'Comment_publication': '2023-10-08T04:52:26Z'},
#  {'comment_Id': 'UgxS5zyioYeOUAY2WAN4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'My art because of u',
#   'Commet_Author': '@moonXxXxX',
#   'Comment_publication': '2023-10-06T03:37:14Z'},
#  {'comment_Id': 'Ugz1xJEu7LqXDWSgIKF4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Hess back!! The OG !!!! Sir ty for making my childhood and making us love ART 💜 Love from Pakistan 🇵🇰🇵🇰',
#   'Commet_Author': '@minahilxbts5925',
#   'Comment_publication': '2023-10-03T21:09:47Z'},
#  {'comment_Id': 'UgwE0el1Ta1MK8PpOMR4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'I am your big fan',
#   'Commet_Author': '@prasantasaha5723',
#   'Comment_publication': '2023-09-28T15:34:30Z'},
#  {'comment_Id': 'Ugz9Mc4NdIQAdqM5QK54AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Sir Mera bhi drawing channel hai plz checkout<br>And plz give some drawings tips',
#   'Commet_Author': '@AJSDrawingofficial_747',
#   'Comment_publication': '2023-09-28T11:22:24Z'},
#  {'comment_Id': 'UgzZEfkLmm0MuaBKHxJ4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Our first art and craft teache 😊Sir you are an inspiration for me☺... Nostalgia 🤧🤧🤧',
#   'Commet_Author': '@chixx_17',
#   'Comment_publication': '2023-09-17T04:38:12Z'},
#  {'comment_Id': 'UgzZjQSVSLA27ofroLx4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Big fan broo❤',
#   'Commet_Author': '@hessafathimasworld886',
#   'Comment_publication': '2023-09-13T13:04:34Z'},
#  {'comment_Id': 'UgwHQ9QkFiaU3mz3Kdl4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Bro I am remember you when I am 8 year old you are supper you are my ideal 🥰🥰🥰😍',
#   'Commet_Author': '@MohammadFarooq-gr5kd',
#   'Comment_publication': '2023-09-11T08:07:32Z'},
#  {'comment_Id': 'Ugx_8trvAz_JwP2MFR54AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'What is the name of the song?? Plz tell',
#   'Commet_Author': '@Vishy767',
#   'Comment_publication': '2023-08-31T17:39:24Z'},
#  {'comment_Id': 'UgwaRiLmEk2bNO3GgWZ4AaABAg',
#   'Video_Id': 'ieX38it7gFo',
#   'Comment_Text': 'Made to Mad?<br>Why?!',
#   'Commet_Author': '@CaveSpirits',
#   'Comment_publication': '2023-08-30T13:06:50Z'},
#  {'comment_Id': 'UgyuBERmL24_8Wi0xfl4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Rob sir can you pls make spider man action figure from paper',
#   'Commet_Author': '@Games_Of_Sanket_The_Blue_Man',
#   'Comment_publication': '2024-01-02T09:26:31Z'},
#  {'comment_Id': 'UgzegZpoeqhdYXhWIy94AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Hi sir can you please make a video on How to make Anime Light Box',
#   'Commet_Author': '@manishsable3381',
#   'Comment_publication': '2024-01-01T08:46:32Z'},
#  {'comment_Id': 'Ugzh3ZebahaYhvjtB3F4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': '😍😍😍😍',
#   'Commet_Author': '@mukeshbarma8734',
#   'Comment_publication': '2023-12-28T14:43:52Z'},
#  {'comment_Id': 'UgwElNs6H-k5xBn3_y94AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Do you know rinks',
#   'Commet_Author': '@promilajha7667',
#   'Comment_publication': '2023-12-22T09:36:46Z'},
#  {'comment_Id': 'UgzhIpZP3O0VJXGVM-d4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Do you know rinks',
#   'Commet_Author': '@promilajha7667',
#   'Comment_publication': '2023-12-22T09:36:28Z'},
#  {'comment_Id': 'Ugw9g-Pe9K9vhKwLAQp4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Rip video 😭',
#   'Commet_Author': '@priteshdavale1398',
#   'Comment_publication': '2023-12-22T09:19:04Z'},
#  {'comment_Id': 'UgymHKpN-LdAPo6Mgqd4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'He was our childhood art teacher still i remember his arts❤ who all r here to subscribe rob YouTube channel like here ❤',
#   'Commet_Author': '@prasadraj4163',
#   'Comment_publication': '2023-12-20T16:55:22Z'},
#  {'comment_Id': 'UgzszApXEElWd4RfD9N4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Miss my old days',
#   'Commet_Author': '@gauravkapse2661',
#   'Comment_publication': '2023-12-15T13:18:13Z'},
#  {'comment_Id': 'UgyYFYp-CnOWxLsyEPR4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Please come back rob i always loved to watch you even those days you were on tv i always watch you',
#   'Commet_Author': '@DARKANGEL_BG',
#   'Comment_publication': '2023-12-12T13:05:58Z'},
#  {'comment_Id': 'UgyfEEN4jbK8t0grVft4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Just got a thought to know where our Rob is now, and I am not dissapointed...happy to see you just as same as u were in my childhood.❤',
#   'Commet_Author': '@sabeenashaikh7689',
#   'Comment_publication': '2023-12-03T09:30:56Z'},
#  {'comment_Id': 'UgwnDF3YsgbcvYSPME14AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Please come back and upload videos regularly where are you 😢',
#   'Commet_Author': '@poketrainerteenu7803',
#   'Comment_publication': '2023-11-26T13:25:28Z'},
#  {'comment_Id': 'UgwUeswMeLV1MDqNxwZ4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Rob try to animation video',
#   'Commet_Author': '@Entarten_001',
#   'Comment_publication': '2023-11-23T07:59:51Z'},
#  {'comment_Id': 'Ugz_DLz0t-ZZ0mSGaFF4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'You are my Childhood. Love from 🇵🇰',
#   'Commet_Author': '@abdulrahimqasim9562',
#   'Comment_publication': '2023-11-20T21:03:05Z'},
#  {'comment_Id': 'UgzruRIEMtKYTa28sxp4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Ur my fav  chidhood memories rob watch ur vedios',
#   'Commet_Author': '@user-xv9vu9nu8x',
#   'Comment_publication': '2023-11-16T14:07:08Z'},
#  {'comment_Id': 'UgyPGiFB7d8VzgE_s6l4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'u are my childhood inspiration when i saw u on pogo channel',
#   'Commet_Author': '@UsmanAbbasi-bd3db',
#   'Comment_publication': '2023-11-16T09:40:37Z'},
#  {'comment_Id': 'UgxJNCA7GViTVjkBASF4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'M.A.D. ROB Sir ❤❤❤ How are you.. we are big fans of your Creativity in our Childhood days ❤ POGO x M.A.D x ROB 🎉🎉🎉❤❤',
#   'Commet_Author': '@MxB_Gaming.',
#   'Comment_publication': '2023-11-13T11:48:13Z'},
#  {'comment_Id': 'Ugz9uOJyuAJw1Z9Z5IN4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'M.A.D. ROB Sir ❤❤❤ How are you.. we are big fans of your Creativity in our Childhood days ❤ POGO x M.A.D x ROB 🎉🎉🎉❤❤',
#   'Commet_Author': '@MxB_Gaming.',
#   'Comment_publication': '2023-11-13T11:47:24Z'},
#  {'comment_Id': 'UgwlqAAzNCx5LRKQRMd4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Hi Rob i missed ur show i grew up watching when i was  teenager such amazing craft inspire me to do so much i remember i mailed u on my yahoo mail n u replied me i cant believe that was happy surprising moment plzz do same show again on ur YouTube channel ppzzz that show ws such a beautiful memory the creatives behind that show n u a master of many arts we miss u thank u what u have given us i wish we have more show like this for our future kids❤ much lv 🇵🇰',
#   'Commet_Author': '@fa-edits',
#   'Comment_publication': '2023-11-12T12:50:16Z'},
#  {'comment_Id': 'UgyIIG9GvgpBozQ-7DJ4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Nostalgia 😭😭😭',
#   'Commet_Author': '@sprenzonontop069',
#   'Comment_publication': '2023-11-12T09:03:54Z'},
#  {'comment_Id': 'UgwxrVS0NA1wGoMuDJd4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'I was 8-10 years old when I used to watch the MAD show, never missed one episode, not even a segment, watched it all on repeat whenever it aired.. Now I am a grown up adult, in my late twenties. Rob, you have a special place in all of us 2000&#39;s kids&#39; heart. You made our childhood awesome! We didn&#39;t have the medium back then, now we do, and want to tell you, we love you! <br><br>Thanks to you I appreciated my creativity and worked on it, and made a career out if it, now I am a professional web developer of 12 years experience. Yes, I started when I was 12-13 years old, and thanks to you I always found it fun to  do art, be it with pen a paper or a computer. I still sometimes do art using pen and paper but mostly using code and the credit goes to you, you are my first Guru!',
#   'Commet_Author': '@DeepakKamat',
#   'Comment_publication': '2023-11-10T10:04:02Z'},
#  {'comment_Id': 'UgwI59aK6N12g2wwlV94AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'The Coolest guy in India 🥶💪',
#   'Commet_Author': '@MizoChivalry60093',
#   'Comment_publication': '2023-11-10T01:35:03Z'},
#  {'comment_Id': 'Ugyf9kFECbEzzeImgZ54AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Glad to know the M.A.D. we knew is still out there',
#   'Commet_Author': '@harshitpoddar5382',
#   'Comment_publication': '2023-11-09T20:23:15Z'},
#  {'comment_Id': 'Ugx01oPMCSdRQ0mH2Q14AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'I am your big fan mad rob. Your my childhood star. In my childhood i always ❤️ watching your show.',
#   'Commet_Author': '@sagarshetty5341',
#   'Comment_publication': '2023-11-08T11:57:15Z'},
#  {'comment_Id': 'UgxLGlG9Lh_hLYBbvf14AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Pogo😭MAD dang I miss those days',
#   'Commet_Author': '@KAZE_KEN',
#   'Comment_publication': '2023-11-07T13:18:59Z'},
#  {'comment_Id': 'UgwI6qcU3HDe3japzHV4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'I am Swapnil and I’m a small YouTuber. I love to see your videos. I want to take a interview of you…',
#   'Commet_Author': '@versebound',
#   'Comment_publication': '2023-10-23T11:00:33Z'},
#  {'comment_Id': 'Ugx6K-Jg3aNDN195Vtt4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Can you tell me the name of your laptop?',
#   'Commet_Author': '@ishrarirfan3177',
#   'Comment_publication': '2023-10-18T21:15:02Z'},
#  {'comment_Id': 'UgzUDSGDSbUz7RYYVxF4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'You are my Memory From childhood 😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢😢 huge immense love from me ❤❤❤❤❤',
#   'Commet_Author': '@WBkeyboardist',
#   'Comment_publication': '2023-10-16T22:49:14Z'},
#  {'comment_Id': 'UgxXa9SyjSewfRUOQaN4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'You can just introduce yourself like &quot; I&#39;m rob, your childhood hero&quot;.. that&#39;s enough',
#   'Commet_Author': '@shanvicky4917',
#   'Comment_publication': '2023-10-12T17:23:12Z'},
#  {'comment_Id': 'Ugzm2lWyYCY-xWXUG_V4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Rob is our saktiman time',
#   'Commet_Author': '@qamartausif194',
#   'Comment_publication': '2023-10-11T13:59:57Z'},
#  {'comment_Id': 'UgyfBLRaNaPNBfprmRV4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Bro iron man ka helmet banao please 🙏',
#   'Commet_Author': '@hemupatel4336',
#   'Comment_publication': '2023-09-29T02:37:56Z'},
#  {'comment_Id': 'UgzGJMrltf-tQZMMP6J4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'plz come back ROB we need u so much 😥😥😭😭',
#   'Commet_Author': '@susovansarkar3585',
#   'Comment_publication': '2023-09-28T18:02:55Z'},
#  {'comment_Id': 'UgwGaRfTDt2sHuQCCX14AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'hello Rob, i&#39;ve beenwatching you videos since m.a.d and magicskool. i wanted to ask if you could make a video about the chewing gum magic(with coat and rubber band). i wanted to show this trick to my friends but i cant find your old videos.<br>~big fan',
#   'Commet_Author': '@rabiashinu4098',
#   'Comment_publication': '2023-09-27T19:27:09Z'},
#  {'comment_Id': 'Ugx77hThpjlniouhIAd4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Bhaiya video kab daloge',
#   'Commet_Author': '@Cartoon-gb5uh',
#   'Comment_publication': '2023-09-27T15:48:46Z'},
#  {'comment_Id': 'UgyKISO2h0caDexfhcZ4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Our Childhood hero 🙌☺️',
#   'Commet_Author': '@rohitrg7805',
#   'Comment_publication': '2023-09-26T19:50:23Z'},
#  {'comment_Id': 'UgzHJpeaj5DdgROW04N4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Love from Pakistan for my Childhood Drawing Mentor 🇵🇰❤️',
#   'Commet_Author': '@Monotheist123',
#   'Comment_publication': '2023-09-26T19:47:00Z'},
#  {'comment_Id': 'Ugz5S_2jEYlBzS1NWQt4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'BRO YOU ARE LEGEND PLEASE COME BACK TO YOUTUBE AND MAKE US NOSTALGIC 🥺❤<br><br>~pogo lover',
#   'Commet_Author': '@Font444',
#   'Comment_publication': '2023-09-26T14:57:44Z'},
#  {'comment_Id': 'UgwMAn_NwfAFHtkEQP54AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Pogo',
#   'Commet_Author': '@tjgame9673',
#   'Comment_publication': '2023-09-24T18:16:41Z'},
#  {'comment_Id': 'UgxmOuwGpbJCXfi48nR4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Plz make any craft on Harry Potter',
#   'Commet_Author': '@preetisingh-wc1rw',
#   'Comment_publication': '2023-09-21T07:03:10Z'},
#  {'comment_Id': 'UgxQBHVtGpdchUf6K7R4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'MAD PLS MAKE TUTORIALS PLS OR START A CLASS HOW TO DO/DRAW!!! PLS WE REALLY MISS THAT CHILDHOOD ROB❤❤❤',
#   'Commet_Author': '@ashtag5170',
#   'Comment_publication': '2023-09-18T15:59:39Z'},
#  {'comment_Id': 'Ugyod6YCkfKvRwpuS4J4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'You are my entire childhood I always watched all of the M.A.D arts and crafts episodes whether it would be on tv or youtube',
#   'Commet_Author': '@shamirali70',
#   'Comment_publication': '2023-09-15T10:02:05Z'},
#  {'comment_Id': 'UgxrV0Voil_N-0WrMvx4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Rob please upload more videos this video was uploaded six months ago',
#   'Commet_Author': '@shamirali70',
#   'Comment_publication': '2023-09-15T10:00:45Z'},
#  {'comment_Id': 'Ugy_ls1EAqQbbsdsP-B4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Salam Rob',
#   'Commet_Author': '@shamirali70',
#   'Comment_publication': '2023-09-15T09:59:58Z'},
#  {'comment_Id': 'UgxL8B7kX7UTwrTNQW54AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Finally I found my 1st science teacher ❤😭😭😭😭😭😭😭😭😭😭',
#   'Commet_Author': '@KUNAL-CHAUDHARY_BR0907.',
#   'Comment_publication': '2023-09-14T09:53:20Z'},
#  {'comment_Id': 'UgygoNMKYpPLiQvXkYl4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Make a ghost mask of cod',
#   'Commet_Author': '@lordjvixX999',
#   'Comment_publication': '2023-09-11T16:03:21Z'},
#  {'comment_Id': 'Ugwfyqgbyo9rkhsWYDp4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Sir how about slime have you tried sir 🤔',
#   'Commet_Author': '@sanjanakattishetti9490',
#   'Comment_publication': '2023-09-09T13:01:57Z'},
#  {'comment_Id': 'UgxwnSd39DBxONDHU1l4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'My childhood hero😢😢❤❤❤',
#   'Commet_Author': '@bloodyff06',
#   'Comment_publication': '2023-08-22T04:10:17Z'},
#  {'comment_Id': 'Ugx1iWGxiWdfKiIH-TZ4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'My childhood favourite show',
#   'Commet_Author': '@mdjyogini',
#   'Comment_publication': '2023-08-13T17:44:24Z'},
#  {'comment_Id': 'Ugxvvf9_X6VYneKAs694AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Sir please make a tutorial on how to make layered paper cut out art..... 🙏',
#   'Commet_Author': '@kaun_anurag',
#   'Comment_publication': '2023-08-01T08:22:22Z'},
#  {'comment_Id': 'Ugx7TynceFUccUe0-9t4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'Sir, I have a HP pavillion*360 laptop which can convert into tablet. When I turn my laptop into tablet mode (360 degree) then the keyboard is disabled but keyboard buttons is pressed all by surface. PLEASE CAN YOU MADE A TABLET COVER FOR LAPTOP (TABLET MODE) TO PROTECT THE KEYBOARD BUTTONS WHILE ENJOYING LAPTOP LIKE TABLET ( HP PAVILLION*360)',
#   'Commet_Author': '@neeltrendz9340',
#   'Comment_publication': '2023-07-28T16:44:26Z'},
#  {'comment_Id': 'Ugw62GDCny8-TEVlBpd4AaABAg',
#   'Video_Id': 'WDJrRiI4kJ4',
#   'Comment_Text': 'I am born in 2004 and this guy made my childhood colourful',
#   'Commet_Author': '@deoxysda2294',
#   'Comment_publication': '2023-07-14T09:05:27Z'},
#  {'comment_Id': 'UgwmhqNHGmoHzdYTPi94AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'My favorite m.a.d and art attack   i watch in my childhood 🥺😭😣',
#   'Commet_Author': '@devarakkam993',
#   'Comment_publication': '2024-01-03T16:51:58Z'},
#  {'comment_Id': 'UgyUmJQWcG7kxB8AUgB4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Amazing Stop Motion 🤩',
#   'Commet_Author': '@jinanshmehta9859',
#   'Comment_publication': '2023-12-31T05:43:09Z'},
#  {'comment_Id': 'UgyIIG_5ApFo61Pr8Hp4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Sir can you please show us how to make ghostface mask from the scream 6',
#   'Commet_Author': '@shaikhahtesham3438',
#   'Comment_publication': '2023-12-04T06:16:55Z'},
#  {'comment_Id': 'UgxOkI-_tDVLQuYTIJh4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Realizing manike song was sung by a sri lankan 🇱🇰 girl 🙌🙌🔥🔥🔥',
#   'Commet_Author': '@TADrawings123',
#   'Comment_publication': '2023-11-12T06:58:11Z'},
#  {'comment_Id': 'UgxXuP4SUYUxpaJhi6V4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'I am a big fan of you since childhood ❤️ from Sri Lanka 🇱🇰',
#   'Commet_Author': '@ashendiluk9580',
#   'Comment_publication': '2023-11-07T07:15:01Z'},
#  {'comment_Id': 'UgzpgkpSL4XE3xbbevx4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'WOW ❤😊',
#   'Commet_Author': '@mahvishsiddiqui9750',
#   'Comment_publication': '2023-10-30T13:35:00Z'},
#  {'comment_Id': 'UgzCl7oAXQQafQ-Dy6B4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': '2023 anyone?',
#   'Commet_Author': '@ritesh981',
#   'Comment_publication': '2023-10-29T16:45:50Z'},
#  {'comment_Id': 'Ugz4qFU51u7J9LCLCq94AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'this video deservers millions of views',
#   'Commet_Author': '@shashank6255',
#   'Comment_publication': '2023-10-10T01:16:51Z'},
#  {'comment_Id': 'UgxAbZ-4x5cTb8vSgl54AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'ROB we love you 😭♥️🥹💞',
#   'Commet_Author': '@Ravali._.',
#   'Comment_publication': '2023-08-10T07:20:43Z'},
#  {'comment_Id': 'Ugyc5y7tYC0rwDAvAwt4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Bro this guy didn&#39;t even age for the past 20 year?? He looks exactly the same.',
#   'Commet_Author': '@musicandhappinessbyjo795',
#   'Comment_publication': '2023-07-23T17:57:31Z'},
#  {'comment_Id': 'UgzLXt288No9ituLwAF4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'when i was in 5th class i saw all the episodes on POGO, and now in present I really miss your show M.A.D🥹. I miss my childhood days🥺😔.',
#   'Commet_Author': '@origingaming3404',
#   'Comment_publication': '2023-07-16T05:38:24Z'},
#  {'comment_Id': 'UgwpIgiCNotf2wNQn0h4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Crazy',
#   'Commet_Author': '@ravikantarya5854',
#   'Comment_publication': '2023-07-13T12:02:03Z'},
#  {'comment_Id': 'UgySKjsS8yzr5Jn_D6J4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'You are awesome 😘',
#   'Commet_Author': '@princeraj5095',
#   'Comment_publication': '2023-07-05T06:43:29Z'},
#  {'comment_Id': 'Ugz3xyeX5kvmDmKSe4l4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'mad <br>pogo  ......',
#   'Commet_Author': '@DKWORLD-xp3mz',
#   'Comment_publication': '2023-07-04T17:26:42Z'},
#  {'comment_Id': 'UgweuCaXLlbN0MU099V4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Pogo cool dude 😊',
#   'Commet_Author': '@smrutisagarnaik6855',
#   'Comment_publication': '2023-07-02T21:34:12Z'},
#  {'comment_Id': 'UgzUl8bO3tJpY37xVbh4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'I like how Rob made her wear children friendly clothes, as opposed to original video song :p',
#   'Commet_Author': '@sztrlb123',
#   'Comment_publication': '2023-06-29T18:59:32Z'},
#  {'comment_Id': 'UgxddJXLb7ydHYBvTNF4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'brh Nora is really fat in this one<br>PLS Redo<br>Hurting nora fans',
#   'Commet_Author': '@sanskarthedumb1723',
#   'Comment_publication': '2023-06-29T08:48:21Z'},
#  {'comment_Id': 'UgwLpsjAs8EDjy1YxMp4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Love you',
#   'Commet_Author': '@Pallavmithu',
#   'Comment_publication': '2023-06-25T16:54:29Z'},
#  {'comment_Id': 'Ugzw_o3xlnoFc6SvoWR4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'can creativity level cross this ...♥️♥️',
#   'Commet_Author': '@harsh-kz9in',
#   'Comment_publication': '2023-06-23T13:03:41Z'},
#  {'comment_Id': 'UgxUo1MAiHhOtwofNex4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'I missed you and your program',
#   'Commet_Author': '@aaminaaashiq',
#   'Comment_publication': '2023-06-05T15:28:57Z'},
#  {'comment_Id': 'UgxwThKYEfuE8rjGOId4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Aap art ki book banate Ho',
#   'Commet_Author': '@neetutiwari5829',
#   'Comment_publication': '2023-06-01T02:51:21Z'},
#  {'comment_Id': 'Ugw033sL-wkYxFfEkjh4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'He was , is and always will be M.A.D 😊',
#   'Commet_Author': '@riturikideb653',
#   'Comment_publication': '2023-05-29T17:21:23Z'},
#  {'comment_Id': 'UgwLWiooi9A22y0J2g14AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'so cool',
#   'Commet_Author': '@ikskr2219',
#   'Comment_publication': '2023-05-29T13:32:42Z'},
#  {'comment_Id': 'UgyqGin720W7aaaBkwp4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Great!',
#   'Commet_Author': '@rupendrakumarsahu9084',
#   'Comment_publication': '2023-05-29T11:19:46Z'},
#  {'comment_Id': 'UgycfRKpcliznd0WqfR4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Extremely Beautiful Sir 🤩, A huge respect to you and your talent and skills',
#   'Commet_Author': '@sunitajeengar9794',
#   'Comment_publication': '2023-05-29T05:59:21Z'},
#  {'comment_Id': 'UgwgpNdl-tmMqCl1sWJ4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Good to see our childhood carfts and drawing guider',
#   'Commet_Author': '@ABCD-lh2df',
#   'Comment_publication': '2023-05-13T08:39:52Z'},
#  {'comment_Id': 'UgztIRVeCiPyUM-Snr14AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'My First Drawing Teacher <br>🥲🥲🥲🥲',
#   'Commet_Author': '@faizanshaikh708',
#   'Comment_publication': '2023-05-01T11:41:01Z'},
#  {'comment_Id': 'Ugx_hio1_wzhOBehbIp4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'two min silence for people who thinks it&#39;s real',
#   'Commet_Author': '@harshvaish5395',
#   'Comment_publication': '2023-04-08T17:25:04Z'},
#  {'comment_Id': 'UgyNaE26J1eu4LK3wLh4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Hello, why you stopped your pogo show? It was awsome',
#   'Commet_Author': '@dhunshah6489',
#   'Comment_publication': '2023-04-03T03:12:50Z'},
#  {'comment_Id': 'UgwTY_Rc4brL4nR7ss54AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': '🤣🤣🤣🔥🔥',
#   'Commet_Author': '@bithikatanny7391',
#   'Comment_publication': '2023-03-31T05:11:56Z'},
#  {'comment_Id': 'UgzrpFDt8ddRvW9Ze_V4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'legend on YouTube shorts',
#   'Commet_Author': '@raghavendra6921',
#   'Comment_publication': '2023-03-29T10:16:07Z'},
#  {'comment_Id': 'Ugw6G58Pxqmqjdvdd4l4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Only our Rob can pull it off ❤ our childhood ❤',
#   'Commet_Author': '@ForWiseByWise',
#   'Comment_publication': '2023-03-28T15:03:26Z'},
#  {'comment_Id': 'UgwAFFRPmOdGMwtbjGx4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Waoo',
#   'Commet_Author': '@pantherd7118',
#   'Comment_publication': '2023-03-25T03:06:12Z'},
#  {'comment_Id': 'UgyCSEEFD_iM6eOONFt4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'I used to watch u on pogo frm nursery to class 3rd or 4 th and now watching u first time on YouTube when I am in 12 th ... 🥺I love u mad <br>... I miss my those sweet memories before going to school in the morning when I used to have my breakfast I used to watch u on tv',
#   'Commet_Author': '@DwivediChahat',
#   'Comment_publication': '2023-03-19T17:16:24Z'},
#  {'comment_Id': 'UgzTdV5YnIVhVnNPT5p4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': '❤️✨',
#   'Commet_Author': '@iamwalker672',
#   'Comment_publication': '2023-03-02T07:52:02Z'},
#  {'comment_Id': 'UgyxXi5OGf_nivnozIl4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'I am a 90s kid, you arent aging at all !!! so happy to see you.',
#   'Commet_Author': '@riya6385',
#   'Comment_publication': '2023-01-30T05:15:34Z'},
#  {'comment_Id': 'UgzY0hlR4lscj-nrzCx4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'How is he still soo young.... 😑',
#   'Commet_Author': '@wittyladx',
#   'Comment_publication': '2023-01-28T10:58:49Z'},
#  {'comment_Id': 'UgzDEOUQiVhiTEq09VF4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Wow..',
#   'Commet_Author': '@sudeep900',
#   'Comment_publication': '2023-01-25T12:29:19Z'},
#  {'comment_Id': 'UgwvyVwkdedVcMtlxbt4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': '💕💕',
#   'Commet_Author': '@samsungtabs5e65',
#   'Comment_publication': '2023-01-20T17:05:04Z'},
#  {'comment_Id': 'Ugyj2dqUaDIIFLl05pR4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Hey Rob please make a team Titans stickers',
#   'Commet_Author': '@laadkanwar4844',
#   'Comment_publication': '2023-01-17T06:33:35Z'},
#  {'comment_Id': 'Ugyzk6yiNL_VpIrUtB94AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'big fan bro',
#   'Commet_Author': '@SAMEER00982',
#   'Comment_publication': '2023-01-14T15:56:53Z'},
#  {'comment_Id': 'UgxKolaINjVZWeSrbkZ4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': '<a href="https://youtube.com/shorts/gDkIPeL-rAo?feature=share">https://youtube.com/shorts/gDkIPeL-rAo?feature=share</a><br><br>asuna sketch',
#   'Commet_Author': '@ajvelite',
#   'Comment_publication': '2023-01-14T10:16:56Z'},
#  {'comment_Id': 'UgzEqNGS3bnjEklMhNt4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': '<a href="https://youtube.com/shorts/xB6iJT2IqN0?feature=share">https://youtube.com/shorts/xB6iJT2IqN0?feature=share</a><br><br>Guru ji🙏<br>meri skill ko review kare🙋',
#   'Commet_Author': '@ajvelite',
#   'Comment_publication': '2023-01-13T07:47:41Z'},
#  {'comment_Id': 'Ugxpb077wcbPP93ThZR4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Sir ❤️🙏🏻 mai aapko 😊 Bachpan se dekhta aa raha hu pehle aap pogo par aate thai fir aapka magic skool 🤩show bhi aaya karta tha 🙏🏻please aap dobara tv par aa sakte ho kya sir 🙏🏻',
#   'Commet_Author': '@anuj7461',
#   'Comment_publication': '2023-01-11T13:51:07Z'},
#  {'comment_Id': 'UgwgljITNqvZjhVXqIp4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Epiccc',
#   'Commet_Author': '@rahulisgreat4911',
#   'Comment_publication': '2023-01-11T06:46:30Z'},
#  {'comment_Id': 'UgxHQGdU8gQ1mo37tMl4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Dude<br>Bring back MAD!!',
#   'Commet_Author': '@lakshyavir1330',
#   'Comment_publication': '2023-01-06T17:02:38Z'},
#  {'comment_Id': 'Ugy2YJT0qBveCz7SKMx4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Rob bhaiya aap post Karoge imaging that season 4',
#   'Commet_Author': '@mohdafsharkhan7525',
#   'Comment_publication': '2023-01-02T06:31:12Z'},
#  {'comment_Id': 'Ugz3-Ph1yXA8gjPLoPR4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'We miss you rob sir <br>Please post more videos',
#   'Commet_Author': '@ninukutty',
#   'Comment_publication': '2022-12-28T07:04:30Z'},
#  {'comment_Id': 'UgzDBUuMDNC-xm0TyjB4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': '🤩 mind-blowing',
#   'Commet_Author': '@alandaniel8150',
#   'Comment_publication': '2022-12-27T05:57:09Z'},
#  {'comment_Id': 'UgwMm5_tHPcdVWT0sep4AaABAg',
#   'Video_Id': 'uMeAQ4pO_dI',
#   'Comment_Text': 'Can you tell me how to make your glue?',
#   'Commet_Author': '@no_oneisthebest5441',
#   'Comment_publication': '2022-12-24T14:00:20Z'},
#  {'comment_Id': 'UgwNkp1M0f35yRYe8Jh4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'You are mad in pogo',
#   'Commet_Author': '@shalinirajushaliniraju347',
#   'Comment_publication': '2024-01-12T06:57:26Z'},
#  {'comment_Id': 'Ugye-0jIkAWIGoB2M2N4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'I miss those days of MAD on pogo!!!',
#   'Commet_Author': '@jigarrana9688',
#   'Comment_publication': '2024-01-04T16:06:33Z'},
#  {'comment_Id': 'UgwjP64-PZvJJacXlip4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Fooled me 😅',
#   'Commet_Author': '@anthonycompton7702',
#   'Comment_publication': '2023-12-08T15:30:35Z'},
#  {'comment_Id': 'Ugwi62zuSZQeRirOFTN4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Yes because I have seen this video before on a reaction channel',
#   'Commet_Author': '@roganstargaming7647',
#   'Comment_publication': '2023-11-13T05:25:06Z'},
#  {'comment_Id': 'UgyEPmZr3l8TwsiHath4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'our childhood memories ❤ <a href="http://music.art.dance/">Music.Art.Dance</a>',
#   'Commet_Author': '@trtutorials661',
#   'Comment_publication': '2023-10-31T13:45:24Z'},
#  {'comment_Id': 'UgywG2TgziEIHoHvlDl4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': '😳',
#   'Commet_Author': '@loganayagiselvanayagam433',
#   'Comment_publication': '2023-10-29T08:10:36Z'},
#  {'comment_Id': 'UgxqgzuLenvv1503jvx4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Omg',
#   'Commet_Author': '@rizvihr9258',
#   'Comment_publication': '2023-10-27T09:20:41Z'},
#  {'comment_Id': 'UgyVa2Ji2BmjTtDZSuh4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Paper pin 📍 is drawing',
#   'Commet_Author': '@meeramishra2445',
#   'Comment_publication': '2023-10-22T12:26:16Z'},
#  {'comment_Id': 'UgwtlMnm2Edlpyl8nhB4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Song name??',
#   'Commet_Author': '@dipikakumari8411',
#   'Comment_publication': '2023-09-08T21:03:55Z'},
#  {'comment_Id': 'UgwO33H5lW0k-tbj-ul4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'At the first play I didn&#39;t even saw what was he doing 😅😅😅',
#   'Commet_Author': '@piyushjha943',
#   'Comment_publication': '2023-07-30T17:52:21Z'},
#  {'comment_Id': 'UgwVlH-DtQlgli3muex4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Bahi ab app tv par kab a rhe ho 😊😊😊',
#   'Commet_Author': '@HIGHLIGHT.GAME000',
#   'Comment_publication': '2023-07-04T07:03:08Z'},
#  {'comment_Id': 'UgzzDvIHY-zsnURq5wV4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Pin',
#   'Commet_Author': '@anime_49758',
#   'Comment_publication': '2023-07-04T03:50:47Z'},
#  {'comment_Id': 'UgwYuYfDYEo3zJkxxmJ4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'bro what colour should you',
#   'Commet_Author': '@AnuMahto-xw1dk',
#   'Comment_publication': '2023-06-17T02:29:43Z'},
#  {'comment_Id': 'Ugw3QRQvVQ2iLzRgKzh4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'I knew it',
#   'Commet_Author': '@keertiraj4975',
#   'Comment_publication': '2023-06-14T15:26:48Z'},
#  {'comment_Id': 'Ugx8gLYR8uvRBtJHTSl4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': '😎',
#   'Commet_Author': '@siddharth8103',
#   'Comment_publication': '2023-06-03T01:51:50Z'},
#  {'comment_Id': 'UgxPZSQ-cnnBhaeIMFx4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': '🤯',
#   'Commet_Author': '@nirjalthelari3398',
#   'Comment_publication': '2023-05-14T07:54:28Z'},
#  {'comment_Id': 'UgwU8nBJUs7bpfvJN_x4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'I got it before reveal 😊',
#   'Commet_Author': '@KhansistersPakistan',
#   'Comment_publication': '2023-05-11T07:56:29Z'},
#  {'comment_Id': 'Ugy2xFOJcCLKP9MbobJ4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'That pin',
#   'Commet_Author': '@shivajiravpawar709',
#   'Comment_publication': '2023-01-26T03:50:47Z'},
#  {'comment_Id': 'UgxMXrlfe-KKXltEN_J4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Love from maharastra ❤️❤️❤️',
#   'Commet_Author': '@ashmit_loner_',
#   'Comment_publication': '2023-01-24T16:57:25Z'},
#  {'comment_Id': 'UgzCUtlfpFucwDS2GEJ4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'You Fooled Me',
#   'Commet_Author': '@NoisyCloud',
#   'Comment_publication': '2022-12-27T05:29:58Z'},
#  {'comment_Id': 'UgxnSOXYIlCdyac6ECt4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Error 101 not found.',
#   'Commet_Author': '@surajbhan2334',
#   'Comment_publication': '2022-12-25T10:48:12Z'},
#  {'comment_Id': 'UgxUfj0BpEmZFbCVmM14AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': '😳',
#   'Commet_Author': '@susbg69420',
#   'Comment_publication': '2022-12-08T13:42:32Z'},
#  {'comment_Id': 'UgwISGX3R9MuftRORKR4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Clip on the paper',
#   'Commet_Author': '@devansheesharma12a8',
#   'Comment_publication': '2022-12-04T15:33:35Z'},
#  {'comment_Id': 'UgwpgtaXALvSZC3LLcp4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'never let them know your next move',
#   'Commet_Author': '@m_of_minds',
#   'Comment_publication': '2022-11-18T09:07:26Z'},
#  {'comment_Id': 'UgyRLlW-HTgsDsIUjmZ4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': '👍',
#   'Commet_Author': '@Aslamas-gp2xg',
#   'Comment_publication': '2022-10-07T12:01:41Z'},
#  {'comment_Id': 'UgzHy1R3V6La-9hjWWJ4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'can you make ben 10 watch',
#   'Commet_Author': '@MARTIN-bw7cu',
#   'Comment_publication': '2022-10-05T02:44:35Z'},
#  {'comment_Id': 'UgwkvnPdMbj-BIH-_XR4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'I rob i want to make a thing for my mother birthday',
#   'Commet_Author': '@AjaySharma-sn9bc',
#   'Comment_publication': '2022-10-04T10:11:37Z'},
#  {'comment_Id': 'Ugw7pup9uUSUO6GTjGp4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Oh yeah! The paper pin on the sheet is a drawing.<br>I used to watch Mad on Pogo in my childhood, don&#39;t know why such a great and wonderful show stop but  really happy to see you again..... after a long time And really eager to watch your show, your amazing and mad creative work again☺️<br>Sir,I always impressed by your amazing ideas and hope I am going to learn a lot from you again...<br>Rob! You always rob our heart 💖and no doubt definitely you are going to rob our heart again...',
#   'Commet_Author': '@suman9510',
#   'Comment_publication': '2022-10-02T14:04:10Z'},
#  {'comment_Id': 'Ugw0jnNue8B6DdhuT0V4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'The pin in the top right corner',
#   'Commet_Author': '@darshiljani3117',
#   'Comment_publication': '2022-10-01T15:20:43Z'},
#  {'comment_Id': 'UgxFOE_PTAiQpG_rWSN4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': '🔥',
#   'Commet_Author': '@shresthshanker6200',
#   'Comment_publication': '2022-09-29T04:28:51Z'},
#  {'comment_Id': 'UgzGo6AHnG2slIyZjal4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'I also had your mad merch set at that time my uncle gifted me',
#   'Commet_Author': '@vasualpaca4709',
#   'Comment_publication': '2022-09-26T22:52:44Z'},
#  {'comment_Id': 'UgwWjZlaQeMpewaY5M94AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'I&#39;m soo happy to see u grow like this I still remember you making huge drawings with any objects omg that could be soo hectic',
#   'Commet_Author': '@vasualpaca4709',
#   'Comment_publication': '2022-09-26T22:50:31Z'},
#  {'comment_Id': 'UgzVjgmtgabJRpOYXfp4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Bro if u see this Commet I&#39;m following you from my childhood mad tv show I made many things because of u at childhood now I don&#39;t have tv but I was soo happy to find u here .',
#   'Commet_Author': '@vasualpaca4709',
#   'Comment_publication': '2022-09-26T22:49:17Z'},
#  {'comment_Id': 'UgyLXOfhFxmomStw0bF4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Paper pin and youtube shorts card',
#   'Commet_Author': '@vasualpaca4709',
#   'Comment_publication': '2022-09-26T22:47:15Z'},
#  {'comment_Id': 'UgxOpZGlgB0UmSBIWm54AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'please how to make mobile stand on pvc pipe',
#   'Commet_Author': '@yashpatel891',
#   'Comment_publication': '2022-09-26T05:11:47Z'},
#  {'comment_Id': 'Ugz77rjIWehbKp8ZkWd4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'cringe - affan subhani better',
#   'Commet_Author': '@nasty2654',
#   'Comment_publication': '2022-09-25T21:54:20Z'},
#  {'comment_Id': 'UgwIzJLg7gTyJI8dI5B4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Rob love  from Tripura 😎❤️👍',
#   'Commet_Author': '@artandfightwithpgx',
#   'Comment_publication': '2022-09-25T17:20:57Z'},
#  {'comment_Id': 'UgysjlPTbbEtcc04og94AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Am here bcz of my childhood memories 😫😫😫😣😭😭😭',
#   'Commet_Author': '@Furqan485',
#   'Comment_publication': '2022-09-19T16:32:53Z'},
#  {'comment_Id': 'UgywZ_f0yDNXHfUansR4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'The white mark 😃',
#   'Commet_Author': '@shahriarapurba7400',
#   'Comment_publication': '2022-09-18T16:49:51Z'},
#  {'comment_Id': 'UgyxkQ6UoJ_DRAaGdvt4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'The pin',
#   'Commet_Author': '@pallabroy8800',
#   'Comment_publication': '2022-09-18T13:16:34Z'},
#  {'comment_Id': 'UgyBHlf_fM66MD8F_iZ4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Sir can you show us how to make rings at home or how to etch rings or how to make HDPE accessories please .',
#   'Commet_Author': '@FORKURO2718',
#   'Comment_publication': '2022-09-17T14:35:39Z'},
#  {'comment_Id': 'Ugy00sWCq3iEF6Ev6d54AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'I still didn&#39;t get it',
#   'Commet_Author': '@yashjit',
#   'Comment_publication': '2022-09-17T10:44:40Z'},
#  {'comment_Id': 'UgyC2cv4Eg9IUTKB0-94AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Sir make your pogo drawings or old memories',
#   'Commet_Author': '@FK_gamer10',
#   'Comment_publication': '2022-09-15T08:13:48Z'},
#  {'comment_Id': 'UgwNyHNwsNvDrZ6Qcep4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Make thor hammer stormbraker',
#   'Commet_Author': '@triggered_tanzee6501',
#   'Comment_publication': '2022-09-15T06:10:29Z'},
#  {'comment_Id': 'UgzxlDPpE1TUuQzbMOF4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': '😶😶',
#   'Commet_Author': '@JOYLAD',
#   'Comment_publication': '2022-09-14T17:47:04Z'},
#  {'comment_Id': 'Ugz8yF7XxjIG83-K69t4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Yes',
#   'Commet_Author': '@Yugth',
#   'Comment_publication': '2022-09-14T10:49:19Z'},
#  {'comment_Id': 'UgyjRQoLTwlsonN4RWt4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Hi sir can you make Maharana Pratap  hilmat armour in cardboard plz',
#   'Commet_Author': '@maeshpawar107',
#   'Comment_publication': '2022-09-12T17:13:03Z'},
#  {'comment_Id': 'UgyaFzqyyuiCWJ1CnJZ4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': '👋  hi',
#   'Commet_Author': '@PoojaSingh-fh8dr',
#   'Comment_publication': '2022-09-12T10:52:14Z'},
#  {'comment_Id': 'UgxhbO9dG6FPBqn04hV4AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Please  draw goku',
#   'Commet_Author': '@rahulkumarsharma1688',
#   'Comment_publication': '2022-09-12T08:07:15Z'},
#  {'comment_Id': 'Ugy4628-3AF2STG7Dk94AaABAg',
#   'Video_Id': 'df3regswjQI',
#   'Comment_Text': 'Huh rob are u crazy i found that in one second',
# ...
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Imagine getting a star from rob sir',
#   'Commet_Author': '@diyagarg4818',
#   'Comment_publication': '2021-03-23T12:47:44Z'},
#  {'comment_Id': 'UgwsUYFzcduLcoZ4MrB4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Rob, why you stopped the imagine that show',
#   'Commet_Author': '@WeebAce',
#   'Comment_publication': '2021-03-23T11:19:38Z'},
#  {'comment_Id': 'UgyB0lI-hYV_UlMDM2J4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Make a wall stickers ❤️',
#   'Commet_Author': '@vanshgurjar4977',
#   'Comment_publication': '2021-03-23T08:57:35Z'},
#  {'comment_Id': 'UgzC_ziaGWvOrbBtUm14AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Rob can you do something related to Justice League Zack Snyder cut',
#   'Commet_Author': '@ashakunder2931',
#   'Comment_publication': '2021-03-23T07:23:04Z'},
#  {'comment_Id': 'Ugy5OiKqpvLE3OVAUQh4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Rob brother please PIN this comment,  it&#39;s my Wish!!   Pleaseee',
#   'Commet_Author': '@assassings3030',
#   'Comment_publication': '2021-03-22T13:31:37Z'},
#  {'comment_Id': 'UgzMpErc6sekIzVlygt4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'You are a talented guy  👏 ❤',
#   'Commet_Author': '@devanshiprasad8710',
#   'Comment_publication': '2021-03-22T10:19:21Z'},
#  {'comment_Id': 'UgxUkrWFoppUOe0PBIp4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Anything new?',
#   'Commet_Author': '@geetanjali1970',
#   'Comment_publication': '2021-03-22T08:43:59Z'},
#  {'comment_Id': 'Ugz1zdHXMQzGAkSQh-d4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'pls put some crafts',
#   'Commet_Author': '@divyam_agarwal',
#   'Comment_publication': '2021-03-22T06:42:09Z'},
#  {'comment_Id': 'UgzKX_M_VpgNofcUWUF4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'BMW lite 😁😁',
#   'Commet_Author': '@jerrymayank2832',
#   'Comment_publication': '2021-03-21T18:06:27Z'},
#  {'comment_Id': 'UgzEq7rTWHmy629fM3B4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Sir title me back to basics hai magar pehle wala <b>Rob</b> kaha hai sir????<br>Come back karne ki jarurat hai <a href="http://www.youtube.com/results?search_query=%23supportrob">#supportRob</a>',
#   'Commet_Author': '@shashwatojha7213',
#   'Comment_publication': '2021-03-21T16:30:48Z'},
#  {'comment_Id': 'UgxL8d4h8sCYdRX3REp4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Your mobile number',
#   'Commet_Author': '@satishchangude3386',
#   'Comment_publication': '2021-03-21T07:32:02Z'},
#  {'comment_Id': 'Ugxv5wvbyl5zw5Ni0654AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Make a video on DIY Monoeraser',
#   'Commet_Author': '@nizamuddinnizam4538',
#   'Comment_publication': '2021-03-21T07:26:45Z'},
#  {'comment_Id': 'UgzKVEszCb6DUz7ho254AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Please do some Harry Potter diy 😭❤️',
#   'Commet_Author': '@bristimanna9606',
#   'Comment_publication': '2021-03-21T06:54:00Z'},
#  {'comment_Id': 'Ugy93sNqL0pZzXB57W14AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Hello iam shreshth and I am 10 year old .I like your all vedio.<br>Can I get heart in this comment',
#   'Commet_Author': '@shreshthpatel3947',
#   'Comment_publication': '2021-03-21T06:37:36Z'},
#  {'comment_Id': 'UgwrH6RiKyecI1qzs9l4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Aapka drawing to Disney me bhi aati ha na',
#   'Commet_Author': '@warboys609',
#   'Comment_publication': '2021-03-21T05:26:53Z'},
#  {'comment_Id': 'UgwUs3qR9lf9BErt3_14AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Wow Rob bhaiyya your imagination and creativity is amazing.',
#   'Commet_Author': '@chandrakalamusale4240',
#   'Comment_publication': '2021-03-21T03:33:38Z'},
#  {'comment_Id': 'UgzsnrZfENw88ky5VUp4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Me at the beginning: what&#39;s app special there it&#39;s just a toy car....<br>Me at the ending: uh😶',
#   'Commet_Author': '@7N8173',
#   'Comment_publication': '2021-03-20T11:33:39Z'},
#  {'comment_Id': 'UgzzhRaPWmvcdm3-3p14AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'You are super talented Rob sir👍🏻👌 your<br>D.i.ys are are awesome . God bless you 😇',
#   'Commet_Author': '@yashburbadkar5524',
#   'Comment_publication': '2021-03-20T11:32:20Z'},
#  {'comment_Id': 'Ugw19NbuPx8cT3eibkB4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'SIR THIS IS MY HUMBLE REQUEST TO YOU make a video on the topic  [WHY Can&#39;t WE Draw What WE SEE in OUR mind] PLEASE SIR .',
#   'Commet_Author': '@nightcoreoriginals',
#   'Comment_publication': '2021-03-20T10:08:53Z'},
#  {'comment_Id': 'Ugy0fFL7WB5ygo5X2Ht4AaABAg',
#   'Video_Id': 'Zb21vAf5GfA',
#   'Comment_Text': 'Hey Rob plz check your email I have sent one.........',
#   'Commet_Author': '@urvashidhabale1813',
#   'Comment_publication': '2021-03-20T09:58:41Z'},
#  {'comment_Id': 'Ugx2VC5dKc8k-nNHnVF4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Osssm! ❤ pal 👏👏',
#   'Commet_Author': '@tej_aks',
#   'Comment_publication': '2023-11-10T05:14:04Z'},
#  {'comment_Id': 'UgwUEu4hh9y-f80Zpwd4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Bruce lee drawing nice 👍👍 bhaiya apko yad hai selo colour of present Disney imagen that 😁😁😁🙂',
#   'Commet_Author': '@Monsterhannat',
#   'Comment_publication': '2023-09-21T13:10:09Z'},
#  {'comment_Id': 'Ugz0wkxxN8lN4zp3Nel4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Cool 😎😘😘😘😘😘😘 I love it 🤠😻🤠😻',
#   'Commet_Author': '@MohammadFarooq-gr5kd',
#   'Comment_publication': '2023-09-11T08:23:57Z'},
#  {'comment_Id': 'Ugy9sUzSaWPMbPgSg-l4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Bro this man really deserves a lot of likes than he has got',
#   'Commet_Author': '@WANKER_69',
#   'Comment_publication': '2023-06-12T03:48:29Z'},
#  {'comment_Id': 'UgyWi1JmqGYrUSYGgeZ4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Bruce Lee 💖🙃❤️💕🌹',
#   'Commet_Author': '@parul_sharmaA',
#   'Comment_publication': '2022-11-13T07:09:31Z'},
#  {'comment_Id': 'UgyLKJi_hIm5eossItJ4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Cool 😎  ²⁰⁹²²',
#   'Commet_Author': '@lainpadang8033',
#   'Comment_publication': '2022-09-20T10:56:02Z'},
#  {'comment_Id': 'Ugzw6sqHC-E1WXXB4_94AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Superb',
#   'Commet_Author': '@susheelkanwarkhangarot9118',
#   'Comment_publication': '2022-08-19T09:25:40Z'},
#  {'comment_Id': 'UgxEBX6O2yQ-2jUFawd4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Wow bruce lee fan here. I love his quots',
#   'Commet_Author': '@muhammedhafan961',
#   'Comment_publication': '2022-06-08T16:17:08Z'},
#  {'comment_Id': 'UgySNLqss36pzYdImh14AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Sir please give a tutorial for this.<br>And from heart you are super aartist',
#   'Commet_Author': '@monikagangrade1978',
#   'Comment_publication': '2022-05-02T17:59:52Z'},
#  {'comment_Id': 'UgxTdakYgz6LKTR3qlp4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'If water drunken by Bruce Lee and Rob <br>It becomes Bruce rob',
#   'Commet_Author': '@hangonhope9706',
#   'Comment_publication': '2022-02-01T11:59:43Z'},
#  {'comment_Id': 'Ugz88alEj0aAf8JHG8B4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'You literally made my childhood, so happy to see you on yt!! 😁',
#   'Commet_Author': '@gunesh6694',
#   'Comment_publication': '2022-01-24T10:17:57Z'},
#  {'comment_Id': 'UgzoRyYn8ljf44Pb7WR4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'I am 13 now and i started watching you scince i was 7 i know not a lot of years but time flies by it felt like yesterday you gave me the inspiration to draw and do diy&#39;s i miss you on pogo good days',
#   'Commet_Author': '@rice9908',
#   'Comment_publication': '2022-01-09T18:11:50Z'},
#  {'comment_Id': 'UgwPLHRCgu79v6tI-aR4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': '❤️',
#   'Commet_Author': '@subhadeepgan',
#   'Comment_publication': '2022-01-05T17:06:32Z'},
#  {'comment_Id': 'Ugy61CQhirVAGRjA62x4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Please come again on pogo',
#   'Commet_Author': '@harshpanchal5992',
#   'Comment_publication': '2021-12-15T11:20:41Z'},
#  {'comment_Id': 'UgyYpS1gnWcrjzY58t14AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Bruslee',
#   'Commet_Author': '@rameshamdavadia5269',
#   'Comment_publication': '2021-11-27T14:28:19Z'},
#  {'comment_Id': 'UgzA6Fuzh_qm5XZtyN94AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'ROB is just great!!!',
#   'Commet_Author': '@meninges340',
#   'Comment_publication': '2021-11-22T16:33:21Z'},
#  {'comment_Id': 'Ugx5rg_lwEva8hMKfBR4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Rob jab app ka purana show ata tha tab mai bacha tha abb bata hu bhot acha show tha 😀❤️',
#   'Commet_Author': '@Alicee_eeee',
#   'Comment_publication': '2021-11-18T09:06:14Z'},
#  {'comment_Id': 'Ugyj_mNfGLOock6AcZJ4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Wonderful✨😍✨😍✨😍✨😍✨😍',
#   'Commet_Author': '@cadetrupantardas4097',
#   'Comment_publication': '2021-11-17T03:39:29Z'},
#  {'comment_Id': 'UgxzV-xDjuUmh0EFR_B4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Omg',
#   'Commet_Author': '@samiyaali7135',
#   'Comment_publication': '2021-11-15T10:22:51Z'},
#  {'comment_Id': 'UgxNHBRff2ExJHOYjpV4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Hi Rob',
#   'Commet_Author': '@sourajitkalsi9616',
#   'Comment_publication': '2021-11-15T04:48:58Z'},
#  {'comment_Id': 'UgxmfHznEhEMGtrKMVh4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'He never fails to amaze❤️',
#   'Commet_Author': '@smitisudhapatra2112',
#   'Comment_publication': '2021-10-30T19:35:39Z'},
#  {'comment_Id': 'UgxcEH3F9Qf5KsUFzJl4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': '🔥🔥🔥',
#   'Commet_Author': '@Baljeet_12',
#   'Comment_publication': '2021-10-27T10:08:35Z'},
#  {'comment_Id': 'UgzgPAQO-YHOek7Wjd14AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Iron man darwing',
#   'Commet_Author': '@adarshmote1105',
#   'Comment_publication': '2021-10-21T13:04:44Z'},
#  {'comment_Id': 'UgwKpmP8aSutM-UM25h4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Which country are you',
#   'Commet_Author': '@kavetypriyanka8088',
#   'Comment_publication': '2021-10-15T07:04:02Z'},
#  {'comment_Id': 'UgylLFbCB7qmTyvex094AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Hi rob',
#   'Commet_Author': '@drivedeepgameplay7133',
#   'Comment_publication': '2021-10-12T09:29:05Z'},
#  {'comment_Id': 'UgyIZF8c6D6aJb2NRDJ4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'The legend rob',
#   'Commet_Author': '@brotherartgallery6456',
#   'Comment_publication': '2021-10-11T05:44:07Z'},
#  {'comment_Id': 'UgwtMy9ZbPE4OnQM4rV4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Legends knows legends',
#   'Commet_Author': '@yashrajnimse',
#   'Comment_publication': '2021-10-04T17:11:51Z'},
#  {'comment_Id': 'UgzU-UR4vHJF31_iU2t4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'you draw a free fire CHARECTER Kelly',
#   'Commet_Author': '@a__666',
#   'Comment_publication': '2021-09-30T18:50:21Z'},
#  {'comment_Id': 'UgzKFU1pM3HjchGfaHl4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'It&#39;s amazing 🔥🔥',
#   'Commet_Author': '@manasgupta932',
#   'Comment_publication': '2021-09-30T16:40:18Z'},
#  {'comment_Id': 'Ugxxqq9rukAwPxHj6Qt4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Before I even knew Bob Ross. I knew Rob. First inspiration towards Arts. You are my favourite Rob 👍🏼',
#   'Commet_Author': '@MaryamsWorldofArt',
#   'Comment_publication': '2021-09-28T14:17:50Z'},
#  {'comment_Id': 'UgwJGpYYWgklckz7opt4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': '<a href="https://youtu.be/GZkwbogdxrc">https://youtu.be/GZkwbogdxrc</a>',
#   'Commet_Author': '@rohitkhengare3859',
#   'Comment_publication': '2021-09-25T08:29:04Z'},
#  {'comment_Id': 'Ugya23z3PvOdWyq51S54AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'I LOVE BRUCE LEE',
#   'Commet_Author': '@roronoazoro.__.',
#   'Comment_publication': '2021-09-23T14:45:03Z'},
#  {'comment_Id': 'UgzqzcqWUYWwWm0q4-N4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Imaine that',
#   'Commet_Author': '@MasterJen',
#   'Comment_publication': '2021-09-23T04:40:11Z'},
#  {'comment_Id': 'UgzT-Nxm0f-cSjvkAV94AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'UP mein Kartik ji wale hai na',
#   'Commet_Author': '@ak__47__gamer76',
#   'Comment_publication': '2021-09-20T15:55:56Z'},
#  {'comment_Id': 'UgwCgnqLLF33XLMPswR4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'It was just a fantastic 🤓',
#   'Commet_Author': '@A.V.K_SPACE',
#   'Comment_publication': '2021-09-16T05:41:24Z'},
#  {'comment_Id': 'Ugzg38KSancHEzLlAg54AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'I love you',
#   'Commet_Author': '@rojasabbani5599',
#   'Comment_publication': '2021-09-13T14:26:19Z'},
#  {'comment_Id': 'Ugy7V3k435EhteRVbxt4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Bhai aap imaginary Mein Aate the na',
#   'Commet_Author': '@karnaisingh5545',
#   'Comment_publication': '2021-09-13T13:34:35Z'},
#  {'comment_Id': 'Ugx8-CSj_Upi0ts2JYV4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'So soooo sooooooo easy for me and ur coca cola painting was very nice but easy and this drawing is wonderful',
#   'Commet_Author': '@cutekhanakandkhushvi9428',
#   'Comment_publication': '2021-09-13T06:51:32Z'},
#  {'comment_Id': 'UgxVs4FEBNsAum6ffkh4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'How about coming back to imagine that 2',
#   'Commet_Author': '@ghf79',
#   'Comment_publication': '2021-09-08T18:18:17Z'},
#  {'comment_Id': 'UgzLQ8o6aOxu-egvjXl4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Amazing😍👍',
#   'Commet_Author': '@chavdaayushi3816',
#   'Comment_publication': '2021-09-05T14:31:07Z'},
#  {'comment_Id': 'UgztKt1x2X4p4jTRVG54AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Following you since childhood sir...love your creativity ❤️',
#   'Commet_Author': '@highfivesumit',
#   'Comment_publication': '2021-09-04T14:20:26Z'},
#  {'comment_Id': 'Ugw9GbEMtMtOpv3c1qF4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Legendary dialog by bruselee...<br><br>Amagine a like by rob..our childhood  hero😙♥️',
#   'Commet_Author': '@jeonsyn1742',
#   'Comment_publication': '2021-09-04T13:37:07Z'},
#  {'comment_Id': 'Ugwp0NdrKtdAWHFqCE94AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'I am you big fan rob every day I see you TV show you are really talented 🙂',
#   'Commet_Author': '@krishanukarmakar9309',
#   'Comment_publication': '2021-09-04T10:51:17Z'},
#  {'comment_Id': 'UgxQ0g3LikcjwPFQ-kd4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Pogo channel',
#   'Commet_Author': '@zippy2196',
#   'Comment_publication': '2021-09-01T13:22:10Z'},
#  {'comment_Id': 'UgzEjCQnMRc0ufP56514AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Aap mast baneto ho😎😎🤗😇',
#   'Commet_Author': '@stargaming2452',
#   'Comment_publication': '2021-08-31T15:31:18Z'},
#  {'comment_Id': 'Ugw0K234SI5AIahf1fV4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Your my fewarate art master but isee in pogo rv',
#   'Commet_Author': '@sabikhmuhammed8421',
#   'Comment_publication': '2021-08-31T14:18:09Z'},
#  {'comment_Id': 'UgzszfHDzfVPZbfsf6R4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Such a long time seeing Rob',
#   'Commet_Author': '@shashibhagwat',
#   'Comment_publication': '2021-08-31T06:50:03Z'},
#  {'comment_Id': 'UgyCXSQYOHUQXCgiV_Z4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Can I draw like that I am 10 years old',
#   'Commet_Author': '@monikapal4847',
#   'Comment_publication': '2021-08-16T01:38:09Z'},
#  {'comment_Id': 'UgzppyG-mrvjRMub9X14AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'Bruce Lee was just amazing 🤩 🤩🤩🤩',
#   'Commet_Author': '@JUSTMAKET05',
#   'Comment_publication': '2021-06-27T03:43:56Z'},
#  {'comment_Id': 'Ugy06fJPqFt1mhaW6sB4AaABAg',
#   'Video_Id': 'lM_Sk8biVco',
#   'Comment_Text': 'An artist painting an artist 👨\u200d🎨👌👌',
#   'Commet_Author': '@somilagrawal9028',
#   'Comment_publication': '2021-06-23T15:56:11Z'},
#  ...]

# %%
# Function To Fetch All Playlists Information Of The Channel

def get_playlist_info(channel_id):
    next_page_token = None
    p_data = []
    while True:
        request = youtube.playlists().list(
            part = 'snippet,contentDetails',
            channelId = channel_id,
            maxResults = 50,
            pageToken = next_page_token
        )
        response = request.execute()

        for item in response['items']:
            playlist_data = dict(Playlist_Id = item['id'],
                                Channel_Id = item['snippet']['channelId'],
                                Title = item['snippet']['title'],
                                Channel_Name = item['snippet']['channelTitle'],
                                PublishedAt = item['snippet']['publishedAt'],
                                Video_Count = item['contentDetails']['itemCount'])
            p_data.append(playlist_data)

        next_page_token = response.get('nextPageToken')   
        if next_page_token is None:
            break
    return p_data

# %%
playlist_details = get_playlist_info('UCT8FGLq9AU1H6U3ePhegxJA')

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PLzl205uwoTCA34RkR24xTEXpdoND80DP9',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': '#CreateWithAlpenliebe and Rob',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2021-12-11T10:36:50Z',
#   'Video_Count': 8},
#  {'Playlist_Id': 'PLzl205uwoTCBxk-ey-hW4J44ULop0YxVE',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': '#FavouriteDIYsWithMe',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2020-03-26T10:54:30Z',
#   'Video_Count': 11},
#  {'Playlist_Id': 'PLzl205uwoTCB0IWHWqhSJKR0mix6ZLOoM',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'My Love For Marvel',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2019-07-17T06:56:02Z',
#   'Video_Count': 29},
#  {'Playlist_Id': 'PLzl205uwoTCCIXbLSoPsGyAbbggDosNIL',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Me & My Friends',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2019-07-17T05:42:55Z',
#   'Video_Count': 28},
#  {'Playlist_Id': 'PLzl205uwoTCD-qTQ7nPMNtifIgT9fP9nK',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'DIY for Festivals & Special Days',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2019-07-16T14:06:12Z',
#   'Video_Count': 26},
#  {'Playlist_Id': 'PLzl205uwoTCApYcCv5gtxnG02o9ayVbk0',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Speed Paintings',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2019-07-16T13:17:45Z',
#   'Video_Count': 12},
#  {'Playlist_Id': 'PLzl205uwoTCADJA2n1ADrPnspglSn__d7',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Easy DIY for kids',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2019-07-16T12:43:15Z',
#   'Video_Count': 153},
#  {'Playlist_Id': 'PLzl205uwoTCBVFdTHf9zT-eNFGEDxcoye',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': '\'How To Make" Superhero DIY\'s - in Hindi',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2019-06-26T11:05:31Z',
#   'Video_Count': 12},
#  {'Playlist_Id': 'PLzl205uwoTCBUfQmak96JhSFqlyCOJOFJ',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': '"How to make" Superhero DIYs - In English',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2019-05-02T08:29:18Z',
#   'Video_Count': 27},
#  {'Playlist_Id': 'PLzl205uwoTCBRQjd1rnlZTdKOKnx6CkdM',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': "Imaginarium - It's A Wonderful World | India's First Live Art Show",
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2018-11-22T14:10:31Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLzl205uwoTCCTRBibXGNKBXDZUmfcMe4h',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob - Diwali Special',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2018-11-02T06:55:09Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PLzl205uwoTCAhtqatj3yfERY11RyYb7H5',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Easy DIY Projects for Summer Vacations',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2018-04-25T21:37:48Z',
#   'Video_Count': 55},
#  {'Playlist_Id': 'PLzl205uwoTCCCA0wvvKp54lH9TWSWmhrW',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': "April Fool's Day DIY Pranks",
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2018-03-09T17:14:32Z',
#   'Video_Count': 8},
#  {'Playlist_Id': 'PLzl205uwoTCDOtSBkoPMdZJIY9fOCnhvO',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Most Popular "How to make" (DIY) Videos',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2018-02-22T19:28:02Z',
#   'Video_Count': 31},
#  {'Playlist_Id': 'PLzl205uwoTCBPscISDRyQ3jTnegNu5mRC',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'How-to DIYs for Christmas',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2017-12-17T07:17:37Z',
#   'Video_Count': 8},
#  {'Playlist_Id': 'PLzl205uwoTCD-UpXiFTRFeMBvn9_UT9d2',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Halloween Special | DIY Videos',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2017-10-30T07:01:49Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLzl205uwoTCDNP5LUhJ32R_e3ADe61PH3',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': '#DoGoodBeGood - YouTube Kids Playlist',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2017-08-31T07:13:52Z',
#   'Video_Count': 21},
#  {'Playlist_Id': 'PLzl205uwoTCCY9SnErWyT1lpIOYKq2tjX',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob - Vlogs',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2017-02-24T09:27:19Z',
#   'Video_Count': 12},
#  {'Playlist_Id': 'PLzl205uwoTCB98_hSbQrGRd4wXm9dWW1y',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob - Challenges!',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2017-02-24T08:13:15Z',
#   'Video_Count': 11},
#  {'Playlist_Id': 'PLzl205uwoTCAmjN375PmUhfg7V5F2bQr1',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Build With Hot Wheels',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2016-11-03T09:27:32Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLzl205uwoTCA_o5g9WD1qUk_rgNmB_fjV',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff with Rob - Specials',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2016-10-27T13:28:41Z',
#   'Video_Count': 25},
#  {'Playlist_Id': 'PLzl205uwoTCBvFrj6s5ZdTPEeDwCJBNhf',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Easy DIY For Kids',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2016-10-26T09:13:09Z',
#   'Video_Count': 52},
#  {'Playlist_Id': 'PLzl205uwoTCBB-KbMbITNrh9nRXFIerPZ',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob - Telugu',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2016-08-10T11:36:53Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLzl205uwoTCClPVDLCYXjkcSEYg2nRW0E',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob - Tamil',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2016-08-10T11:35:43Z',
#   'Video_Count': 9},
#  {'Playlist_Id': 'PLzl205uwoTCDhpaVaoP-d9yRWSvAmHMFY',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob - Hindi',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2016-08-10T11:35:14Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLzl205uwoTCDQRdu7avnCehfvaFaWjFmQ',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob Vlogs',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2016-02-20T12:06:34Z',
#   'Video_Count': 11},
#  {'Playlist_Id': 'PLzl205uwoTCDoMDuaGirDWbdYzxRHudlT',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob Shorts - All under one minute!',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2015-05-12T07:54:05Z',
#   'Video_Count': 15},
#  {'Playlist_Id': 'PLzl205uwoTCA5koSBBhZNWBhumN5cnZGJ',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob - Special stuff for special days',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2014-11-10T12:09:32Z',
#   'Video_Count': 27},
#  {'Playlist_Id': 'PLzl205uwoTCBn7p47j6Nko-AFTU6UvOhE',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Rob and the Mob!',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2014-11-10T12:08:25Z',
#   'Video_Count': 28},
#  {'Playlist_Id': 'PLzl205uwoTCBd3IpLTKqSyZzLEBtInGVH',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'How-to tutorials on Room Decor DIY ideas for adults',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2014-11-10T12:05:35Z',
#   'Video_Count': 78},
#  {'Playlist_Id': 'PLzl205uwoTCC-s9n11sGmTA2jJl6aw3mp',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff With Rob - PrankTank',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2014-11-10T12:03:53Z',
#   'Video_Count': 8},
#  {'Playlist_Id': 'PLzl205uwoTCAXtqOJl76DCPEG87uFyKeF',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Mad Stuff with Rob - Drawsome Awesome',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2014-11-10T12:02:09Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PLzl205uwoTCCIN52JrpDcxk7CIzaKLqyv',
#   'Channel_Id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'Title': 'Latest Uploads',
#   'Channel_Name': 'Mad Stuff With Rob',
#   'PublishedAt': '2014-11-10T11:32:13Z',
#   'Video_Count': 209}]

# %%
# Connecting To MongoDB For YouTube Data Storage

client = pymongo.MongoClient("mongodb+srv://paarthasarathyrengasamy:sarathyr@cluster0.nijfyq8.mongodb.net/?retryWrites=true&w=majority")

db = client["youtube_collection_data"]

# %%
# Complete YouTube Data Insertion

def channel_details(channel_id):
    channel_info = get_channel_info(channel_id)
    playlist_info = get_playlist_info(channel_id)
    video_ids = get_videos_ids(channel_id) 
    video_info = get_video_info(video_ids)
    comment_info = get_comment_info(video_ids)

    data_collection = db['channel_details']
    data_collection.insert_one({"channel_information" : channel_info, "playlist_information" : playlist_info,
                      "video_information" : video_info, "comment_information" : comment_info })
    
    return "upload completed successfully"

# %%
# Inserting YouTube Channels into MongoDB

insert = channel_details("UCn9l4gU5mkmmlC2eiVu0LHw")

# %% [markdown]
# 1. Mad Stuff With Rob = UCT8FGLq9AU1H6U3ePhegxJA
#
# 2. Tushar Lall = UCbpLD76CnWWZ-JqZ9LjR2Mw
#
# 3. Maron 5 = UCBVjMGOIkavEAhyqpxJ73Dw
#
# 4. Rithu rocks = UC5wuaJnklgYnbJIeTVhPWug
#
# 5. Cars Town - Cartoons for kids = UCs111c1zLU8CGntT6cePyxg
#
# 6. AutoTrend தமிழ் Channel = UCNGGMSKukkLMxWwtjzrohgg
#
# 7. Bazylland - Tractors & Excavators = UCfI1cD9PdHiz1gIwRkFVcrA
#
# 8. Vlad and Niki = UCvlE5gTbOvjiolFlEm-c_Ow
#
# 9. Cooks and Crafts Magic = UC9zuXnuJOp2MnMAd8shpmEw
#
# 10. Grizzy & the Lemmings = UCn9l4gU5mkmmlC2eiVu0LHw

# %%
insert
# Out:
# 'upload completed successfully'

# %%
# All Channel Information

channel_list = []
db = client["youtube_collection_data"]
data_collection = db['channel_details']
for ch_data in data_collection.find({}, {"_id": 0, "channel_information": 1}):  # Correct the field name
    print(ch_data["channel_information"])
# Out:
# {'channel_name': 'Mad Stuff With Rob', 'channel_id': 'UCT8FGLq9AU1H6U3ePhegxJA', 'channel_description': "hey Guys! You might remember me from M.A.D. on POGO but I have now started my own YouTube journey. So for all those who want to catch up on the new stuff that I've been doing then I suggest you subscribe! I upload a new DIY video every week. So stay tuned!\n\nHappy DIY-ing!\n\nYouTube - http://www.youtube.com/user/madstuffwithrob\nFacebook - https://www.facebook.com/artguyrob\nInstagram - http://instagram.com/artguyrob\n\n\n", 'channel_playlist': 'UUT8FGLq9AU1H6U3ePhegxJA', 'channel_viewcount': '164534912', 'channel_subcribers': '2460000', 'channel_videocount': '473'}
# {'channel_name': 'Tushar Lall', 'channel_id': 'UCbpLD76CnWWZ-JqZ9LjR2Mw', 'channel_description': 'Arranger. Composer. Producer- Indian Jam Project\nWork - tusharlall02@gmail.com', 'channel_playlist': 'UUbpLD76CnWWZ-JqZ9LjR2Mw', 'channel_viewcount': '31316435', 'channel_subcribers': '363000', 'channel_videocount': '53'}
# {'channel_name': 'Maroon 5', 'channel_id': 'UCBVjMGOIkavEAhyqpxJ73Dw', 'channel_description': 'Welcome to the Maroon 5 official Youtube Channel. Head to our website for more info- www.maroon5.com', 'channel_playlist': 'UUBVjMGOIkavEAhyqpxJ73Dw', 'channel_viewcount': '23385326594', 'channel_subcribers': '36800000', 'channel_videocount': '176'}
# {'channel_name': 'Rithu Rocks', 'channel_id': 'UC5wuaJnklgYnbJIeTVhPWug', 'channel_description': '" Rithu Rocks "\nRithu Rocks channel is all about Entertainment in Tamil. Variety of video content that will make people entertained.\n\nA huge love to all our subscribers and fans. We are overwhelmed by your response.\n\nFor business enquiries and brand collaborations.\nPlease email us at\n rithurocksbranding@gmail.com\n\n', 'channel_playlist': 'UU5wuaJnklgYnbJIeTVhPWug', 'channel_viewcount': '281607105', 'channel_subcribers': '2490000', 'channel_videocount': '38'}
# {'channel_name': 'Cars Town - Cartoons for kids', 'channel_id': 'UCs111c1zLU8CGntT6cePyxg', 'channel_description': 'Welcome to the best cartoons channel for kids - Cars Team Cartoons - Cartoons for Kids ! Here you can watch long cartoons about all the kinds of cars: Monster Trucks, Trucks, Garbage Trucks, Excavators, Tow Trucks and Tractors, Police cars, Fire Trucks, Bulldozers and many others. Series of 20 + Minutes, every day updates. Funny cars compilations. Enjoy the colorful, bright, interesting and super positive kids friendly cartoons. We care about your child and will do our best to make him happy. Enjoy new cartoons every day. Subscribe and leave your comments to improve our work. Have a nice time on our channel.', 'channel_playlist': 'UUs111c1zLU8CGntT6cePyxg', 'channel_viewcount': '25138053', 'channel_subcribers': '298000', 'channel_videocount': '37'}
# {'channel_name': 'AutoTrend தமிழ் Channel', 'channel_id': 'UCNGGMSKukkLMxWwtjzrohgg', 'channel_description': 'Tamil Car Reviews - உங்கள் தமிழ் கார் விமர்சன சேனல்! \n\nஉங்களுக்காக, தமிழ் மொழியில் சிறந்த கார் மதிப்புரைகளை வழங்குகிறோம். அனைத்து பிராண்டுகள் மற்றும் மாடல்களிலும் புதிய மற்றும் பழைய கார்களை விமர்சிக்கிறோம். கார்களின் விவரக்குறிப்புகள், சிறப்பம்சங்கள், விலைகள் மற்றும் பிற தகவல்களை வழங்குகிறோம்.\n\nஎங்கள் கார் மதிப்புரைகளைப் பார்க்கவும், உங்கள் கருத்துக்களை எங்களுடன் பகிர்ந்து கொள்ளவும்.\n\nWe provide Detailed car reviews in Tamil for All cars and All variants! AutoTrend தமிழ் Channel is exclusively for தமிழ் Automobile Enthusiasts !\n\nIf you want to buy a new car and need advise. \nPlease send us an E-mail / WhatsApp. \n\nFor Businesses Collaboration, Sponsorship and Media Invite Contact Us at \n✉️ : autotrendtamil@gmail.com\n 📲 / WhatsApp: 9206880010\n\nStay tuned for more Videos “SUBSCRIBE NOW" \nhttps://youtube.com/@AutoTrendTamil', 'channel_playlist': 'UUNGGMSKukkLMxWwtjzrohgg', 'channel_viewcount': '29744810', 'channel_subcribers': '171000', 'channel_videocount': '837'}
# {'channel_name': 'Bazylland - Tractors & Excavators', 'channel_id': 'UCfI1cD9PdHiz1gIwRkFVcrA', 'channel_description': 'SUBSCRIBE FOR A COOKIE!\n\nHello, welcome to my Bazylland channel\nEnjoy watching my Farming Simulator 22 videos daily and subscribe to my channel!\n\nHow I Make Videos:\n\nI play Farming Simulator 19/22 along with the game mods and create different scenes and maps for each movie.\n\nI make thumbnails by taking a screenshot of my Farming Simulator 19/22 game.\nLater, I edit these screenshots and create the thumbnails.\n\nAll footage used in my video is 100% captured and I am my property.\n\n* Every gameplay clip on this channel is recorded and edited by me (NO RE-USE OF CONTENT).\n\n#LS22 #bazylland  #tractor @bazylland-tractors & Excavators\n\n\nKontakt:\nbazylland@bazylland.pl\n\n\n8f7ce', 'channel_playlist': 'UUfI1cD9PdHiz1gIwRkFVcrA', 'channel_viewcount': '3321369577', 'channel_subcribers': '7110000', 'channel_videocount': '849'}
# {'channel_name': 'Vlad and Niki', 'channel_id': 'UCvlE5gTbOvjiolFlEm-c_Ow', 'channel_description': '“Vlad & Niki” is the global preschool phenomenon and highest rated kids channel on YouTube starring the imaginative personalities and antics of brothers Vlad and Niki, who are showcased in non-stop fun and crazy adventures. Since launching on YouTube in 2018, the “Vlad & Niki” has attracted more than 230+ million subscribers worldwide and 130+ billion views, while averaging five billion monthly views on 21 channels and translated into 18 languages. Each episode is produced with a creative mix of live action, animation and music to create comedic videos for the preschool demographic. "Vlad & Niki" is the property of Content Media Group FZC, LLC, headed by co-founders Sergey and Victoria Vashketov, the parents of global superstar kidfluencers Vlad and Niki.\n\nContact for advertising\nvladandniki@underscoretalent.com\n', 'channel_playlist': 'UUvlE5gTbOvjiolFlEm-c_Ow', 'channel_viewcount': '83459698170', 'channel_subcribers': '108000000', 'channel_videocount': '639'}
# {'channel_name': 'Cooks and Crafts Magic', 'channel_id': 'UC9zuXnuJOp2MnMAd8shpmEw', 'channel_description': "I'm a Professor by Profession. Apart from teaching I have an avid interest in Cooking & Craft. I try my best to share the little knowledge that I have gained in my journey of my life. Hope this helps all my viewers. I'm not perfect & I'm Constantly looking for opportunities to learn. Thank you  for your support & motivation.", 'channel_playlist': 'UU9zuXnuJOp2MnMAd8shpmEw', 'channel_viewcount': '2130', 'channel_subcribers': '204', 'channel_videocount': '10'}
# {'channel_name': 'Grizzy & les Lemmings', 'channel_id': 'UCn9l4gU5mkmmlC2eiVu0LHw', 'channel_description': "Bienvenue sur la chaîne de Grizzy & les Lemmings !\n\nIl est gros comme un ours, fort comme un ours, intelligent... comme un ours. Aucun animal, c'est sûr, n'oserait contester ses privilèges dans toute la faune du Canada. A l'exception près d’un groupe issu de la famille la plus inoffensive, stupide et ridicule de tous les mammifères : les lemmings.\n\nChaque semaine retrouve une nouvelle vidéo.\n\n► Pour t'abonner: http://bit.ly/2sSUFy7", 'channel_playlist': 'UUn9l4gU5mkmmlC2eiVu0LHw', 'channel_viewcount': '3301886584', 'channel_subcribers': '7410000', 'channel_videocount': '295'}

# %%
channel_list = []
db = client["youtube_collection_data"]
data_collection = db['channel_details']
for ch_data in data_collection.find({}, {"_id": 0, "channel_information": 1}):  # Correct the field name
    channel_list.append(ch_data["channel_information"])

# %%
channel_list
# Out:
# [{'channel_name': 'Mad Stuff With Rob',
#   'channel_id': 'UCT8FGLq9AU1H6U3ePhegxJA',
#   'channel_description': "hey Guys! You might remember me from M.A.D. on POGO but I have now started my own YouTube journey. So for all those who want to catch up on the new stuff that I've been doing then I suggest you subscribe! I upload a new DIY video every week. So stay tuned!\n\nHappy DIY-ing!\n\nYouTube - http://www.youtube.com/user/madstuffwithrob\nFacebook - https://www.facebook.com/artguyrob\nInstagram - http://instagram.com/artguyrob\n\n\n",
#   'channel_playlist': 'UUT8FGLq9AU1H6U3ePhegxJA',
#   'channel_viewcount': '164534912',
#   'channel_subcribers': '2460000',
#   'channel_videocount': '473'},
#  {'channel_name': 'Tushar Lall',
#   'channel_id': 'UCbpLD76CnWWZ-JqZ9LjR2Mw',
#   'channel_description': 'Arranger. Composer. Producer- Indian Jam Project\nWork - tusharlall02@gmail.com',
#   'channel_playlist': 'UUbpLD76CnWWZ-JqZ9LjR2Mw',
#   'channel_viewcount': '31316435',
#   'channel_subcribers': '363000',
#   'channel_videocount': '53'},
#  {'channel_name': 'Maroon 5',
#   'channel_id': 'UCBVjMGOIkavEAhyqpxJ73Dw',
#   'channel_description': 'Welcome to the Maroon 5 official Youtube Channel. Head to our website for more info- www.maroon5.com',
#   'channel_playlist': 'UUBVjMGOIkavEAhyqpxJ73Dw',
#   'channel_viewcount': '23385326594',
#   'channel_subcribers': '36800000',
#   'channel_videocount': '176'},
#  {'channel_name': 'Rithu Rocks',
#   'channel_id': 'UC5wuaJnklgYnbJIeTVhPWug',
#   'channel_description': '" Rithu Rocks "\nRithu Rocks channel is all about Entertainment in Tamil. Variety of video content that will make people entertained.\n\nA huge love to all our subscribers and fans. We are overwhelmed by your response.\n\nFor business enquiries and brand collaborations.\nPlease email us at\n rithurocksbranding@gmail.com\n\n',
#   'channel_playlist': 'UU5wuaJnklgYnbJIeTVhPWug',
#   'channel_viewcount': '281607105',
#   'channel_subcribers': '2490000',
#   'channel_videocount': '38'},
#  {'channel_name': 'Cars Town - Cartoons for kids',
#   'channel_id': 'UCs111c1zLU8CGntT6cePyxg',
#   'channel_description': 'Welcome to the best cartoons channel for kids - Cars Team Cartoons - Cartoons for Kids ! Here you can watch long cartoons about all the kinds of cars: Monster Trucks, Trucks, Garbage Trucks, Excavators, Tow Trucks and Tractors, Police cars, Fire Trucks, Bulldozers and many others. Series of 20 + Minutes, every day updates. Funny cars compilations. Enjoy the colorful, bright, interesting and super positive kids friendly cartoons. We care about your child and will do our best to make him happy. Enjoy new cartoons every day. Subscribe and leave your comments to improve our work. Have a nice time on our channel.',
#   'channel_playlist': 'UUs111c1zLU8CGntT6cePyxg',
#   'channel_viewcount': '25138053',
#   'channel_subcribers': '298000',
#   'channel_videocount': '37'},
#  {'channel_name': 'AutoTrend தமிழ் Channel',
#   'channel_id': 'UCNGGMSKukkLMxWwtjzrohgg',
#   'channel_description': 'Tamil Car Reviews - உங்கள் தமிழ் கார் விமர்சன சேனல்! \n\nஉங்களுக்காக, தமிழ் மொழியில் சிறந்த கார் மதிப்புரைகளை வழங்குகிறோம். அனைத்து பிராண்டுகள் மற்றும் மாடல்களிலும் புதிய மற்றும் பழைய கார்களை விமர்சிக்கிறோம். கார்களின் விவரக்குறிப்புகள், சிறப்பம்சங்கள், விலைகள் மற்றும் பிற தகவல்களை வழங்குகிறோம்.\n\nஎங்கள் கார் மதிப்புரைகளைப் பார்க்கவும், உங்கள் கருத்துக்களை எங்களுடன் பகிர்ந்து கொள்ளவும்.\n\nWe provide Detailed car reviews in Tamil for All cars and All variants! AutoTrend தமிழ் Channel is exclusively for தமிழ் Automobile Enthusiasts !\n\nIf you want to buy a new car and need advise. \nPlease send us an E-mail / WhatsApp. \n\nFor Businesses Collaboration, Sponsorship and Media Invite Contact Us at \n✉️ : autotrendtamil@gmail.com\n 📲 / WhatsApp: 9206880010\n\nStay tuned for more Videos “SUBSCRIBE NOW" \nhttps://youtube.com/@AutoTrendTamil',
#   'channel_playlist': 'UUNGGMSKukkLMxWwtjzrohgg',
#   'channel_viewcount': '29744810',
#   'channel_subcribers': '171000',
#   'channel_videocount': '837'},
#  {'channel_name': 'Bazylland - Tractors & Excavators',
#   'channel_id': 'UCfI1cD9PdHiz1gIwRkFVcrA',
#   'channel_description': 'SUBSCRIBE FOR A COOKIE!\n\nHello, welcome to my Bazylland channel\nEnjoy watching my Farming Simulator 22 videos daily and subscribe to my channel!\n\nHow I Make Videos:\n\nI play Farming Simulator 19/22 along with the game mods and create different scenes and maps for each movie.\n\nI make thumbnails by taking a screenshot of my Farming Simulator 19/22 game.\nLater, I edit these screenshots and create the thumbnails.\n\nAll footage used in my video is 100% captured and I am my property.\n\n* Every gameplay clip on this channel is recorded and edited by me (NO RE-USE OF CONTENT).\n\n#LS22 #bazylland  #tractor @bazylland-tractors & Excavators\n\n\nKontakt:\nbazylland@bazylland.pl\n\n\n8f7ce',
#   'channel_playlist': 'UUfI1cD9PdHiz1gIwRkFVcrA',
#   'channel_viewcount': '3321369577',
#   'channel_subcribers': '7110000',
#   'channel_videocount': '849'},
#  {'channel_name': 'Vlad and Niki',
#   'channel_id': 'UCvlE5gTbOvjiolFlEm-c_Ow',
#   'channel_description': '“Vlad & Niki” is the global preschool phenomenon and highest rated kids channel on YouTube starring the imaginative personalities and antics of brothers Vlad and Niki, who are showcased in non-stop fun and crazy adventures. Since launching on YouTube in 2018, the “Vlad & Niki” has attracted more than 230+ million subscribers worldwide and 130+ billion views, while averaging five billion monthly views on 21 channels and translated into 18 languages. Each episode is produced with a creative mix of live action, animation and music to create comedic videos for the preschool demographic. "Vlad & Niki" is the property of Content Media Group FZC, LLC, headed by co-founders Sergey and Victoria Vashketov, the parents of global superstar kidfluencers Vlad and Niki.\n\nContact for advertising\nvladandniki@underscoretalent.com\n',
#   'channel_playlist': 'UUvlE5gTbOvjiolFlEm-c_Ow',
#   'channel_viewcount': '83459698170',
#   'channel_subcribers': '108000000',
#   'channel_videocount': '639'},
#  {'channel_name': 'Cooks and Crafts Magic',
#   'channel_id': 'UC9zuXnuJOp2MnMAd8shpmEw',
#   'channel_description': "I'm a Professor by Profession. Apart from teaching I have an avid interest in Cooking & Craft. I try my best to share the little knowledge that I have gained in my journey of my life. Hope this helps all my viewers. I'm not perfect & I'm Constantly looking for opportunities to learn. Thank you  for your support & motivation.",
#   'channel_playlist': 'UU9zuXnuJOp2MnMAd8shpmEw',
#   'channel_viewcount': '2130',
#   'channel_subcribers': '204',
#   'channel_videocount': '10'},
#  {'channel_name': 'Grizzy & les Lemmings',
#   'channel_id': 'UCn9l4gU5mkmmlC2eiVu0LHw',
#   'channel_description': "Bienvenue sur la chaîne de Grizzy & les Lemmings !\n\nIl est gros comme un ours, fort comme un ours, intelligent... comme un ours. Aucun animal, c'est sûr, n'oserait contester ses privilèges dans toute la faune du Canada. A l'exception près d’un groupe issu de la famille la plus inoffensive, stupide et ridicule de tous les mammifères : les lemmings.\n\nChaque semaine retrouve une nouvelle vidéo.\n\n► Pour t'abonner: http://bit.ly/2sSUFy7",
#   'channel_playlist': 'UUn9l4gU5mkmmlC2eiVu0LHw',
#   'channel_viewcount': '3301886584',
#   'channel_subcribers': '7410000',
#   'channel_videocount': '295'}]

# %%
# Creating DataFrame for YouTube Channel Data

channel_list = []
db = client["youtube_collection_data"]
data_collection = db['channel_details']
for ch_data in data_collection.find({}, {"_id": 0, "channel_information": 1}):  # Correct the field name
    channel_list.append(ch_data["channel_information"])

df = pd.DataFrame(channel_list)

# %%
df
# Out:
#                         channel_name                channel_id  \
# 0                 Mad Stuff With Rob  UCT8FGLq9AU1H6U3ePhegxJA
# 1                        Tushar Lall  UCbpLD76CnWWZ-JqZ9LjR2Mw
# 2                           Maroon 5  UCBVjMGOIkavEAhyqpxJ73Dw
# 3                        Rithu Rocks  UC5wuaJnklgYnbJIeTVhPWug
# 4      Cars Town - Cartoons for kids  UCs111c1zLU8CGntT6cePyxg
# 5            AutoTrend தமிழ் Channel  UCNGGMSKukkLMxWwtjzrohgg
# 6  Bazylland - Tractors & Excavators  UCfI1cD9PdHiz1gIwRkFVcrA
# 7                      Vlad and Niki  UCvlE5gTbOvjiolFlEm-c_Ow
# 8             Cooks and Crafts Magic  UC9zuXnuJOp2MnMAd8shpmEw
# 9              Grizzy & les Lemmings  UCn9l4gU5mkmmlC2eiVu0LHw
#
#                                  channel_description  \
# 0  hey Guys! You might remember me from M.A.D. on...
# 1  Arranger. Composer. Producer- Indian Jam Proje...
# 2  Welcome to the Maroon 5 official Youtube Chann...
# 3  " Rithu Rocks "\nRithu Rocks channel is all ab...
# 4  Welcome to the best cartoons channel for kids ...
# 5  Tamil Car Reviews - உங்கள் தமிழ் கார் விமர்சன ...
# 6  SUBSCRIBE FOR A COOKIE!\n\nHello, welcome to m...
# 7  “Vlad & Niki” is the global preschool phenomen...
# 8  I'm a Professor by Profession. Apart from teac...
# 9  Bienvenue sur la chaîne de Grizzy & les Lemmin...
#
#            channel_playlist channel_viewcount channel_subcribers  \
# 0  UUT8FGLq9AU1H6U3ePhegxJA         164534912            2460000
# 1  UUbpLD76CnWWZ-JqZ9LjR2Mw          31316435             363000
# 2  UUBVjMGOIkavEAhyqpxJ73Dw       23385326594           36800000
# 3  UU5wuaJnklgYnbJIeTVhPWug         281607105            2490000
# 4  UUs111c1zLU8CGntT6cePyxg          25138053             298000
# 5  UUNGGMSKukkLMxWwtjzrohgg          29744810             171000
# 6  UUfI1cD9PdHiz1gIwRkFVcrA        3321369577            7110000
# 7  UUvlE5gTbOvjiolFlEm-c_Ow       83459698170          108000000
# 8  UU9zuXnuJOp2MnMAd8shpmEw              2130                204
# 9  UUn9l4gU5mkmmlC2eiVu0LHw        3301886584            7410000
#
#   channel_videocount
# 0                473
# 1                 53
# 2                176
# 3                 38
# 4                 37
# 5                837
# 6                849
# 7                639
# 8                 10
# 9                295

# %%
# Creating Channel Information Table

# Establish a connection to the MySQL database

def channels_table():

    mydb = mysql.connector.connect(
            host="localhost",
            user="paart",
            password="2352",
            database="data_collection_from_youtube",
            port="3306"
        )


    # Creating a cursor to execute SQL queries
    
    cursor = mydb.cursor()

    drop_query = '''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()


    # Creating a table for channels

    try:
        create_query ='''create table if not exists channels(channel_name varchar(100),
                                                                channel_id varchar(100) primary key,
                                                                channel_description text,
                                                                channel_playlist varchar(100),
                                                                channel_viewcount bigint,
                                                                channel_subcribers bigint,
                                                                channel_videocount bigint)'''
        
        cursor.execute(create_query)
        mydb.commit()

    except:
        print("Channels table already created")    

    channel_list = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for ch_data in data_collection.find({}, {"_id": 0, "channel_information": 1}):  
        channel_list.append(ch_data["channel_information"])

    df = pd.DataFrame(channel_list)  


    for index,row in df.iterrows():
        insert_query = '''insert into channels( channel_name,
                                                channel_id,
                                                channel_description,
                                                channel_playlist,
                                                channel_viewcount,
                                                channel_subcribers,
                                                channel_videocount)
                                                
                                                values(%s,%s,%s,%s,%s,%s,%s)'''
        values = (row['channel_name'],
            row['channel_id'],
            row['channel_description'],
            row['channel_playlist'],
            row['channel_viewcount'],
            row['channel_subcribers'],
            row['channel_videocount'])

        try:
            cursor.execute(insert_query,values)     
            mydb.commit()
        except:
            print("channels values are already inserted")

# %%
# Building Playlist Information Table

playlist_list = []
db = client["youtube_collection_data"]
data_collection = db['channel_details']
for pl_data in data_collection.find({}, {"_id": 0, "playlist_information": 1}): 
    for i in range(len(pl_data["playlist_information"])):
        playlist_list.append(pl_data["playlist_information"][i])

df1 = pd.DataFrame(playlist_list)

# %%
df1
# Out:
#                             Playlist_Id                Channel_Id  \
# 0    PLzl205uwoTCA34RkR24xTEXpdoND80DP9  UCT8FGLq9AU1H6U3ePhegxJA
# 1    PLzl205uwoTCBxk-ey-hW4J44ULop0YxVE  UCT8FGLq9AU1H6U3ePhegxJA
# 2    PLzl205uwoTCB0IWHWqhSJKR0mix6ZLOoM  UCT8FGLq9AU1H6U3ePhegxJA
# 3    PLzl205uwoTCCIXbLSoPsGyAbbggDosNIL  UCT8FGLq9AU1H6U3ePhegxJA
# 4    PLzl205uwoTCD-qTQ7nPMNtifIgT9fP9nK  UCT8FGLq9AU1H6U3ePhegxJA
# ..                                  ...                       ...
# 157  PLfcmsKi1TD5xCIPkXSqekRgLdYLGYO5to  UCn9l4gU5mkmmlC2eiVu0LHw
# 158  PLfcmsKi1TD5zgzn-qc_5bA-tuTr28lbK0  UCn9l4gU5mkmmlC2eiVu0LHw
# 159  PLfcmsKi1TD5z-BLQ2GVA4txE6uAaCvDWb  UCn9l4gU5mkmmlC2eiVu0LHw
# 160  PLfcmsKi1TD5zV9fi7gpDZvvV6vd-c2ImX  UCn9l4gU5mkmmlC2eiVu0LHw
# 161  PLfcmsKi1TD5xJzZBY1NWhNYVekNwH4pRo  UCn9l4gU5mkmmlC2eiVu0LHw
#
#                                           Title           Channel_Name  \
# 0                 #CreateWithAlpenliebe and Rob     Mad Stuff With Rob
# 1                          #FavouriteDIYsWithMe     Mad Stuff With Rob
# 2                            My Love For Marvel     Mad Stuff With Rob
# 3                               Me & My Friends     Mad Stuff With Rob
# 4              DIY for Festivals & Special Days     Mad Stuff With Rob
# ..                                          ...                    ...
# 157                  30'⏱ Grizzy & les Lemmings  Grizzy & les Lemmings
# 158  Tous les épisodes de Grizzy & les Lemmings  Grizzy & les Lemmings
# 159                     ⏱️20minutes of Grizzy !  Grizzy & les Lemmings
# 160     Tous les bonus de Grizzy & les Lemmings  Grizzy & les Lemmings
# 161     Tous les clips de Grizzy & les Lemmings  Grizzy & les Lemmings
#
#               PublishedAt  Video_Count
# 0    2021-12-11T10:36:50Z            8
# 1    2020-03-26T10:54:30Z           11
# 2    2019-07-17T06:56:02Z           29
# 3    2019-07-17T05:42:55Z           28
# 4    2019-07-16T14:06:12Z           26
# ..                    ...          ...
# 157  2018-07-30T07:51:15Z           13
# 158  2017-09-02T10:06:04Z          209
# 159  2017-08-07T08:02:45Z           83
# 160  2017-06-09T15:35:47Z           27
# 161  2017-06-09T15:35:01Z          227
#
# [162 rows x 6 columns]

# %%
# Creating Playlists Information Function


def playlist_table():

    mydb = mysql.connector.connect(
        host="localhost",
        user="paart",
        password="2352",
        database="data_collection_from_youtube",
        port="3306"
    )

    # Create a cursor to execute SQL queries
    cursor = mydb.cursor()

    drop_query = '''DROP TABLE IF EXISTS playlists'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query = '''CREATE TABLE IF NOT EXISTS playlists(
                        Playlist_Id VARCHAR(100) PRIMARY KEY,
                        Channel_Id VARCHAR(100),
                        Title VARCHAR(100),
                        Channel_Name VARCHAR(100),
                        PublishedAt TIMESTAMP,
                        Video_Count INT
                    )'''
    cursor.execute(create_query)
    mydb.commit()    

    playlist_list = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for pl_data in data_collection.find({}, {"_id": 0, "playlist_information": 1}): 
        for i in range(len(pl_data["playlist_information"])):
            playlist_list.append(pl_data["playlist_information"][i])

    df1 = pd.DataFrame(playlist_list)

    from datetime import datetime

    # ...

    for index, row in df1.iterrows():
        # Convert ISO 8601 datetime string to MySQL-compatible format
        published_at = datetime.strptime(row['PublishedAt'], '%Y-%m-%dT%H:%M:%SZ').strftime('%Y-%m-%d %H:%M:%S')

        insert_query = '''insert into playlists(Playlist_Id,
                                                Channel_Id,
                                                Title,
                                                Channel_Name,
                                                PublishedAt,
                                                Video_Count)
                        values(%s, %s, %s, %s, %s, %s)'''

        values = (row['Playlist_Id'],
                row['Channel_Id'],
                row['Title'],
                row['Channel_Name'],
                published_at,  # Use the formatted datetime string
                row['Video_Count'])

        cursor.execute(insert_query, values)
        mydb.commit()

# %%
# Creating Video Information Table

video_list = []
db = client["youtube_collection_data"]
data_collection = db['channel_details']
for vi_data in data_collection.find({}, {"_id": 0, "video_information": 1}): 
    for i in range(len(vi_data["video_information"])):
        video_list.append(vi_data["video_information"][i])

df2 = pd.DataFrame(video_list)

# %%
df2
# Out:
#                Channel_Name                Channel_ID  \
# 0        Mad Stuff With Rob  UCT8FGLq9AU1H6U3ePhegxJA
# 1        Mad Stuff With Rob  UCT8FGLq9AU1H6U3ePhegxJA
# 2        Mad Stuff With Rob  UCT8FGLq9AU1H6U3ePhegxJA
# 3        Mad Stuff With Rob  UCT8FGLq9AU1H6U3ePhegxJA
# 4        Mad Stuff With Rob  UCT8FGLq9AU1H6U3ePhegxJA
# ...                     ...                       ...
# 3558  Grizzy & les Lemmings  UCn9l4gU5mkmmlC2eiVu0LHw
# 3559  Grizzy & les Lemmings  UCn9l4gU5mkmmlC2eiVu0LHw
# 3560  Grizzy & les Lemmings  UCn9l4gU5mkmmlC2eiVu0LHw
# 3561  Grizzy & les Lemmings  UCn9l4gU5mkmmlC2eiVu0LHw
# 3562  Grizzy & les Lemmings  UCn9l4gU5mkmmlC2eiVu0LHw
#
#                                             Video_Title     Video_ID  \
# 0             Superhero Doodles with Uni Pin Fineliners  ieX38it7gFo
# 1             Tried the new WINDOWS 11 | Cool Features!  WDJrRiI4kJ4
# 2     I did the #ManikeMove with @NoraFatehi, sort o...  uMeAQ4pO_dI
# 3     Comment 😎 if you got it before reveal, 😳 if yo...  df3regswjQI
# 4     MAGIC LOOP TUTORIAL | How To Make A Infinite L...  WzjdkcFjEaY
# ...                                                 ...          ...
# 3558  Cours de vol avec les Lemmings - Grizzy & les ...  ZWbMDw13YeM
# 3559  Anniversaire surprise avec les Lemmings - Griz...  IFKDDgtUPZ0
# 3560                   TOP 10 de Grizzy VS les Lemmings  Axnhq_fW_Dw
# 3561  Grizzy tente de se faire adopter par les Lemmi...  Gb6DDES_vvQ
# 3562  Course poursuite Grizzy VS Lemmings pour la pâ...  oovO2w5LhsM
#
#                                            Thumbnail  \
# 0     https://i.ytimg.com/vi/ieX38it7gFo/default.jpg
# 1     https://i.ytimg.com/vi/WDJrRiI4kJ4/default.jpg
# 2     https://i.ytimg.com/vi/uMeAQ4pO_dI/default.jpg
# 3     https://i.ytimg.com/vi/df3regswjQI/default.jpg
# 4     https://i.ytimg.com/vi/WzjdkcFjEaY/default.jpg
# ...                                              ...
# 3558  https://i.ytimg.com/vi/ZWbMDw13YeM/default.jpg
# 3559  https://i.ytimg.com/vi/IFKDDgtUPZ0/default.jpg
# 3560  https://i.ytimg.com/vi/Axnhq_fW_Dw/default.jpg
# 3561  https://i.ytimg.com/vi/Gb6DDES_vvQ/default.jpg
# 3562  https://i.ytimg.com/vi/oovO2w5LhsM/default.jpg
#
#                                             Description        Published_Date  \
# 0     Uniball sent me these Uni Pin Fineliners and I...  2023-05-08T06:27:48Z
# 1     Guys as you can see I got my hands on this sup...  2023-02-24T07:59:13Z
# 2     Even my illustrations can’t resist doing the #...  2022-10-07T06:39:56Z
# 3                                                        2022-08-30T06:04:43Z
# 4     First 1000 people to click on this link will g...  2022-05-16T10:33:32Z
# ...                                                 ...                   ...
# 3558  Les Lemmings jouent à flotter comme des drapea...  2017-06-24T08:00:02Z
# 3559  Anniversaire surprise avec les Lemmings - Griz...  2017-06-17T08:00:00Z
# 3560  TOP 10 de Grizzy VS les Lemmings\nRetrouve une...  2017-06-10T08:00:01Z
# 3561  Suite à un terrible choc sur la tête, Grizzy n...  2017-06-10T08:00:01Z
# 3562  Grizzy est frustré : il découvre que la réserv...  2017-06-10T08:00:01Z
#
#                                                    Tags  Duration Defnination  \
# 0     [mad stuff with rob, mad stuff, pogo, rob, DIY...     PT53S          hd
# 1     [mad stuff with rob, mad stuff, pogo, rob, DIY...    PT3M8S          hd
# 2                                                  None     PT21S          hd
# 3                                                  None     PT22S          hd
# 4     [mad stuff with rob, mad stuff, pogo, rob, DIY...  PT10M12S          hd
# ...                                                 ...       ...         ...
# 3558  [lemmings, kids, grizzly and the lemmings, gri...   PT1M49S          hd
# 3559  [Grizzy & the lemmings, grizzy & les lemmings,...   PT2M17S          hd
# 3560  [Grizzy & les Lemmings, Grizzy & the lemmings,...   PT4M55S          hd
# 3561  [grizzy & les Lemmings, grizzy & the lemmings,...   PT2M20S          hd
# 3562  [Grizzy & les lemmings, grizzy & the lemmings,...   PT2M15S          hd
#
#          Views  Likes Comment_count Favourite_count Like_count
# 0       241238  18597           130               0      18597
# 1        65304   2608           264               0       2608
# 2       192290  13521           145               0      13521
# 3       157498   5819           112               0       5819
# 4       150295   7674           405               0       7674
# ...        ...    ...           ...             ...        ...
# 3558   1030643   1619             0               0       1619
# 3559  17297624  72591             0               0      72591
# 3560    856702   2334             0               0       2334
# 3561   8728646  34059             0               0      34059
# 3562    776921   2375             0               0       2375
#
# [3563 rows x 15 columns]

# %%
# Creating a Function for Table Videos

def videos_table():
    mydb = mysql.connector.connect(
        host="localhost",
        user="paart",
        password="2352",
        database="data_collection_from_youtube",
        port="3306"
    )

    # Create a cursor to execute SQL queries

    cursor = mydb.cursor()

    drop_query = '''DROP TABLE IF EXISTS videos'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query = '''CREATE TABLE IF NOT EXISTS videos(
                        Channel_Name VARCHAR(100),
                        Channel_ID VARCHAR(100),
                        Video_Title VARCHAR(100),
                        Video_ID VARCHAR(100) PRIMARY KEY,
                        Thumbnail VARCHAR(200),
                        Description TEXT,
                        Published_Date TIMESTAMP,
                        Tags TEXT,
                        Duration BIGINT,
                        Defnination VARCHAR(50),
                        Views BIGINT,
                        Likes BIGINT,
                        Comment_count INT,
                        Favourite_count INT,
                        Like_count INT
                        )'''
    cursor.execute(create_query)
    mydb.commit()  

    video_list = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for vi_data in data_collection.find({}, {"_id": 0, "video_information": 1}): 
        for i in range(len(vi_data["video_information"])):
            video_list.append(vi_data["video_information"][i])

    df2 = pd.DataFrame(video_list)


    from datetime import datetime

    # ...

    for index, row in df2.iterrows():
        # Convert ISO 8601 datetime string to MySQL-compatible format

        published_date = datetime.strptime(row['Published_Date'], '%Y-%m-%dT%H:%M:%SZ').strftime('%Y-%m-%d %H:%M:%S')

        # Convert the list to a comma-separated string

        tags_str = ', '.join(map(str, row['Tags'])) if row['Tags'] is not None else ''



        # Convert ISO 8601 duration string to seconds
        
        iso_duration = row['Duration']
        duration_seconds = 0

        if 'T' in iso_duration:
            time_part = iso_duration.split('T')[1]

            if 'H' in time_part:
                hours, time_part = time_part.split('H')
                duration_seconds += int(hours) * 3600

            if 'M' in time_part:
                minutes = int(time_part.split('M')[0])
                duration_seconds += minutes * 60

                if 'S' in time_part:
                    seconds = int(time_part.split('M')[1].split('S')[0])
                    duration_seconds += seconds
            elif 'S' in time_part:
                duration_seconds += int(time_part.split('S')[0])


        elif 'S' in iso_duration:
            duration_seconds += int(iso_duration.split('S')[0])

        insert_query = '''INSERT INTO videos(Channel_Name, 
                                            Channel_ID, 
                                            Video_Title, 
                                            Video_ID,
                                            Thumbnail, 
                                            Description, 
                                            Published_Date, 
                                            Tags, 
                                            Duration, 
                                            Defnination, 
                                            Views, 
                                            Likes, 
                                            Comment_count, 
                                            Favourite_count, 
                                            Like_count)
                        VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)

                        ON DUPLICATE KEY UPDATE
                        Channel_Name=VALUES(Channel_Name), 
                        Channel_ID=VALUES(Channel_ID), 
                        Video_Title=VALUES(Video_Title), 
                        Thumbnail=VALUES(Thumbnail),
                        Description=VALUES(Description), 
                        Published_Date=VALUES(Published_Date), 
                        Tags=VALUES(Tags), 
                        Duration=VALUES(Duration),
                        Defnination=VALUES(Defnination), 
                        Views=VALUES(Views), 
                        Likes=VALUES(Likes), 
                        Comment_count=VALUES(Comment_count),
                        Favourite_count=VALUES(Favourite_count), 
                        Like_count=VALUES(Like_count)'''

        values = (row['Channel_Name'], 
                row['Channel_ID'], 
                row['Video_Title'], 
                row['Video_ID'], 
                row['Thumbnail'], 
                row['Description'],
                published_date, 
                tags_str, 
                duration_seconds, 
                row['Defnination'], 
                row['Views'], 
                row['Likes'],
                row['Comment_count'], 
                row['Favourite_count'], 
                row['Like_count']
                )



        cursor.execute(insert_query, values)
        mydb.commit()

# %%
# Creating DataFrame for Comments Table

comment_list = []
db = client["youtube_collection_data"]
data_collection = db['channel_details']
for com_data in data_collection.find({}, {"_id": 0, "comment_information": 1}): 
    for i in range(len(com_data["comment_information"])):
        comment_list.append(com_data["comment_information"][i])

df3 = pd.DataFrame(comment_list)

# %%
df3
# Out:
#                       comment_Id     Video_Id  \
# 0     Ugy2xigIkFfL74f7eiF4AaABAg  ieX38it7gFo
# 1     Ugym2pauU9r051QCWx94AaABAg  ieX38it7gFo
# 2     UgyEOe10vndzKN8jOY54AaABAg  ieX38it7gFo
# 3     UgyTitNRlm_NOa1xPjB4AaABAg  ieX38it7gFo
# 4     UgwtedMtej7HIBs6Nwp4AaABAg  ieX38it7gFo
# ...                          ...          ...
# 9198  UgyNiZLSX_GmCseCpEF4AaABAg  cy6FlmUM94k
# 9199  Ugy0lFl4e2TsM1q5kWd4AaABAg  cy6FlmUM94k
# 9200  Ugxl97ktSI5nEI7nNO94AaABAg  cy6FlmUM94k
# 9201  Ugy9Ij09XzL0LEOADgl4AaABAg  cy6FlmUM94k
# 9202  Ugxp-AKhE0Verjikmgp4AaABAg  cy6FlmUM94k
#
#                                            Comment_Text  \
# 0                                                 ❤❤❤❤❤
# 1           joh joh free fire lover hai woh like karo ❤
# 2                   Sir aap ko tv mai nahi aate par kyo
# 3                     Happy belated birthday rob sir 🎉🎉
# 4                                                   🙏🙏🙏
# ...                                                 ...
# 9198                                      Very nice 👌👌👌
# 9199                                            Nice✌️💙
# 9200                                                  😍
# 9201  This is going to be a variety one😋<br>And fina...
# 9202                                        Yummy...👌👌👌
#
#                    Commet_Author   Comment_publication
# 0       @devanshn.contractor5259  2024-01-08T18:03:17Z
# 1                    @gwneha3093  2023-12-31T17:14:28Z
# 2                 @aactorboy9588  2023-12-31T11:02:32Z
# 3              @dimplesharma1454  2023-12-29T15:02:15Z
# 4                  @Debjittandar  2023-12-27T13:36:50Z
# ...                          ...                   ...
# 9198          @kumarisuseela2759  2020-06-25T09:26:34Z
# 9199                     @alendz  2020-06-25T08:30:28Z
# 9200      @gayathrielangovan6662  2020-06-25T06:45:33Z
# 9201                @aneetamaryk  2020-06-25T05:52:06Z
# 9202  @lavanyajayaseelakumar3022  2020-06-25T05:33:08Z
#
# [9203 rows x 5 columns]

# %%
## Creating Comment Table in MySQL

def comments_table():

    mydb = mysql.connector.connect(
        host="localhost",
        user="paart",
        password="2352",
        database="data_collection_from_youtube",
        port="3306"
    )

    # Create a cursor to execute SQL queries

    cursor = mydb.cursor()

    drop_query = '''DROP TABLE IF EXISTS comments'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query = '''CREATE TABLE IF NOT EXISTS comments(
                        comment_Id VARCHAR(100) PRIMARY KEy,
                        Video_Id VARCHAR(100),
                        Comment_Text TEXT,
                        Commet_Author VARCHAR(100),
                        Comment_publication TIMESTAMP
                        )'''
    cursor.execute(create_query)
    mydb.commit() 

    comment_list = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for com_data in data_collection.find({}, {"_id": 0, "comment_information": 1}): 
        for i in range(len(com_data["comment_information"])):
            comment_list.append(com_data["comment_information"][i])

    df3 = pd.DataFrame(comment_list)

    from datetime import datetime
    # ...

    for index, row in df3.iterrows():
        # Convert ISO 8601 datetime string to MySQL-compatible format
        
        comment_publ = datetime.strptime(row['Comment_publication'], '%Y-%m-%dT%H:%M:%SZ').strftime('%Y-%m-%d %H:%M:%S')
        insert_query = '''insert into comments(comment_Id,
                                                Video_Id,
                                                Comment_Text,
                                                Commet_Author,
                                                Comment_publication
                                                )
                            values(%s, %s, %s, %s, %s)'''

        values = (row['comment_Id'],
                row['Video_Id'],
                row['Comment_Text'],
                row['Commet_Author'],  # Use the formatted datetime string
                comment_publ
                )

        cursor.execute(insert_query, values)
        mydb.commit()

# %%
# Creating Database Tables for Channel, Video, Playlist, and Comment Information

def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_table()

    return "Tables Created Successfully"

# %%
Tables = tables()

# %%
Tables
# Out:
# 'Tables Created Successfully'

# %%
# Initializing Streamlit for YouTube Data Exploration

def show_channels_table():
    channel_list = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for ch_data in data_collection.find({}, {"_id": 0, "channel_information": 1}):  # Correct the field name
        channel_list.append(ch_data["channel_information"])

    df = st.dataframe(channel_list)

    return df

# %%
def show_playlist_table():
    playlist_list = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for pl_data in data_collection.find({}, {"_id": 0, "playlist_information": 1}): 
        for i in range(len(pl_data["playlist_information"])):
            playlist_list.append(pl_data["playlist_information"][i])

    df1 = st.dataframe(playlist_list) 

    return df1

# %%
def show_videos_table():
    video_list = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for vi_data in data_collection.find({}, {"_id": 0, "video_information": 1}): 
        for i in range(len(vi_data["video_information"])):
            video_list.append(vi_data["video_information"][i])

    df2 = st.dataframe(video_list)

    return df2

# %%
def show_comments_table():
    comment_list = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for com_data in data_collection.find({}, {"_id": 0, "comment_information": 1}): 
        for i in range(len(com_data["comment_information"])):
            comment_list.append(com_data["comment_information"][i])

    df3 = st.dataframe(comment_list)

    return df3

# %%
# Designing the User Interface for YouTube Data Exploration

# Set page title and icon

st.set_page_config(
    page_title="YouTube Data Exploration",
    page_icon=":red_circle:"
)

# Sidebar

with st.sidebar:
    st.title(":violet[YouTube Data Dive: Script, Collect, and Analyze]")
    st.markdown("## Description")
    st.write("- Explore the vast realm of YouTube data with Python scripting, efficient data collection, seamless API integration, and robust data management using MongoDB and SQL.")
    st.write("- Effortlessly explore and visualize YouTube data, transforming raw information into actionable insights.")
    

# Main content
    
st.title(":red[Explore YouTube Data: Harvesting and Warehousing]")
st.header("Welcome to the YouTube Data Exploration Dashboard!")

# Interactive Channel ID Input for YouTube Data Exploration

channel_id = st.text_input("Enter the Channel ID")

# Data Collection and Storage based on Channel ID in MongoDB

if st.button("Collect and store data"):
    channel_ids = []
    db = client["youtube_collection_data"]
    data_collection = db['channel_details']
    for ch_data in data_collection.find({}, {"_id": 0, "channel_information": 1}):  # Correct the field name
        channel_ids.append(ch_data["channel_information"]['channel_id'])

        if channel_id in channel_ids:
            st.success("Channel Details of the given Channel ID already exists")

        else:
            insert = channel_details(channel_id)    
            st.success(insert)

# Migrate Data to SQL Database
            
if st.button("Migrate to SQL"):
    table = tables()
    st.success(table)

# Select Table for Viewing
    
show_table = st.radio("Select the Table fro View",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS")) 
if show_table == "CHANNELS":
    show_channels_table()

elif show_table == "PLAYLISTS":
    show_playlist_table()

elif show_table == "VIDEOS":
    show_videos_table()

elif show_table == "COMMENTS":
    show_comments_table()
# Out:
# DeltaGenerator()

# %%
# SQL Connection

mydb = mysql.connector.connect(
    host="localhost",
    user="paart",
    password="2352",
    database="data_collection_from_youtube",
    port="3306"
)

# Create a cursor to execute SQL queries
cursor = mydb.cursor()


question = st.selectbox("Select Your Question",("1. What are the names of all the videos and their corresponding channels?",
                                                "2. Which channels have the most number of videos, and how many videos do they have?",
                                                "3. What are the top 10 most viewed videos and their respective channels?",
                                                "4. How many comments were made on each video, and what are their corresponding video names?",
                                                "5. Which videos have the highest number of likes, and what are their corresponding channel names?",
                                                "6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?",
                                                "7. What is the total number of views for each channel, and what are their corresponding channel names?",
                                                "8. What are the names of all the channels that have published videos in the year2022?",
                                                "9. What is the average duration of all videos in each channel, and what are their corresponding channel names",
                                                "10. Which videos have the highest number of comments, and what are their corresponding channel names?"))


if question == "1. What are the names of all the videos and their corresponding channels?":

    query1 = '''select Video_Title as videos, Channel_Name as channelname from videos'''
    cursor.execute(query1)

    # Fetch the results before committing
    table1 = cursor.fetchall()
    df_table1 = pd.DataFrame(table1, columns=["video title", "channel name"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table1)

elif question == "2. Which channels have the most number of videos, and how many videos do they have?":

    query2 = '''select channel_name as channelname,channel_videocount as no_of_videos from channels order by channel_videocount desc'''
    cursor.execute(query2)

    # Fetch the results before committing
    table2 = cursor.fetchall()
    df_table2 = pd.DataFrame(table2, columns=["Channel name", "No of Videos"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table2)


elif question == "3. What are the top 10 most viewed videos and their respective channels?":

    query3 = '''select Views as views, Channel_Name as `channel name`, Video_Title as `video title` from videos where Views is not null order by Views desc limit 10
    '''
    cursor.execute(query3)

    # Fetch the results before committing
    table3 = cursor.fetchall()
    df_table3 = pd.DataFrame(table3, columns=["views", "channel name","video title"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table3)    


elif question == "4. How many comments were made on each video, and what are their corresponding video names?":

    query4 = '''select Comment_count as no_of_comments,Video_Title as videotitle from videos where Comment_count is not null'''
    cursor.execute(query4)

    # Fetch the results before committing
    table4 = cursor.fetchall()
    df_table4 = pd.DataFrame(table4, columns=["no_of_comments", "video title"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table4)    


elif question == "5. Which videos have the highest number of likes, and what are their corresponding channel names?":

    query5 = '''select Video_Title as videotitle,Channel_Name as channelname,Likes as likecount from videos where Likes is not null order by Likes desc'''
    cursor.execute(query5)

    # Fetch the results before committing
    table5 = cursor.fetchall()
    df_table5 = pd.DataFrame(table5, columns=["video title", "channelname","like count"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table5)


elif question == "6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?":

    query6 = '''select Likes as likecount,Video_title as videotitle from videos'''
    cursor.execute(query6)

    # Fetch the results before committing
    table6 = cursor.fetchall()
    df_table6 = pd.DataFrame(table6, columns=["like count", "video title"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table6)


elif question == "7. What is the total number of views for each channel, and what are their corresponding channel names?":

    query7 = '''select channel_name as channelname,channel_viewcount as totalviews from channels'''
    cursor.execute(query7)

    # Fetch the results before committing
    table7 = cursor.fetchall()
    df_table7 = pd.DataFrame(table7, columns=["channel name", "total views"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table7)      


elif question == "8. What are the names of all the channels that have published videos in the year2022?":

    query8 = '''select Channel_Name as channelname,Published_Date as publishedin2022 from videos where extract(year from Published_Date) = 2022'''
    cursor.execute(query8)

    # Fetch the results before committing
    table8 = cursor.fetchall()
    df_table8 = pd.DataFrame(table8, columns=["channel name", "published in 2022"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table8)  



elif question == "9. What is the average duration of all videos in each channel, and what are their corresponding channel names":

    query9 = '''select Channel_Name as channelname,AVG(Duration) as avgduration from videos group by Channel_Name order by AVG(Duration) desc'''
    cursor.execute(query9)

    # Fetch the results before committing
    table9 = cursor.fetchall()
    df_table9 = pd.DataFrame(table9, columns=["channel name", "avg duration"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table9)    


elif question == "10. Which videos have the highest number of comments, and what are their corresponding channel names?":

    query10 = '''select Channel_Name as channelname,Video_Title as videotitle,Comment_count as Highest_no_of_comments from videos where Comment_count is not null order by Comment_count desc'''
    cursor.execute(query10)

    # Fetch the results before committing
    table10 = cursor.fetchall()
    df_table10 = pd.DataFrame(table10, columns=["channel name", "video title","Highest no of comments"])

    # Close the cursor
    cursor.close()

    # Commit the transaction
    mydb.commit()

    
    st.write(df_table10)
